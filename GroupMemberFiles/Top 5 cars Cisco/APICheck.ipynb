# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path


# Import the API key
from config import car_key
from config import car_secret_key

# %%
def linreg_plot(x_values, y_values):
    slope, intercept, rvalue, pvalue, stderr = linregress(x_values[1], y_values[1])
    regress_values = x_values[1] * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    x_quantile = np.percentile(x_values[1], [1])
    if slope > 0:
        y_quantile = np.percentile(y_values[1], [99])
    else:
        y_quantile = np.percentile(y_values[1], [1])
    print(f"The r^2-value is: {rvalue**2}")
    plt.scatter(x_values[1],y_values[1], color="#A345F5", marker = "+")
    plt.plot(x_values[1],regress_values,color="#FF8800")
    plt.annotate(line_eq,(x_quantile, y_quantile),fontsize=18,color="black",weight="bold")
    plt.title(f"{x_values[0]} vs {y_values[0]}")
    plt.xlabel(x_values[0])
    plt.ylabel(y_values[0])
    plt.show()

# %%
# search base URL
base_url = f"https://mc-api.marketcheck.com/v2/popular/cars?api_key={car_key}&car_type=new&country=us"


response = requests.get(base_url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "count": 147239,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 23,
#             "iqr": 21,
#             "listings_count": 0,
#             "max": 1678,
#             "mean": 30,
#             "median": 25,
#             "min": 1,
#             "population_standard_deviation": 29,
#             "standard_deviation": 29,
#             "trimmed_mean": 26,
#             "variance": 830
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 38357,
#             "max": 504639,
#             "mean": 115,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3344,
#             "standard_deviation": 3344,
#             "trimmed_mean": 6,
#             "variance": 11181495
#         },
#         "model": "RAV4",
#         "price_stats": {
#             "geometric_mean": 37486,
#             "iqr": 6027,
#             "listings_count": 140741,
#             "max": 63313,
#             "mean": 37796,
#             "median": 36894,
#             "min": 7995,
#             "population_standard_deviation": 4991,
#             "standard_deviation": 4991,
#             "trimmed_mean": 37290,
#             "variance": 24909423
#         }
#     },
#     {
#         "count": 114370,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 28,
#             "iqr": 33,
#             "listings_count": 0,
#             "max": 2151,
#             "mean": 41,
#             "median": 29,
#             "min": 1,
#             "population_standard_deviation": 48,
#             "standard_deviation": 48,
#             "trimmed_mean": 34,
#             "variance": 2346
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 82694,
#             "max": 466625,
#             "mean": 78,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2807,
#             "standard_deviation": 2807,
#             "trimmed_mean": 7,
#             "variance": 7878725
#         },
#         "model": "CR-V",
#         "price_stats": {
#             "geometric_mean": 37521,
#             "iqr": 4200,
#             "listings_count": 106827,
#             "max": 403550,
#             "mean": 37653,
#             "median": 37850,
#             "min": 5297,
#             "population_standard_deviation": 3298,
#             "standard_deviation": 3298,
#             "trimmed_mean": 37698,
#             "variance": 10878186
#         }
#     },
#     {
#         "count": 104913,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 69,
#             "iqr": 101,
#             "listings_count": 0,
#             "max": 1616,
#             "mean": 99,
#             "median": 78,
#             "min": 1,
#             "population_standard_deviation": 79,
#             "standard_deviation": 79,
#             "trimmed_mean": 89,
#             "variance": 6255
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 10,
#             "listings_count": 74583,
#             "max": 682594,
#             "mean": 305,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 4383,
#             "standard_deviation": 4383,
#             "trimmed_mean": 10,
#             "variance": 19212377
#         },
#         "model": "Silverado 1500",
#         "price_stats": {
#             "geometric_mean": 54238,
#             "iqr": 13615,
#             "listings_count": 102301,
#             "max": 1032750,
#             "mean": 55070,
#             "median": 54495,
#             "min": 5995,
#             "population_standard_deviation": 10535,
#             "standard_deviation": 10535,
#             "trimmed_mean": 54784,
#             "variance": 110989521
#         }
#     },
#     {
#         "count": 101915,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 55,
#             "iqr": 101,
#             "listings_count": 0,
#             "max": 2374,
#             "mean": 101,
#             "median": 63,
#             "min": 1,
#             "population_standard_deviation": 108,
#             "standard_deviation": 108,
#             "trimmed_mean": 80,
#             "variance": 11751
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 22,
#             "iqr": 45,
#             "listings_count": 58319,
#             "max": 234000,
#             "mean": 481,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 4039,
#             "standard_deviation": 4039,
#             "trimmed_mean": 51,
#             "variance": 16311529
#         },
#         "model": "F-150",
#         "price_stats": {
#             "geometric_mean": 58675,
#             "iqr": 16477,
#             "listings_count": 95885,
#             "max": 225000,
#             "mean": 60245,
#             "median": 57573,
#             "min": 6495,
#             "population_standard_deviation": 14830,
#             "standard_deviation": 14830,
#             "trimmed_mean": 58674,
#             "variance": 219917760
#         }
#     },
#     {
#         "count": 96011,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 20,
#             "iqr": 19,
#             "listings_count": 0,
#             "max": 909,
#             "mean": 28,
#             "median": 21,
#             "min": 1,
#             "population_standard_deviation": 31,
#             "standard_deviation": 31,
#             "trimmed_mean": 23,
#             "variance": 948
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 23382,
#             "max": 210066,
#             "mean": 147,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3127,
#             "standard_deviation": 3127,
#             "trimmed_mean": 6,
#             "variance": 9777053
#         },
#         "model": "Camry",
#         "price_stats": {
#             "geometric_mean": 34454,
#             "iqr": 5225,
#             "listings_count": 91901,
#             "max": 80350,
#             "mean": 34665,
#             "median": 34175,
#             "min": 5999,
#             "population_standard_deviation": 3848,
#             "standard_deviation": 3848,
#             "trimmed_mean": 34496,
#             "variance": 14807014
#         }
#     },
#     {
#         "count": 76723,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 30,
#             "iqr": 36,
#             "listings_count": 0,
#             "max": 2192,
#             "mean": 41,
#             "median": 37,
#             "min": 1,
#             "population_standard_deviation": 35,
#             "standard_deviation": 35,
#             "trimmed_mean": 38,
#             "variance": 1260
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 19045,
#             "max": 245021,
#             "mean": 118,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3072,
#             "standard_deviation": 3072,
#             "trimmed_mean": 6,
#             "variance": 9439185
#         },
#         "model": "Tacoma",
#         "price_stats": {
#             "geometric_mean": 46629,
#             "iqr": 7556,
#             "listings_count": 73580,
#             "max": 85865,
#             "mean": 46975,
#             "median": 46527,
#             "min": 11289,
#             "population_standard_deviation": 5750,
#             "standard_deviation": 5750,
#             "trimmed_mean": 46816,
#             "variance": 33067248
#         }
#     },
#     {
#         "count": 68050,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 37,
#             "iqr": 35,
#             "listings_count": 0,
#             "max": 1698,
#             "mean": 52,
#             "median": 37,
#             "min": 1,
#             "population_standard_deviation": 50,
#             "standard_deviation": 50,
#             "trimmed_mean": 42,
#             "variance": 2541
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 19589,
#             "max": 151148,
#             "mean": 111,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1881,
#             "standard_deviation": 1881,
#             "trimmed_mean": 6,
#             "variance": 3539698
#         },
#         "model": "Tundra",
#         "price_stats": {
#             "geometric_mean": 62544,
#             "iqr": 11012,
#             "listings_count": 65741,
#             "max": 324849,
#             "mean": 63022,
#             "median": 62641,
#             "min": 6950,
#             "population_standard_deviation": 7849,
#             "standard_deviation": 7849,
#             "trimmed_mean": 62735,
#             "variance": 61602769
#         }
#     },
#     {
#         "count": 67199,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 22,
#             "iqr": 18,
#             "listings_count": 0,
#             "max": 960,
#             "mean": 29,
#             "median": 25,
#             "min": 1,
#             "population_standard_deviation": 31,
#             "standard_deviation": 31,
#             "trimmed_mean": 25,
#             "variance": 949
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 7,
#             "listings_count": 15683,
#             "max": 188546,
#             "mean": 146,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3263,
#             "standard_deviation": 3263,
#             "trimmed_mean": 6,
#             "variance": 10646657
#         },
#         "model": "Corolla",
#         "price_stats": {
#             "geometric_mean": 25304,
#             "iqr": 2784,
#             "listings_count": 64459,
#             "max": 278478,
#             "mean": 25388,
#             "median": 24817,
#             "min": 9995,
#             "population_standard_deviation": 2311,
#             "standard_deviation": 2311,
#             "trimmed_mean": 25168,
#             "variance": 5338809
#         }
#     },
#     {
#         "count": 61216,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 30,
#             "iqr": 41,
#             "listings_count": 0,
#             "max": 903,
#             "mean": 44,
#             "median": 33,
#             "min": 1,
#             "population_standard_deviation": 38,
#             "standard_deviation": 38,
#             "trimmed_mean": 38,
#             "variance": 1462
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 40388,
#             "max": 926880,
#             "mean": 81,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 4953,
#             "standard_deviation": 4953,
#             "trimmed_mean": 7,
#             "variance": 24537132
#         },
#         "model": "Trax",
#         "price_stats": {
#             "geometric_mean": 24852,
#             "iqr": 2595,
#             "listings_count": 57642,
#             "max": 256230,
#             "mean": 24916,
#             "median": 24985,
#             "min": 9500,
#             "population_standard_deviation": 2148,
#             "standard_deviation": 2148,
#             "trimmed_mean": 24967,
#             "variance": 4615625
#         }
#     },
#     {
#         "count": 49754,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 52,
#             "iqr": 65,
#             "listings_count": 0,
#             "max": 1417,
#             "mean": 73,
#             "median": 56,
#             "min": 1,
#             "population_standard_deviation": 66,
#             "standard_deviation": 66,
#             "trimmed_mean": 63,
#             "variance": 4402
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 9,
#             "listings_count": 36008,
#             "max": 200020,
#             "mean": 176,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2170,
#             "standard_deviation": 2170,
#             "trimmed_mean": 12,
#             "variance": 4708202
#         },
#         "model": "Tucson",
#         "price_stats": {
#             "geometric_mean": 35024,
#             "iqr": 5737,
#             "listings_count": 48514,
#             "max": 345550,
#             "mean": 35260,
#             "median": 34735,
#             "min": 11018,
#             "population_standard_deviation": 4305,
#             "standard_deviation": 4305,
#             "trimmed_mean": 35135,
#             "variance": 18533646
#         }
#     },
#     {
#         "count": 49227,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 59,
#             "iqr": 67,
#             "listings_count": 0,
#             "max": 1129,
#             "mean": 82,
#             "median": 62,
#             "min": 1,
#             "population_standard_deviation": 72,
#             "standard_deviation": 72,
#             "trimmed_mean": 70,
#             "variance": 5239
#         },
#         "make": "GMC",
#         "miles_stats": {
#             "geometric_mean": 9,
#             "iqr": 8,
#             "listings_count": 34724,
#             "max": 590072,
#             "mean": 234,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 4075,
#             "standard_deviation": 4075,
#             "trimmed_mean": 10,
#             "variance": 16607960
#         },
#         "model": "Sierra 1500",
#         "price_stats": {
#             "geometric_mean": 59242,
#             "iqr": 14504,
#             "listings_count": 48091,
#             "max": 900060,
#             "mean": 60267,
#             "median": 60595,
#             "min": 8000,
#             "population_standard_deviation": 11361,
#             "standard_deviation": 11361,
#             "trimmed_mean": 60207,
#             "variance": 129065955
#         }
#     },
#     {
#         "count": 49152,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 26,
#             "iqr": 28,
#             "listings_count": 0,
#             "max": 2435,
#             "mean": 40,
#             "median": 27,
#             "min": 1,
#             "population_standard_deviation": 58,
#             "standard_deviation": 58,
#             "trimmed_mean": 31,
#             "variance": 3388
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 6,
#             "listings_count": 34390,
#             "max": 216283,
#             "mean": 96,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2428,
#             "standard_deviation": 2428,
#             "trimmed_mean": 7,
#             "variance": 5897234
#         },
#         "model": "Civic",
#         "price_stats": {
#             "geometric_mean": 27553,
#             "iqr": 1400,
#             "listings_count": 45851,
#             "max": 58045,
#             "mean": 27638,
#             "median": 27100,
#             "min": 5066,
#             "population_standard_deviation": 2145,
#             "standard_deviation": 2145,
#             "trimmed_mean": 27418,
#             "variance": 4600664
#         }
#     },
#     {
#         "count": 47897,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 61,
#             "iqr": 57,
#             "listings_count": 0,
#             "max": 1437,
#             "mean": 76,
#             "median": 63,
#             "min": 1,
#             "population_standard_deviation": 53,
#             "standard_deviation": 53,
#             "trimmed_mean": 69,
#             "variance": 2796
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 18678,
#             "max": 98000,
#             "mean": 104,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1825,
#             "standard_deviation": 1825,
#             "trimmed_mean": 6,
#             "variance": 3332415
#         },
#         "model": "Outback",
#         "price_stats": {
#             "geometric_mean": 38238,
#             "iqr": 6924,
#             "listings_count": 46753,
#             "max": 378044,
#             "mean": 38471,
#             "median": 38866,
#             "min": 5038,
#             "population_standard_deviation": 4416,
#             "standard_deviation": 4416,
#             "trimmed_mean": 38547,
#             "variance": 19497878
#         }
#     },
#     {
#         "count": 46374,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 49,
#             "iqr": 44,
#             "listings_count": 0,
#             "max": 1139,
#             "mean": 61,
#             "median": 49,
#             "min": 1,
#             "population_standard_deviation": 42,
#             "standard_deviation": 42,
#             "trimmed_mean": 55,
#             "variance": 1757
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 6,
#             "listings_count": 18330,
#             "max": 81113,
#             "mean": 57,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1302,
#             "standard_deviation": 1302,
#             "trimmed_mean": 5,
#             "variance": 1694607
#         },
#         "model": "Crosstrek",
#         "price_stats": {
#             "geometric_mean": 31942,
#             "iqr": 5077,
#             "listings_count": 45202,
#             "max": 362227,
#             "mean": 32108,
#             "median": 31992,
#             "min": 12500,
#             "population_standard_deviation": 3786,
#             "standard_deviation": 3786,
#             "trimmed_mean": 32152,
#             "variance": 14333833
#         }
#     },
#     {
#         "count": 45556,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 57,
#             "iqr": 70,
#             "listings_count": 0,
#             "max": 1571,
#             "mean": 79,
#             "median": 67,
#             "min": 1,
#             "population_standard_deviation": 61,
#             "standard_deviation": 61,
#             "trimmed_mean": 72,
#             "variance": 3725
#         },
#         "make": "Nissan",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 5,
#             "listings_count": 31434,
#             "max": 563785,
#             "mean": 147,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 4885,
#             "standard_deviation": 4885,
#             "trimmed_mean": 7,
#             "variance": 23861084
#         },
#         "model": "Rogue",
#         "price_stats": {
#             "geometric_mean": 34325,
#             "iqr": 4659,
#             "listings_count": 44089,
#             "max": 66750,
#             "mean": 34563,
#             "median": 34274,
#             "min": 6980,
#             "population_standard_deviation": 4063,
#             "standard_deviation": 4063,
#             "trimmed_mean": 34393,
#             "variance": 16511395
#         }
#     },
#     {
#         "count": 44889,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 24,
#             "iqr": 24,
#             "listings_count": 0,
#             "max": 388,
#             "mean": 31,
#             "median": 26,
#             "min": 1,
#             "population_standard_deviation": 23,
#             "standard_deviation": 23,
#             "trimmed_mean": 29,
#             "variance": 509
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 9533,
#             "max": 35302,
#             "mean": 62,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 750,
#             "standard_deviation": 750,
#             "trimmed_mean": 6,
#             "variance": 561823
#         },
#         "model": "Grand Highlander",
#         "price_stats": {
#             "geometric_mean": 53500,
#             "iqr": 7801,
#             "listings_count": 43062,
#             "max": 83988,
#             "mean": 53703,
#             "median": 54768,
#             "min": 34787,
#             "population_standard_deviation": 4650,
#             "standard_deviation": 4650,
#             "trimmed_mean": 53691,
#             "variance": 21623403
#         }
#     },
#     {
#         "count": 44292,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 39,
#             "iqr": 55,
#             "listings_count": 0,
#             "max": 2057,
#             "mean": 60,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 70,
#             "standard_deviation": 70,
#             "trimmed_mean": 49,
#             "variance": 4852
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 31805,
#             "max": 364020,
#             "mean": 135,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3401,
#             "standard_deviation": 3401,
#             "trimmed_mean": 7,
#             "variance": 11564592
#         },
#         "model": "Accord",
#         "price_stats": {
#             "geometric_mean": 33089,
#             "iqr": 4793,
#             "listings_count": 41838,
#             "max": 55428,
#             "mean": 33276,
#             "median": 32497,
#             "min": 5697,
#             "population_standard_deviation": 3556,
#             "standard_deviation": 3556,
#             "trimmed_mean": 32986,
#             "variance": 12643092
#         }
#     },
#     {
#         "count": 43494,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 33,
#             "iqr": 54,
#             "listings_count": 0,
#             "max": 1482,
#             "mean": 53,
#             "median": 37,
#             "min": 1,
#             "population_standard_deviation": 53,
#             "standard_deviation": 53,
#             "trimmed_mean": 44,
#             "variance": 2861
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 8,
#             "listings_count": 32815,
#             "max": 215915,
#             "mean": 102,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1981,
#             "standard_deviation": 1981,
#             "trimmed_mean": 10,
#             "variance": 3923203
#         },
#         "model": "Sportage",
#         "price_stats": {
#             "geometric_mean": 34849,
#             "iqr": 5262,
#             "listings_count": 42364,
#             "max": 750202,
#             "mean": 35152,
#             "median": 34840,
#             "min": 6500,
#             "population_standard_deviation": 7933,
#             "standard_deviation": 7933,
#             "trimmed_mean": 34746,
#             "variance": 62928386
#         }
#     },
#     {
#         "count": 42897,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 45,
#             "iqr": 38,
#             "listings_count": 0,
#             "max": 1641,
#             "mean": 57,
#             "median": 50,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 52,
#             "variance": 2739
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 30902,
#             "max": 298386,
#             "mean": 72,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 2270,
#             "standard_deviation": 2270,
#             "trimmed_mean": 7,
#             "variance": 5151215
#         },
#         "model": "HR-V",
#         "price_stats": {
#             "geometric_mean": 29112,
#             "iqr": 2555,
#             "listings_count": 40617,
#             "max": 162185,
#             "mean": 29186,
#             "median": 29025,
#             "min": 5041,
#             "population_standard_deviation": 2070,
#             "standard_deviation": 2070,
#             "trimmed_mean": 29163,
#             "variance": 4284309
#         }
#     },
#     {
#         "count": 42163,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 25,
#             "iqr": 18,
#             "listings_count": 0,
#             "max": 654,
#             "mean": 30,
#             "median": 27,
#             "min": 1,
#             "population_standard_deviation": 23,
#             "standard_deviation": 23,
#             "trimmed_mean": 28,
#             "variance": 518
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 7,
#             "listings_count": 10127,
#             "max": 38196,
#             "mean": 27,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 504,
#             "standard_deviation": 504,
#             "trimmed_mean": 6,
#             "variance": 254054
#         },
#         "model": "Corolla Cross",
#         "price_stats": {
#             "geometric_mean": 31499,
#             "iqr": 4406,
#             "listings_count": 40242,
#             "max": 49710,
#             "mean": 31651,
#             "median": 31961,
#             "min": 21210,
#             "population_standard_deviation": 3078,
#             "standard_deviation": 3078,
#             "trimmed_mean": 31709,
#             "variance": 9472846
#         }
#     },
#     {
#         "count": 40874,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 94,
#             "iqr": 88,
#             "listings_count": 0,
#             "max": 2185,
#             "mean": 126,
#             "median": 111,
#             "min": 1,
#             "population_standard_deviation": 95,
#             "standard_deviation": 95,
#             "trimmed_mean": 114,
#             "variance": 8968
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 34,
#             "iqr": 391,
#             "listings_count": 23830,
#             "max": 333333,
#             "mean": 677,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 4220,
#             "standard_deviation": 4220,
#             "trimmed_mean": 207,
#             "variance": 17806223
#         },
#         "model": "Explorer",
#         "price_stats": {
#             "geometric_mean": 48620,
#             "iqr": 8845,
#             "listings_count": 39107,
#             "max": 81806,
#             "mean": 49092,
#             "median": 48380,
#             "min": 5762,
#             "population_standard_deviation": 6778,
#             "standard_deviation": 6778,
#             "trimmed_mean": 48879,
#             "variance": 45946261
#         }
#     },
#     {
#         "count": 40749,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 38,
#             "iqr": 45,
#             "listings_count": 0,
#             "max": 1657,
#             "mean": 53,
#             "median": 42,
#             "min": 1,
#             "population_standard_deviation": 60,
#             "standard_deviation": 60,
#             "trimmed_mean": 46,
#             "variance": 3562
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 29923,
#             "max": 182056,
#             "mean": 113,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 2396,
#             "standard_deviation": 2396,
#             "trimmed_mean": 7,
#             "variance": 5741853
#         },
#         "model": "Pilot",
#         "price_stats": {
#             "geometric_mean": 49534,
#             "iqr": 5980,
#             "listings_count": 38576,
#             "max": 571365,
#             "mean": 49745,
#             "median": 50495,
#             "min": 5039,
#             "population_standard_deviation": 4991,
#             "standard_deviation": 4991,
#             "trimmed_mean": 49789,
#             "variance": 24905645
#         }
#     },
#     {
#         "count": 39384,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 49,
#             "iqr": 57,
#             "listings_count": 0,
#             "max": 474,
#             "mean": 66,
#             "median": 48,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 59,
#             "variance": 2695
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 8,
#             "listings_count": 15710,
#             "max": 117485,
#             "mean": 126,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2369,
#             "standard_deviation": 2369,
#             "trimmed_mean": 6,
#             "variance": 5611769
#         },
#         "model": "Forester",
#         "price_stats": {
#             "geometric_mean": 35779,
#             "iqr": 5005,
#             "listings_count": 38394,
#             "max": 47446,
#             "mean": 35939,
#             "median": 35782,
#             "min": 11995,
#             "population_standard_deviation": 3357,
#             "standard_deviation": 3357,
#             "trimmed_mean": 35979,
#             "variance": 11270295
#         }
#     },
#     {
#         "count": 39304,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 55,
#             "iqr": 60,
#             "listings_count": 0,
#             "max": 1604,
#             "mean": 77,
#             "median": 54,
#             "min": 1,
#             "population_standard_deviation": 69,
#             "standard_deviation": 69,
#             "trimmed_mean": 65,
#             "variance": 4785
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 26011,
#             "max": 253655,
#             "mean": 321,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 3450,
#             "standard_deviation": 3450,
#             "trimmed_mean": 13,
#             "variance": 11905765
#         },
#         "model": "Equinox",
#         "price_stats": {
#             "geometric_mean": 30531,
#             "iqr": 4435,
#             "listings_count": 38311,
#             "max": 902600,
#             "mean": 30778,
#             "median": 30775,
#             "min": 5299,
#             "population_standard_deviation": 5776,
#             "standard_deviation": 5776,
#             "trimmed_mean": 30743,
#             "variance": 33360382
#         }
#     },
#     {
#         "count": 38245,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 57,
#             "iqr": 66,
#             "listings_count": 0,
#             "max": 2557,
#             "mean": 77,
#             "median": 61,
#             "min": 1,
#             "population_standard_deviation": 70,
#             "standard_deviation": 70,
#             "trimmed_mean": 69,
#             "variance": 4841
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 11,
#             "iqr": 7,
#             "listings_count": 27754,
#             "max": 354451,
#             "mean": 136,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2722,
#             "standard_deviation": 2722,
#             "trimmed_mean": 11,
#             "variance": 7410449
#         },
#         "model": "Elantra",
#         "price_stats": {
#             "geometric_mean": 25808,
#             "iqr": 3214,
#             "listings_count": 37354,
#             "max": 54530,
#             "mean": 25958,
#             "median": 25295,
#             "min": 9598,
#             "population_standard_deviation": 2902,
#             "standard_deviation": 2902,
#             "trimmed_mean": 25632,
#             "variance": 8419463
#         }
#     },
#     {
#         "count": 38057,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 75,
#             "iqr": 88,
#             "listings_count": 0,
#             "max": 1418,
#             "mean": 101,
#             "median": 91,
#             "min": 1,
#             "population_standard_deviation": 67,
#             "standard_deviation": 67,
#             "trimmed_mean": 95,
#             "variance": 4471
#         },
#         "make": "Nissan",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 5,
#             "listings_count": 27488,
#             "max": 991390,
#             "mean": 121,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 6523,
#             "standard_deviation": 6523,
#             "trimmed_mean": 8,
#             "variance": 42554909
#         },
#         "model": "Sentra",
#         "price_stats": {
#             "geometric_mean": 23259,
#             "iqr": 2822,
#             "listings_count": 36997,
#             "max": 37320,
#             "mean": 23378,
#             "median": 23220,
#             "min": 6000,
#             "population_standard_deviation": 2362,
#             "standard_deviation": 2362,
#             "trimmed_mean": 23297,
#             "variance": 5578097
#         }
#     },
#     {
#         "count": 37739,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 92,
#             "iqr": 81,
#             "listings_count": 0,
#             "max": 1212,
#             "mean": 112,
#             "median": 97,
#             "min": 1,
#             "population_standard_deviation": 65,
#             "standard_deviation": 65,
#             "trimmed_mean": 105,
#             "variance": 4259
#         },
#         "make": "Mazda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 26959,
#             "max": 76202,
#             "mean": 81,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1350,
#             "standard_deviation": 1350,
#             "trimmed_mean": 7,
#             "variance": 1821783
#         },
#         "model": "CX-5",
#         "price_stats": {
#             "geometric_mean": 33379,
#             "iqr": 3501,
#             "listings_count": 37040,
#             "max": 51006,
#             "mean": 33528,
#             "median": 32755,
#             "min": 14500,
#             "population_standard_deviation": 3246,
#             "standard_deviation": 3246,
#             "trimmed_mean": 33168,
#             "variance": 10536743
#         }
#     },
#     {
#         "count": 35877,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 75,
#             "iqr": 94,
#             "listings_count": 0,
#             "max": 1116,
#             "mean": 102,
#             "median": 81,
#             "min": 1,
#             "population_standard_deviation": 75,
#             "standard_deviation": 75,
#             "trimmed_mean": 92,
#             "variance": 5692
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 25,
#             "iqr": 33,
#             "listings_count": 21209,
#             "max": 119273,
#             "mean": 419,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 1799,
#             "standard_deviation": 1799,
#             "trimmed_mean": 97,
#             "variance": 3235349
#         },
#         "model": "Bronco Sport",
#         "price_stats": {
#             "geometric_mean": 33609,
#             "iqr": 5184,
#             "listings_count": 34678,
#             "max": 67499,
#             "mean": 33831,
#             "median": 33345,
#             "min": 5500,
#             "population_standard_deviation": 3913,
#             "standard_deviation": 3913,
#             "trimmed_mean": 33642,
#             "variance": 15307862
#         }
#     },
#     {
#         "count": 35142,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 23,
#             "iqr": 20,
#             "listings_count": 0,
#             "max": 1432,
#             "mean": 33,
#             "median": 25,
#             "min": 1,
#             "population_standard_deviation": 42,
#             "standard_deviation": 42,
#             "trimmed_mean": 26,
#             "variance": 1743
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 8849,
#             "max": 743210,
#             "mean": 396,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 8896,
#             "standard_deviation": 8896,
#             "trimmed_mean": 6,
#             "variance": 79143920
#         },
#         "model": "Highlander",
#         "price_stats": {
#             "geometric_mean": 48259,
#             "iqr": 5530,
#             "listings_count": 33652,
#             "max": 86572,
#             "mean": 48430,
#             "median": 47555,
#             "min": 7990,
#             "population_standard_deviation": 4028,
#             "standard_deviation": 4028,
#             "trimmed_mean": 48344,
#             "variance": 16223500
#         }
#     },
#     {
#         "count": 34610,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 30,
#             "iqr": 46,
#             "listings_count": 0,
#             "max": 1168,
#             "mean": 48,
#             "median": 33,
#             "min": 1,
#             "population_standard_deviation": 48,
#             "standard_deviation": 48,
#             "trimmed_mean": 39,
#             "variance": 2295
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 26051,
#             "max": 101499,
#             "mean": 95,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1432,
#             "standard_deviation": 1432,
#             "trimmed_mean": 10,
#             "variance": 2050992
#         },
#         "model": "Forte",
#         "price_stats": {
#             "geometric_mean": 22660,
#             "iqr": 3045,
#             "listings_count": 33643,
#             "max": 750202,
#             "mean": 22802,
#             "median": 22145,
#             "min": 6995,
#             "population_standard_deviation": 5240,
#             "standard_deviation": 5240,
#             "trimmed_mean": 22588,
#             "variance": 27454305
#         }
#     },
#     {
#         "count": 34246,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 112,
#             "iqr": 145,
#             "listings_count": 0,
#             "max": 2199,
#             "mean": 153,
#             "median": 125,
#             "min": 1,
#             "population_standard_deviation": 115,
#             "standard_deviation": 115,
#             "trimmed_mean": 138,
#             "variance": 13199
#         },
#         "make": "RAM",
#         "miles_stats": {
#             "geometric_mean": 20,
#             "iqr": 21,
#             "listings_count": 20156,
#             "max": 157454,
#             "mean": 415,
#             "median": 14,
#             "min": 1,
#             "population_standard_deviation": 3561,
#             "standard_deviation": 3561,
#             "trimmed_mean": 25,
#             "variance": 12677316
#         },
#         "model": "Ram 1500 Pickup",
#         "price_stats": {
#             "geometric_mean": 59601,
#             "iqr": 13920,
#             "listings_count": 33114,
#             "max": 189740,
#             "mean": 61063,
#             "median": 59090,
#             "min": 5500,
#             "population_standard_deviation": 14696,
#             "standard_deviation": 14696,
#             "trimmed_mean": 59425,
#             "variance": 215984195
#         }
#     },
#     {
#         "count": 33152,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 21,
#             "iqr": 41,
#             "listings_count": 0,
#             "max": 778,
#             "mean": 38,
#             "median": 30,
#             "min": 1,
#             "population_standard_deviation": 39,
#             "standard_deviation": 39,
#             "trimmed_mean": 32,
#             "variance": 1486
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 11,
#             "iqr": 15,
#             "listings_count": 17929,
#             "max": 63695,
#             "mean": 48,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 868,
#             "standard_deviation": 868,
#             "trimmed_mean": 13,
#             "variance": 753965
#         },
#         "model": "Maverick",
#         "price_stats": {
#             "geometric_mean": 32099,
#             "iqr": 7355,
#             "listings_count": 30680,
#             "max": 500202,
#             "mean": 32438,
#             "median": 31830,
#             "min": 22470,
#             "population_standard_deviation": 6129,
#             "standard_deviation": 6129,
#             "trimmed_mean": 32101,
#             "variance": 37569257
#         }
#     },
#     {
#         "count": 33088,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 35,
#             "iqr": 42,
#             "listings_count": 0,
#             "max": 1718,
#             "mean": 54,
#             "median": 36,
#             "min": 1,
#             "population_standard_deviation": 73,
#             "standard_deviation": 73,
#             "trimmed_mean": 42,
#             "variance": 5383
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 13,
#             "iqr": 10,
#             "listings_count": 23730,
#             "max": 999999,
#             "mean": 295,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 8364,
#             "standard_deviation": 8364,
#             "trimmed_mean": 13,
#             "variance": 69949854
#         },
#         "model": "Santa Fe",
#         "price_stats": {
#             "geometric_mean": 43555,
#             "iqr": 9061,
#             "listings_count": 32232,
#             "max": 335505,
#             "mean": 43877,
#             "median": 44955,
#             "min": 9474,
#             "population_standard_deviation": 5398,
#             "standard_deviation": 5398,
#             "trimmed_mean": 44058,
#             "variance": 29141321
#         }
#     },
#     {
#         "count": 32964,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 48,
#             "iqr": 68,
#             "listings_count": 0,
#             "max": 1243,
#             "mean": 70,
#             "median": 53,
#             "min": 1,
#             "population_standard_deviation": 58,
#             "standard_deviation": 58,
#             "trimmed_mean": 61,
#             "variance": 3315
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 8,
#             "iqr": 8,
#             "listings_count": 23016,
#             "max": 141543,
#             "mean": 111,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 1582,
#             "standard_deviation": 1582,
#             "trimmed_mean": 9,
#             "variance": 2501615
#         },
#         "model": "TrailBlazer",
#         "price_stats": {
#             "geometric_mean": 28296,
#             "iqr": 4141,
#             "listings_count": 32017,
#             "max": 304400,
#             "mean": 28444,
#             "median": 28290,
#             "min": 15999,
#             "population_standard_deviation": 3239,
#             "standard_deviation": 3239,
#             "trimmed_mean": 28348,
#             "variance": 10489119
#         }
#     },
#     {
#         "count": 32723,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 44,
#             "iqr": 66,
#             "listings_count": 0,
#             "max": 2575,
#             "mean": 71,
#             "median": 49,
#             "min": 1,
#             "population_standard_deviation": 75,
#             "standard_deviation": 75,
#             "trimmed_mean": 58,
#             "variance": 5599
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 22484,
#             "max": 649112,
#             "mean": 141,
#             "median": 7,
#             "min": 1,
#             "population_standard_deviation": 4872,
#             "standard_deviation": 4872,
#             "trimmed_mean": 11,
#             "variance": 23734378
#         },
#         "model": "Silverado 2500HD",
#         "price_stats": {
#             "geometric_mean": 64907,
#             "iqr": 18505,
#             "listings_count": 31543,
#             "max": 120037,
#             "mean": 65943,
#             "median": 64135,
#             "min": 20000,
#             "population_standard_deviation": 11911,
#             "standard_deviation": 11911,
#             "trimmed_mean": 65150,
#             "variance": 141879393
#         }
#     },
#     {
#         "count": 32455,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 69,
#             "iqr": 105,
#             "listings_count": 0,
#             "max": 2444,
#             "mean": 105,
#             "median": 77,
#             "min": 1,
#             "population_standard_deviation": 96,
#             "standard_deviation": 96,
#             "trimmed_mean": 91,
#             "variance": 9309
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 25,
#             "iqr": 146,
#             "listings_count": 18444,
#             "max": 156017,
#             "mean": 726,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 4482,
#             "standard_deviation": 4482,
#             "trimmed_mean": 172,
#             "variance": 20085317
#         },
#         "model": "Escape",
#         "price_stats": {
#             "geometric_mean": 33734,
#             "iqr": 4637,
#             "listings_count": 31043,
#             "max": 1000202,
#             "mean": 34035,
#             "median": 33225,
#             "min": 5500,
#             "population_standard_deviation": 6989,
#             "standard_deviation": 6989,
#             "trimmed_mean": 33667,
#             "variance": 48843558
#         }
#     },
#     {
#         "count": 32127,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 81,
#             "iqr": 133,
#             "listings_count": 0,
#             "max": 2334,
#             "mean": 124,
#             "median": 87,
#             "min": 1,
#             "population_standard_deviation": 114,
#             "standard_deviation": 114,
#             "trimmed_mean": 105,
#             "variance": 13041
#         },
#         "make": "Jeep",
#         "miles_stats": {
#             "geometric_mean": 19,
#             "iqr": 18,
#             "listings_count": 19333,
#             "max": 144269,
#             "mean": 332,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 2621,
#             "standard_deviation": 2621,
#             "trimmed_mean": 25,
#             "variance": 6868312
#         },
#         "model": "Grand Cherokee",
#         "price_stats": {
#             "geometric_mean": 50458,
#             "iqr": 11049,
#             "listings_count": 31271,
#             "max": 95937,
#             "mean": 51202,
#             "median": 49378,
#             "min": 12990,
#             "population_standard_deviation": 8943,
#             "standard_deviation": 8943,
#             "trimmed_mean": 50526,
#             "variance": 79985149
#         }
#     },
#     {
#         "count": 31807,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 46,
#             "iqr": 86,
#             "listings_count": 0,
#             "max": 2607,
#             "mean": 85,
#             "median": 60,
#             "min": 1,
#             "population_standard_deviation": 95,
#             "standard_deviation": 95,
#             "trimmed_mean": 69,
#             "variance": 9047
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 17,
#             "listings_count": 17544,
#             "max": 215052,
#             "mean": 204,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 3717,
#             "standard_deviation": 3717,
#             "trimmed_mean": 16,
#             "variance": 13818034
#         },
#         "model": "F-250 Super Duty",
#         "price_stats": {
#             "geometric_mean": 70542,
#             "iqr": 28752,
#             "listings_count": 29746,
#             "max": 198835,
#             "mean": 72501,
#             "median": 69940,
#             "min": 19995,
#             "population_standard_deviation": 17247,
#             "standard_deviation": 17247,
#             "trimmed_mean": 71709,
#             "variance": 297454439
#         }
#     },
#     {
#         "count": 31120,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 30,
#             "iqr": 44,
#             "listings_count": 0,
#             "max": 648,
#             "mean": 47,
#             "median": 33,
#             "min": 1,
#             "population_standard_deviation": 47,
#             "standard_deviation": 47,
#             "trimmed_mean": 39,
#             "variance": 2179
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 23691,
#             "max": 668000,
#             "mean": 97,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 4450,
#             "standard_deviation": 4450,
#             "trimmed_mean": 10,
#             "variance": 19802892
#         },
#         "model": "Telluride",
#         "price_stats": {
#             "geometric_mean": 47493,
#             "iqr": 9270,
#             "listings_count": 30398,
#             "max": 68995,
#             "mean": 47791,
#             "median": 48198,
#             "min": 30944,
#             "population_standard_deviation": 5286,
#             "standard_deviation": 5286,
#             "trimmed_mean": 47897,
#             "variance": 27936513
#         }
#     },
#     {
#         "count": 28824,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 62,
#             "iqr": 69,
#             "listings_count": 0,
#             "max": 1080,
#             "mean": 83,
#             "median": 69,
#             "min": 1,
#             "population_standard_deviation": 58,
#             "standard_deviation": 58,
#             "trimmed_mean": 76,
#             "variance": 3397
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 8,
#             "listings_count": 21117,
#             "max": 53610,
#             "mean": 88,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 1072,
#             "standard_deviation": 1072,
#             "trimmed_mean": 12,
#             "variance": 1149749
#         },
#         "model": "Palisade",
#         "price_stats": {
#             "geometric_mean": 49602,
#             "iqr": 6925,
#             "listings_count": 28201,
#             "max": 595725,
#             "mean": 49819,
#             "median": 50416,
#             "min": 25238,
#             "population_standard_deviation": 5488,
#             "standard_deviation": 5488,
#             "trimmed_mean": 50016,
#             "variance": 30119529
#         }
#     },
#     {
#         "count": 28249,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 36,
#             "iqr": 46,
#             "listings_count": 0,
#             "max": 1506,
#             "mean": 51,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 45,
#             "standard_deviation": 45,
#             "trimmed_mean": 45,
#             "variance": 1997
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 7,
#             "listings_count": 19045,
#             "max": 954659,
#             "mean": 159,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 7589,
#             "standard_deviation": 7589,
#             "trimmed_mean": 8,
#             "variance": 57591006
#         },
#         "model": "Colorado",
#         "price_stats": {
#             "geometric_mean": 41660,
#             "iqr": 8065,
#             "listings_count": 27375,
#             "max": 77010,
#             "mean": 42118,
#             "median": 42100,
#             "min": 7995,
#             "population_standard_deviation": 6234,
#             "standard_deviation": 6234,
#             "trimmed_mean": 41976,
#             "variance": 38864556
#         }
#     },
#     {
#         "count": 27986,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 20,
#             "iqr": 24,
#             "listings_count": 0,
#             "max": 1241,
#             "mean": 32,
#             "median": 22,
#             "min": 1,
#             "population_standard_deviation": 47,
#             "standard_deviation": 47,
#             "trimmed_mean": 24,
#             "variance": 2166
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 7,
#             "listings_count": 16635,
#             "max": 901536,
#             "mean": 273,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 9104,
#             "standard_deviation": 9104,
#             "trimmed_mean": 7,
#             "variance": 82879102
#         },
#         "model": "Traverse",
#         "price_stats": {
#             "geometric_mean": 47680,
#             "iqr": 11655,
#             "listings_count": 27192,
#             "max": 93305,
#             "mean": 48138,
#             "median": 47795,
#             "min": 5995,
#             "population_standard_deviation": 6661,
#             "standard_deviation": 6661,
#             "trimmed_mean": 48013,
#             "variance": 44364845
#         }
#     },
#     {
#         "count": 26399,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 41,
#             "iqr": 40,
#             "listings_count": 0,
#             "max": 1406,
#             "mean": 56,
#             "median": 45,
#             "min": 1,
#             "population_standard_deviation": 50,
#             "standard_deviation": 50,
#             "trimmed_mean": 48,
#             "variance": 2485
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 9332,
#             "max": 115990,
#             "mean": 172,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2960,
#             "standard_deviation": 2960,
#             "trimmed_mean": 6,
#             "variance": 8759683
#         },
#         "model": "4Runner",
#         "price_stats": {
#             "geometric_mean": 50910,
#             "iqr": 5515,
#             "listings_count": 25214,
#             "max": 85600,
#             "mean": 51092,
#             "median": 50934,
#             "min": 5084,
#             "population_standard_deviation": 4249,
#             "standard_deviation": 4249,
#             "trimmed_mean": 51030,
#             "variance": 18053757
#         }
#     },
#     {
#         "count": 25225,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 60,
#             "iqr": 96,
#             "listings_count": 0,
#             "max": 909,
#             "mean": 93,
#             "median": 68,
#             "min": 1,
#             "population_standard_deviation": 80,
#             "standard_deviation": 80,
#             "trimmed_mean": 81,
#             "variance": 6413
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 13,
#             "iqr": 21,
#             "listings_count": 14047,
#             "max": 83642,
#             "mean": 129,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1427,
#             "standard_deviation": 1427,
#             "trimmed_mean": 17,
#             "variance": 2035788
#         },
#         "model": "Bronco 4-Door",
#         "price_stats": {
#             "geometric_mean": 59748,
#             "iqr": 14500,
#             "listings_count": 24056,
#             "max": 1094400,
#             "mean": 61270,
#             "median": 57840,
#             "min": 15240,
#             "population_standard_deviation": 16804,
#             "standard_deviation": 16804,
#             "trimmed_mean": 58921,
#             "variance": 282386872
#         }
#     },
#     {
#         "count": 24865,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 33,
#             "iqr": 30,
#             "listings_count": 0,
#             "max": 1839,
#             "mean": 50,
#             "median": 33,
#             "min": 1,
#             "population_standard_deviation": 72,
#             "standard_deviation": 72,
#             "trimmed_mean": 37,
#             "variance": 5129
#         },
#         "make": "Lexus",
#         "miles_stats": {
#             "geometric_mean": 9,
#             "iqr": 6,
#             "listings_count": 12629,
#             "max": 238851,
#             "mean": 1207,
#             "median": 7,
#             "min": 1,
#             "population_standard_deviation": 11390,
#             "standard_deviation": 11390,
#             "trimmed_mean": 8,
#             "variance": 129721268
#         },
#         "model": "RX",
#         "price_stats": {
#             "geometric_mean": 59004,
#             "iqr": 6980,
#             "listings_count": 24035,
#             "max": 125660,
#             "mean": 59336,
#             "median": 59540,
#             "min": 7497,
#             "population_standard_deviation": 5532,
#             "standard_deviation": 5532,
#             "trimmed_mean": 59439,
#             "variance": 30602651
#         }
#     },
#     {
#         "count": 24710,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 60,
#             "iqr": 59,
#             "listings_count": 0,
#             "max": 795,
#             "mean": 75,
#             "median": 61,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 68,
#             "variance": 2714
#         },
#         "make": "Mazda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 17829,
#             "max": 40113,
#             "mean": 42,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 548,
#             "standard_deviation": 548,
#             "trimmed_mean": 6,
#             "variance": 300343
#         },
#         "model": "CX-50",
#         "price_stats": {
#             "geometric_mean": 35470,
#             "iqr": 7300,
#             "listings_count": 24199,
#             "max": 61390,
#             "mean": 35784,
#             "median": 34125,
#             "min": 23999,
#             "population_standard_deviation": 4852,
#             "standard_deviation": 4852,
#             "trimmed_mean": 35403,
#             "variance": 23544131
#         }
#     },
#     {
#         "count": 24497,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 98,
#             "iqr": 144,
#             "listings_count": 0,
#             "max": 2305,
#             "mean": 142,
#             "median": 114,
#             "min": 1,
#             "population_standard_deviation": 107,
#             "standard_deviation": 107,
#             "trimmed_mean": 130,
#             "variance": 11528
#         },
#         "make": "RAM",
#         "miles_stats": {
#             "geometric_mean": 14,
#             "iqr": 12,
#             "listings_count": 13815,
#             "max": 289165,
#             "mean": 160,
#             "median": 13,
#             "min": 1,
#             "population_standard_deviation": 3222,
#             "standard_deviation": 3222,
#             "trimmed_mean": 15,
#             "variance": 10383486
#         },
#         "model": "Ram 2500 Pickup",
#         "price_stats": {
#             "geometric_mean": 65270,
#             "iqr": 17188,
#             "listings_count": 22526,
#             "max": 144541,
#             "mean": 66347,
#             "median": 65460,
#             "min": 5800,
#             "population_standard_deviation": 12077,
#             "standard_deviation": 12077,
#             "trimmed_mean": 65722,
#             "variance": 145846299
#         }
#     },
#     {
#         "count": 23679,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 94,
#             "iqr": 93,
#             "listings_count": 0,
#             "max": 904,
#             "mean": 116,
#             "median": 97,
#             "min": 1,
#             "population_standard_deviation": 70,
#             "standard_deviation": 70,
#             "trimmed_mean": 110,
#             "variance": 4933
#         },
#         "make": "Mazda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 7,
#             "listings_count": 16859,
#             "max": 121253,
#             "mean": 70,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 1234,
#             "standard_deviation": 1234,
#             "trimmed_mean": 7,
#             "variance": 1523560
#         },
#         "model": "CX-30",
#         "price_stats": {
#             "geometric_mean": 29574,
#             "iqr": 3650,
#             "listings_count": 23202,
#             "max": 47184,
#             "mean": 29719,
#             "median": 28920,
#             "min": 15949,
#             "population_standard_deviation": 3023,
#             "standard_deviation": 3023,
#             "trimmed_mean": 29367,
#             "variance": 9141407
#         }
#     },
#     {
#         "count": 23668,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 38,
#             "iqr": 61,
#             "listings_count": 0,
#             "max": 1448,
#             "mean": 61,
#             "median": 42,
#             "min": 1,
#             "population_standard_deviation": 65,
#             "standard_deviation": 65,
#             "trimmed_mean": 50,
#             "variance": 4189
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 18233,
#             "max": 140000,
#             "mean": 190,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2361,
#             "standard_deviation": 2361,
#             "trimmed_mean": 10,
#             "variance": 5575955
#         },
#         "model": "Sorento",
#         "price_stats": {
#             "geometric_mean": 40856,
#             "iqr": 6970,
#             "listings_count": 23110,
#             "max": 69425,
#             "mean": 41160,
#             "median": 40475,
#             "min": 8889,
#             "population_standard_deviation": 4997,
#             "standard_deviation": 4997,
#             "trimmed_mean": 41051,
#             "variance": 24971527
#         }
#     },
#     {
#         "count": 23592,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 90,
#             "iqr": 86,
#             "listings_count": 0,
#             "max": 2481,
#             "mean": 119,
#             "median": 87,
#             "min": 1,
#             "population_standard_deviation": 102,
#             "standard_deviation": 102,
#             "trimmed_mean": 101,
#             "variance": 10356
#         },
#         "make": "Jeep",
#         "miles_stats": {
#             "geometric_mean": 15,
#             "iqr": 10,
#             "listings_count": 14211,
#             "max": 203975,
#             "mean": 293,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 2827,
#             "standard_deviation": 2827,
#             "trimmed_mean": 15,
#             "variance": 7993453
#         },
#         "model": "Compass",
#         "price_stats": {
#             "geometric_mean": 33179,
#             "iqr": 5508,
#             "listings_count": 22994,
#             "max": 75203,
#             "mean": 33489,
#             "median": 34035,
#             "min": 5898,
#             "population_standard_deviation": 4480,
#             "standard_deviation": 4480,
#             "trimmed_mean": 33552,
#             "variance": 20072392
#         }
#     }
# ]

# %%
top50_df = pd.DataFrame(response)
top50_df
# df_expanded = pd.concat([top50_df.drop(['price_stats'], axis=1), top50_df['price_stats'].apply(pd.Series)], axis=1)
# df_expanded = pd.concat([top50_df.drop(['miles_stats'], axis=1), top50_df['miles_stats'].apply(pd.Series)], axis=1)
# df_expanded = pd.concat([top50_df.drop(['dom_stats'], axis=1), top50_df['dom_stats'].apply(pd.Series)], axis=1)

# top50_df = pd.DataFrame(data_dict)
# Out:
#    country   count       make             model  \
# 0       us  147239     Toyota              RAV4
# 1       us  114370      Honda              CR-V
# 2       us  104913  Chevrolet    Silverado 1500
# 3       us  101915       Ford             F-150
# 4       us   96011     Toyota             Camry
# 5       us   76723     Toyota            Tacoma
# 6       us   68050     Toyota            Tundra
# 7       us   67199     Toyota           Corolla
# 8       us   61216  Chevrolet              Trax
# 9       us   49754    Hyundai            Tucson
# 10      us   49227        GMC       Sierra 1500
# 11      us   49152      Honda             Civic
# 12      us   47897     Subaru           Outback
# 13      us   46374     Subaru         Crosstrek
# 14      us   45556     Nissan             Rogue
# 15      us   44889     Toyota  Grand Highlander
# 16      us   44292      Honda            Accord
# 17      us   43494        Kia          Sportage
# 18      us   42897      Honda              HR-V
# 19      us   42163     Toyota     Corolla Cross
# 20      us   40874       Ford          Explorer
# 21      us   40749      Honda             Pilot
# 22      us   39384     Subaru          Forester
# 23      us   39304  Chevrolet           Equinox
# 24      us   38245    Hyundai           Elantra
# 25      us   38057     Nissan            Sentra
# 26      us   37739      Mazda              CX-5
# 27      us   35877       Ford      Bronco Sport
# 28      us   35142     Toyota        Highlander
# 29      us   34610        Kia             Forte
# 30      us   34246        RAM   Ram 1500 Pickup
# 31      us   33152       Ford          Maverick
# 32      us   33088    Hyundai          Santa Fe
# 33      us   32964  Chevrolet       TrailBlazer
# 34      us   32723  Chevrolet  Silverado 2500HD
# 35      us   32455       Ford            Escape
# 36      us   32127       Jeep    Grand Cherokee
# 37      us   31807       Ford  F-250 Super Duty
# 38      us   31120        Kia         Telluride
# 39      us   28824    Hyundai          Palisade
# 40      us   28249  Chevrolet          Colorado
# 41      us   27986  Chevrolet          Traverse
# 42      us   26399     Toyota           4Runner
# 43      us   25225       Ford     Bronco 4-Door
# 44      us   24865      Lexus                RX
# 45      us   24710      Mazda             CX-50
# 46      us   24497        RAM   Ram 2500 Pickup
# 47      us   23679      Mazda             CX-30
# 48      us   23668        Kia           Sorento
# 49      us   23592       Jeep           Compass
#
#                                           price_stats  \
# 0   {'geometric_mean': 37486, 'listings_count': 14...
# 1   {'geometric_mean': 37521, 'listings_count': 10...
# 2   {'geometric_mean': 54238, 'listings_count': 10...
# 3   {'geometric_mean': 58675, 'listings_count': 95...
# 4   {'geometric_mean': 34454, 'listings_count': 91...
# 5   {'geometric_mean': 46629, 'listings_count': 73...
# 6   {'geometric_mean': 62544, 'listings_count': 65...
# 7   {'geometric_mean': 25304, 'listings_count': 64...
# 8   {'geometric_mean': 24852, 'listings_count': 57...
# 9   {'geometric_mean': 35024, 'listings_count': 48...
# 10  {'geometric_mean': 59242, 'listings_count': 48...
# 11  {'geometric_mean': 27553, 'listings_count': 45...
# 12  {'geometric_mean': 38238, 'listings_count': 46...
# 13  {'geometric_mean': 31942, 'listings_count': 45...
# 14  {'geometric_mean': 34325, 'listings_count': 44...
# 15  {'geometric_mean': 53500, 'listings_count': 43...
# 16  {'geometric_mean': 33089, 'listings_count': 41...
# 17  {'geometric_mean': 34849, 'listings_count': 42...
# 18  {'geometric_mean': 29112, 'listings_count': 40...
# 19  {'geometric_mean': 31499, 'listings_count': 40...
# 20  {'geometric_mean': 48620, 'listings_count': 39...
# 21  {'geometric_mean': 49534, 'listings_count': 38...
# 22  {'geometric_mean': 35779, 'listings_count': 38...
# 23  {'geometric_mean': 30531, 'listings_count': 38...
# 24  {'geometric_mean': 25808, 'listings_count': 37...
# 25  {'geometric_mean': 23259, 'listings_count': 36...
# 26  {'geometric_mean': 33379, 'listings_count': 37...
# 27  {'geometric_mean': 33609, 'listings_count': 34...
# 28  {'geometric_mean': 48259, 'listings_count': 33...
# 29  {'geometric_mean': 22660, 'listings_count': 33...
# 30  {'geometric_mean': 59601, 'listings_count': 33...
# 31  {'geometric_mean': 32099, 'listings_count': 30...
# 32  {'geometric_mean': 43555, 'listings_count': 32...
# 33  {'geometric_mean': 28296, 'listings_count': 32...
# 34  {'geometric_mean': 64907, 'listings_count': 31...
# 35  {'geometric_mean': 33734, 'listings_count': 31...
# 36  {'geometric_mean': 50458, 'listings_count': 31...
# 37  {'geometric_mean': 70542, 'listings_count': 29...
# 38  {'geometric_mean': 47493, 'listings_count': 30...
# 39  {'geometric_mean': 49602, 'listings_count': 28...
# 40  {'geometric_mean': 41660, 'listings_count': 27...
# 41  {'geometric_mean': 47680, 'listings_count': 27...
# 42  {'geometric_mean': 50910, 'listings_count': 25...
# 43  {'geometric_mean': 59748, 'listings_count': 24...
# 44  {'geometric_mean': 59004, 'listings_count': 24...
# 45  {'geometric_mean': 35470, 'listings_count': 24...
# 46  {'geometric_mean': 65270, 'listings_count': 22...
# 47  {'geometric_mean': 29574, 'listings_count': 23...
# 48  {'geometric_mean': 40856, 'listings_count': 23...
# 49  {'geometric_mean': 33179, 'listings_count': 22...
#
#                                           miles_stats  \
# 0   {'geometric_mean': 6, 'listings_count': 38357,...
# 1   {'geometric_mean': 7, 'listings_count': 82694,...
# 2   {'geometric_mean': 10, 'listings_count': 74583...
# 3   {'geometric_mean': 22, 'listings_count': 58319...
# 4   {'geometric_mean': 6, 'listings_count': 23382,...
# 5   {'geometric_mean': 6, 'listings_count': 19045,...
# 6   {'geometric_mean': 6, 'listings_count': 19589,...
# 7   {'geometric_mean': 5, 'listings_count': 15683,...
# 8   {'geometric_mean': 7, 'listings_count': 40388,...
# 9   {'geometric_mean': 12, 'listings_count': 36008...
# 10  {'geometric_mean': 9, 'listings_count': 34724,...
# 11  {'geometric_mean': 6, 'listings_count': 34390,...
# 12  {'geometric_mean': 6, 'listings_count': 18678,...
# 13  {'geometric_mean': 5, 'listings_count': 18330,...
# 14  {'geometric_mean': 7, 'listings_count': 31434,...
# 15  {'geometric_mean': 6, 'listings_count': 9533, ...
# 16  {'geometric_mean': 7, 'listings_count': 31805,...
# 17  {'geometric_mean': 10, 'listings_count': 32815...
# 18  {'geometric_mean': 7, 'listings_count': 30902,...
# 19  {'geometric_mean': 5, 'listings_count': 10127,...
# 20  {'geometric_mean': 34, 'listings_count': 23830...
# 21  {'geometric_mean': 7, 'listings_count': 29923,...
# 22  {'geometric_mean': 5, 'listings_count': 15710,...
# 23  {'geometric_mean': 10, 'listings_count': 26011...
# 24  {'geometric_mean': 11, 'listings_count': 27754...
# 25  {'geometric_mean': 7, 'listings_count': 27488,...
# 26  {'geometric_mean': 6, 'listings_count': 26959,...
# 27  {'geometric_mean': 25, 'listings_count': 21209...
# 28  {'geometric_mean': 6, 'listings_count': 8849, ...
# 29  {'geometric_mean': 10, 'listings_count': 26051...
# 30  {'geometric_mean': 20, 'listings_count': 20156...
# 31  {'geometric_mean': 11, 'listings_count': 17929...
# 32  {'geometric_mean': 13, 'listings_count': 23730...
# 33  {'geometric_mean': 8, 'listings_count': 23016,...
# 34  {'geometric_mean': 10, 'listings_count': 22484...
# 35  {'geometric_mean': 25, 'listings_count': 18444...
# 36  {'geometric_mean': 19, 'listings_count': 19333...
# 37  {'geometric_mean': 12, 'listings_count': 17544...
# 38  {'geometric_mean': 10, 'listings_count': 23691...
# 39  {'geometric_mean': 12, 'listings_count': 21117...
# 40  {'geometric_mean': 7, 'listings_count': 19045,...
# 41  {'geometric_mean': 7, 'listings_count': 16635,...
# 42  {'geometric_mean': 6, 'listings_count': 9332, ...
# 43  {'geometric_mean': 13, 'listings_count': 14047...
# 44  {'geometric_mean': 9, 'listings_count': 12629,...
# 45  {'geometric_mean': 6, 'listings_count': 17829,...
# 46  {'geometric_mean': 14, 'listings_count': 13815...
# 47  {'geometric_mean': 7, 'listings_count': 16859,...
# 48  {'geometric_mean': 10, 'listings_count': 18233...
# 49  {'geometric_mean': 15, 'listings_count': 14211...
#
#                                             dom_stats
# 0   {'geometric_mean': 23, 'listings_count': 0, 'm...
# 1   {'geometric_mean': 28, 'listings_count': 0, 'm...
# 2   {'geometric_mean': 69, 'listings_count': 0, 'm...
# 3   {'geometric_mean': 55, 'listings_count': 0, 'm...
# 4   {'geometric_mean': 20, 'listings_count': 0, 'm...
# 5   {'geometric_mean': 30, 'listings_count': 0, 'm...
# 6   {'geometric_mean': 37, 'listings_count': 0, 'm...
# 7   {'geometric_mean': 22, 'listings_count': 0, 'm...
# 8   {'geometric_mean': 30, 'listings_count': 0, 'm...
# 9   {'geometric_mean': 52, 'listings_count': 0, 'm...
# 10  {'geometric_mean': 59, 'listings_count': 0, 'm...
# 11  {'geometric_mean': 26, 'listings_count': 0, 'm...
# 12  {'geometric_mean': 61, 'listings_count': 0, 'm...
# 13  {'geometric_mean': 49, 'listings_count': 0, 'm...
# 14  {'geometric_mean': 57, 'listings_count': 0, 'm...
# 15  {'geometric_mean': 24, 'listings_count': 0, 'm...
# 16  {'geometric_mean': 39, 'listings_count': 0, 'm...
# 17  {'geometric_mean': 33, 'listings_count': 0, 'm...
# 18  {'geometric_mean': 45, 'listings_count': 0, 'm...
# 19  {'geometric_mean': 25, 'listings_count': 0, 'm...
# 20  {'geometric_mean': 94, 'listings_count': 0, 'm...
# 21  {'geometric_mean': 38, 'listings_count': 0, 'm...
# 22  {'geometric_mean': 49, 'listings_count': 0, 'm...
# 23  {'geometric_mean': 55, 'listings_count': 0, 'm...
# 24  {'geometric_mean': 57, 'listings_count': 0, 'm...
# 25  {'geometric_mean': 75, 'listings_count': 0, 'm...
# 26  {'geometric_mean': 92, 'listings_count': 0, 'm...
# 27  {'geometric_mean': 75, 'listings_count': 0, 'm...
# 28  {'geometric_mean': 23, 'listings_count': 0, 'm...
# 29  {'geometric_mean': 30, 'listings_count': 0, 'm...
# 30  {'geometric_mean': 112, 'listings_count': 0, '...
# 31  {'geometric_mean': 21, 'listings_count': 0, 'm...
# 32  {'geometric_mean': 35, 'listings_count': 0, 'm...
# 33  {'geometric_mean': 48, 'listings_count': 0, 'm...
# 34  {'geometric_mean': 44, 'listings_count': 0, 'm...
# 35  {'geometric_mean': 69, 'listings_count': 0, 'm...
# 36  {'geometric_mean': 81, 'listings_count': 0, 'm...
# 37  {'geometric_mean': 46, 'listings_count': 0, 'm...
# 38  {'geometric_mean': 30, 'listings_count': 0, 'm...
# 39  {'geometric_mean': 62, 'listings_count': 0, 'm...
# 40  {'geometric_mean': 36, 'listings_count': 0, 'm...
# 41  {'geometric_mean': 20, 'listings_count': 0, 'm...
# 42  {'geometric_mean': 41, 'listings_count': 0, 'm...
# 43  {'geometric_mean': 60, 'listings_count': 0, 'm...
# 44  {'geometric_mean': 33, 'listings_count': 0, 'm...
# 45  {'geometric_mean': 60, 'listings_count': 0, 'm...
# 46  {'geometric_mean': 98, 'listings_count': 0, 'm...
# 47  {'geometric_mean': 94, 'listings_count': 0, 'm...
# 48  {'geometric_mean': 38, 'listings_count': 0, 'm...
# 49  {'geometric_mean': 90, 'listings_count': 0, 'm...

# %%
df_expanded = pd.concat([top50_df.drop(['price_stats'], axis=1), top50_df['price_stats'].apply(pd.Series)], axis=1)
df_expanded = df_expanded.drop("miles_stats", axis=1)
df_expanded = df_expanded.drop("dom_stats", axis=1)
df_expanded
# Out:
#    country   count       make             model  geometric_mean  \
# 0       us  147239     Toyota              RAV4           37486
# 1       us  114370      Honda              CR-V           37521
# 2       us  104913  Chevrolet    Silverado 1500           54238
# 3       us  101915       Ford             F-150           58675
# 4       us   96011     Toyota             Camry           34454
# 5       us   76723     Toyota            Tacoma           46629
# 6       us   68050     Toyota            Tundra           62544
# 7       us   67199     Toyota           Corolla           25304
# 8       us   61216  Chevrolet              Trax           24852
# 9       us   49754    Hyundai            Tucson           35024
# 10      us   49227        GMC       Sierra 1500           59242
# 11      us   49152      Honda             Civic           27553
# 12      us   47897     Subaru           Outback           38238
# 13      us   46374     Subaru         Crosstrek           31942
# 14      us   45556     Nissan             Rogue           34325
# 15      us   44889     Toyota  Grand Highlander           53500
# 16      us   44292      Honda            Accord           33089
# 17      us   43494        Kia          Sportage           34849
# 18      us   42897      Honda              HR-V           29112
# 19      us   42163     Toyota     Corolla Cross           31499
# 20      us   40874       Ford          Explorer           48620
# 21      us   40749      Honda             Pilot           49534
# 22      us   39384     Subaru          Forester           35779
# 23      us   39304  Chevrolet           Equinox           30531
# 24      us   38245    Hyundai           Elantra           25808
# 25      us   38057     Nissan            Sentra           23259
# 26      us   37739      Mazda              CX-5           33379
# 27      us   35877       Ford      Bronco Sport           33609
# 28      us   35142     Toyota        Highlander           48259
# 29      us   34610        Kia             Forte           22660
# 30      us   34246        RAM   Ram 1500 Pickup           59601
# 31      us   33152       Ford          Maverick           32099
# 32      us   33088    Hyundai          Santa Fe           43555
# 33      us   32964  Chevrolet       TrailBlazer           28296
# 34      us   32723  Chevrolet  Silverado 2500HD           64907
# 35      us   32455       Ford            Escape           33734
# 36      us   32127       Jeep    Grand Cherokee           50458
# 37      us   31807       Ford  F-250 Super Duty           70542
# 38      us   31120        Kia         Telluride           47493
# 39      us   28824    Hyundai          Palisade           49602
# 40      us   28249  Chevrolet          Colorado           41660
# 41      us   27986  Chevrolet          Traverse           47680
# 42      us   26399     Toyota           4Runner           50910
# 43      us   25225       Ford     Bronco 4-Door           59748
# 44      us   24865      Lexus                RX           59004
# 45      us   24710      Mazda             CX-50           35470
# 46      us   24497        RAM   Ram 2500 Pickup           65270
# 47      us   23679      Mazda             CX-30           29574
# 48      us   23668        Kia           Sorento           40856
# 49      us   23592       Jeep           Compass           33179
#
#     listings_count    min  median  population_standard_deviation   variance  \
# 0           140741   7995   36894                           4991   24909423
# 1           106827   5297   37850                           3298   10878186
# 2           102301   5995   54495                          10535  110989521
# 3            95885   6495   57573                          14830  219917760
# 4            91901   5999   34175                           3848   14807014
# 5            73580  11289   46527                           5750   33067248
# 6            65741   6950   62641                           7849   61602769
# 7            64459   9995   24817                           2311    5338809
# 8            57642   9500   24985                           2148    4615625
# 9            48514  11018   34735                           4305   18533646
# 10           48091   8000   60595                          11361  129065955
# 11           45851   5066   27100                           2145    4600664
# 12           46753   5038   38866                           4416   19497878
# 13           45202  12500   31992                           3786   14333833
# 14           44089   6980   34274                           4063   16511395
# 15           43062  34787   54768                           4650   21623403
# 16           41838   5697   32497                           3556   12643092
# 17           42364   6500   34840                           7933   62928386
# 18           40617   5041   29025                           2070    4284309
# 19           40242  21210   31961                           3078    9472846
# 20           39107   5762   48380                           6778   45946261
# 21           38576   5039   50495                           4991   24905645
# 22           38394  11995   35782                           3357   11270295
# 23           38311   5299   30775                           5776   33360382
# 24           37354   9598   25295                           2902    8419463
# 25           36997   6000   23220                           2362    5578097
# 26           37040  14500   32755                           3246   10536743
# 27           34678   5500   33345                           3913   15307862
# 28           33652   7990   47555                           4028   16223500
# 29           33643   6995   22145                           5240   27454305
# 30           33114   5500   59090                          14696  215984195
# 31           30680  22470   31830                           6129   37569257
# 32           32232   9474   44955                           5398   29141321
# 33           32017  15999   28290                           3239   10489119
# 34           31543  20000   64135                          11911  141879393
# 35           31043   5500   33225                           6989   48843558
# 36           31271  12990   49378                           8943   79985149
# 37           29746  19995   69940                          17247  297454439
# 38           30398  30944   48198                           5286   27936513
# 39           28201  25238   50416                           5488   30119529
# 40           27375   7995   42100                           6234   38864556
# 41           27192   5995   47795                           6661   44364845
# 42           25214   5084   50934                           4249   18053757
# 43           24056  15240   57840                          16804  282386872
# 44           24035   7497   59540                           5532   30602651
# 45           24199  23999   34125                           4852   23544131
# 46           22526   5800   65460                          12077  145846299
# 47           23202  15949   28920                           3023    9141407
# 48           23110   8889   40475                           4997   24971527
# 49           22994   5898   34035                           4480   20072392
#
#         max   mean  trimmed_mean  standard_deviation    iqr
# 0     63313  37796         37290                4991   6027
# 1    403550  37653         37698                3298   4200
# 2   1032750  55070         54784               10535  13615
# 3    225000  60245         58674               14830  16477
# 4     80350  34665         34496                3848   5225
# 5     85865  46975         46816                5750   7556
# 6    324849  63022         62735                7849  11012
# 7    278478  25388         25168                2311   2784
# 8    256230  24916         24967                2148   2595
# 9    345550  35260         35135                4305   5737
# 10   900060  60267         60207               11361  14504
# 11    58045  27638         27418                2145   1400
# 12   378044  38471         38547                4416   6924
# 13   362227  32108         32152                3786   5077
# 14    66750  34563         34393                4063   4659
# 15    83988  53703         53691                4650   7801
# 16    55428  33276         32986                3556   4793
# 17   750202  35152         34746                7933   5262
# 18   162185  29186         29163                2070   2555
# 19    49710  31651         31709                3078   4406
# 20    81806  49092         48879                6778   8845
# 21   571365  49745         49789                4991   5980
# 22    47446  35939         35979                3357   5005
# 23   902600  30778         30743                5776   4435
# 24    54530  25958         25632                2902   3214
# 25    37320  23378         23297                2362   2822
# 26    51006  33528         33168                3246   3501
# 27    67499  33831         33642                3913   5184
# 28    86572  48430         48344                4028   5530
# 29   750202  22802         22588                5240   3045
# 30   189740  61063         59425               14696  13920
# 31   500202  32438         32101                6129   7355
# 32   335505  43877         44058                5398   9061
# 33   304400  28444         28348                3239   4141
# 34   120037  65943         65150               11911  18505
# 35  1000202  34035         33667                6989   4637
# 36    95937  51202         50526                8943  11049
# 37   198835  72501         71709               17247  28752
# 38    68995  47791         47897                5286   9270
# 39   595725  49819         50016                5488   6925
# 40    77010  42118         41976                6234   8065
# 41    93305  48138         48013                6661  11655
# 42    85600  51092         51030                4249   5515
# 43  1094400  61270         58921               16804  14500
# 44   125660  59336         59439                5532   6980
# 45    61390  35784         35403                4852   7300
# 46   144541  66347         65722               12077  17188
# 47    47184  29719         29367                3023   3650
# 48    69425  41160         41051                4997   6970
# 49    75203  33489         33552                4480   5508

# %%
Make_top_50 = df_expanded['make'].value_counts()
Make_top_50
plt.title("Share of Makes in the Top 50 Cars of the US 2024")
plt.pie(Make_top_50, labels=Make_top_50.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
# Out:
# (-1.0999984402033447,
#  1.0999999090494894,
#  -1.0999991497036314,
#  1.0999999595050425)

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
top_5_cars = df_expanded.head(5)  # Select the top 5 cars

plt.figure(figsize=(10, 6))  # Set the figure size

plt.bar(top_5_cars['model'], top_5_cars['count'])  # Create the bar chart for the top 5 cars

plt.xlabel('Car Model')  # Set the x-axis label
plt.ylabel('Number of Cars')  # Set the y-axis label
plt.title('Top 5 Cars in 2024')  # Set the title

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.show()  # Display the plot

# %%
cars_clean_df = pd.read_csv('Resources/car_sales_clean.csv')
cars_clean_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0  white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0   gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0  white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0   gray
# ...             ...                ...   ...        ...       ...    ...
# 472320    automatic  wbafr1c53bc744672    fl       39.0   66403.0  white
# 472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0  white
# 472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0  black
# 472323    automatic  1n4al3ap0fc216050    ga       38.0   16658.0  white
# 472324    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 472320    brown           lauderdale imports ltd bmw pembrok pines  20300.0
# 472321    black                                    i -5 uhlmann rv  30200.0
# 472322    black             financial services remarketing (lease)  29800.0
# 472323    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 472324     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate   type
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)  Sedan
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)  Sedan
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Sedan
# ...              ...                                      ...    ...
# 472320       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)  Sedan
# 472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)  Truck
# 472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    SUV
# 472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)  Sedan
# 472324       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)  Truck
#
# [472325 rows x 17 columns]

# %%
df_by_year = {year: group for year, group in cars_clean_df.groupby('year')}

# %%
#Data Analysis for Car Sales in 2010
# Dropping columns from the DataFrame
car_sales_2005_df = df_by_year[2005][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2005_df
car_sales_2005_df["make"].value_counts()
# Out:
# make
# Chevrolet        2439
# Ford             1927
# Nissan           1446
# Dodge            1325
# Toyota           1089
# Honda             932
# Chrysler          862
# Jeep              632
# BMW               594
# GMC               522
# Mercedes-Benz     518
# Cadillac          467
# Hyundai           374
# Pontiac           347
# Acura             336
# Volkswagen        324
# Buick             307
# Kia               290
# Infiniti          267
# Volvo             264
# Mazda             249
# Audi              217
# Lexus             195
# Saturn            182
# Mercury           168
# Subaru            142
# MINI              112
# Lincoln           110
# Mitsubishi        102
# Jaguar             86
# HUMMER             78
# Saab               60
# Suzuki             59
# Porsche            55
# Scion              53
# Bentley            18
# Land Rover          8
# Isuzu               7
# Maserati            6
# Name: count, dtype: int64

# %%
car_sales_2006_df = df_by_year[2006][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2006_df
car_sales_2006_df["make"].value_counts()
# Out:
# make
# Chevrolet        2521
# Ford             2458
# Nissan           1504
# Dodge            1446
# Toyota           1272
# BMW              1260
# Chrysler         1140
# Honda             978
# Mercedes-Benz     950
# Jeep              788
# Pontiac           659
# Volkswagen        645
# Cadillac          593
# Hyundai           543
# Lexus             518
# Kia               402
# GMC               390
# Infiniti          373
# Acura             358
# Buick             309
# Audi              266
# HUMMER            245
# Saturn            242
# Lincoln           222
# Mercury           204
# Volvo             197
# Subaru            195
# Mazda             182
# Mitsubishi        171
# MINI              139
# Suzuki            108
# Porsche           102
# Saab               77
# Scion              59
# Jaguar             57
# Bentley            20
# Isuzu              18
# Maserati           17
# Aston Martin        3
# Name: count, dtype: int64

# %%
car_sales_2007_df = df_by_year[2007][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2007_df
car_sales_2007_df["make"].value_counts()
# Out:
# make
# Chevrolet        3598
# Ford             2563
# Toyota           1882
# Dodge            1583
# Nissan           1486
# Honda            1478
# BMW              1296
# Chrysler         1237
# Jeep             1060
# GMC               918
# Mercedes-Benz     890
# Cadillac          814
# Lexus             786
# Pontiac           733
# Volkswagen        555
# Hyundai           533
# Saturn            502
# Audi              383
# Kia               340
# Acura             325
# Buick             290
# Infiniti          262
# Mitsubishi        224
# Volvo             214
# Lincoln           209
# HUMMER            179
# Suzuki            177
# Scion             150
# MINI              144
# Mercury           140
# Mazda             123
# Subaru            100
# Saab               56
# Jaguar             52
# Porsche            39
# Bentley            21
# Maserati           12
# Aston Martin       12
# Isuzu               7
# Lamborghini         3
# Lotus               1
# Ferrari             1
# Name: count, dtype: int64

# %%
car_sales_2008_df = df_by_year[2008][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2008_df
car_sales_2008_df["make"].value_counts()
# Out:
# make
# Chevrolet        3669
# Ford             3237
# Dodge            2053
# Honda            1537
# Toyota           1533
# BMW              1483
# Chrysler         1197
# Nissan           1191
# Mercedes-Benz    1088
# Jeep             1054
# GMC               906
# Pontiac           729
# Lexus             652
# Cadillac          575
# Saturn            566
# Hyundai           484
# Kia               464
# Mazda             438
# Volkswagen        427
# Buick             401
# Audi              383
# Infiniti          369
# Acura             274
# Scion             264
# Land Rover        257
# Mercury           240
# Mitsubishi        222
# Suzuki            206
# Subaru            200
# Lincoln           199
# Volvo             177
# MINI              171
# HUMMER            122
# Porsche            94
# Saab               44
# smart              34
# Jaguar             32
# Maserati           17
# Bentley            13
# Aston Martin        5
# Isuzu               3
# Ferrari             1
# Name: count, dtype: int64

# %%
car_sales_2009_df = df_by_year[2009][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2009_df
# Out:
#         year           make     model state   color      mmr  sellingprice  \
# 2455    2009          Acura       MDX    ca   white  18550.0       18250.0
# 2462    2009          Acura        TL    ca    blue  16350.0       18200.0
# 2480    2009          Acura       MDX    ca  silver  14750.0       13000.0
# 2515    2009           Audi        A3    ca   black  11800.0       14250.0
# 2572    2009         Nissan    Maxima    ca   black  12100.0       10700.0
# ...      ...            ...       ...   ...     ...      ...           ...
# 472239  2009           Jeep  Wrangler    nv   white  23100.0       17500.0
# 472262  2009           Jeep   Compass    oh    blue   6900.0        6300.0
# 472270  2009         Nissan    Sentra    mo    blue   5125.0        5700.0
# 472271  2009        Pontiac        G8    mo     red  29600.0       26500.0
# 472313  2009  Mercedes-Benz   C-Class    hi  silver  12600.0       10250.0
#
#                                        saledate   type
# 2455    Tue Dec 16 2014 12:00:00 GMT-0800 (PST)    SUV
# 2462    Fri Dec 26 2014 15:00:00 GMT-0800 (PST)  Sedan
# 2480    Wed Feb 04 2015 04:30:00 GMT-0800 (PST)    SUV
# 2515    Wed Dec 17 2014 12:15:00 GMT-0800 (PST)  Wagon
# 2572    Thu Dec 18 2014 12:00:00 GMT-0800 (PST)  Sedan
# ...                                         ...    ...
# 472239  Fri Jun 19 2015 05:00:00 GMT-0700 (PDT)    SUV
# 472262  Tue Jun 30 2015 06:30:00 GMT-0700 (PDT)    SUV
# 472270  Tue Jun 23 2015 04:00:00 GMT-0700 (PDT)  Sedan
# 472271  Wed Jun 24 2015 03:30:00 GMT-0700 (PDT)  Sedan
# 472313  Tue Jul 07 2015 09:30:00 GMT-0700 (PDT)  Sedan
#
# [17959 rows x 9 columns]

# %%
car_sales_2010_df = df_by_year[2010][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2010_df
car_sales_2010_df["make"].value_counts()
# Out:
# make
# Ford             3534
# Chevrolet        3347
# Dodge            2421
# Toyota           1991
# Honda            1313
# Nissan           1271
# Hyundai           740
# Mercedes-Benz     738
# Jeep              730
# Chrysler          724
# Kia               621
# GMC               587
# Mazda             551
# Volkswagen        532
# BMW               491
# Lexus             483
# Cadillac          331
# Buick             253
# Audi              236
# Acura             201
# Lincoln           186
# Subaru            165
# Mitsubishi        165
# MINI              147
# Mercury           137
# Infiniti          135
# Volvo             135
# Land Rover        111
# Scion              95
# Pontiac            65
# Suzuki             64
# Porsche            44
# Jaguar             41
# Saab                9
# Ferrari             6
# smart               6
# Rolls-Royce         3
# HUMMER              3
# Bentley             2
# Maserati            2
# Name: count, dtype: int64

# %%
car_sales_2011_df = df_by_year[2011][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2011_df
car_sales_2011_df['make'].value_counts()
# Out:
# make
# Ford             6685
# Chevrolet        4892
# Nissan           4825
# Toyota           3829
# Infiniti         2633
# BMW              2215
# Honda            1563
# Dodge            1476
# Hyundai          1440
# Mercedes-Benz    1310
# Kia              1185
# Jeep             1171
# Mazda             998
# GMC               925
# Lexus             893
# Ram               643
# Cadillac          583
# Volkswagen        507
# Chrysler          470
# Subaru            424
# Buick             379
# Audi              347
# Lincoln           325
# Mitsubishi        290
# Land Rover        285
# Jaguar            217
# Acura             210
# MINI              201
# Volvo             122
# Porsche           107
# Scion             100
# Suzuki             63
# Mercury            28
# Saab               11
# smart              10
# Rolls-Royce         9
# Maserati            7
# Bentley             3
# Aston Martin        2
# Ferrari             1
# Name: count, dtype: int64

# %%
car_sales_2012_df = df_by_year[2012][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2012_df
car_sales_2012_df["make"].value_counts()
# Out:
# make
# Ford             14640
# Nissan           13785
# Honda             7994
# Toyota            6675
# Chevrolet         6359
# Infiniti          4106
# BMW               3720
# Hyundai           3459
# Dodge             2742
# Mercedes-Benz     2641
# Volkswagen        2503
# Lexus             2491
# Kia               2180
# Jeep              1941
# Chrysler          1314
# Acura             1183
# MINI              1050
# Mazda             1047
# GMC               1025
# Ram               1025
# Audi               956
# Lincoln            923
# Cadillac           652
# Buick              472
# Subaru             454
# Scion              398
# Volvo              301
# Mitsubishi         288
# Land Rover         218
# Porsche            205
# FIAT               202
# Jaguar             149
# smart              139
# Suzuki             100
# Maserati            12
# Bentley             12
# Fisker               9
# Ferrari              7
# Rolls-Royce          3
# Name: count, dtype: int64

# %%
car_sales_2013_df = df_by_year[2013][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2013_df
car_sales_2013_df["make"].value_counts()
# Out:
# make
# Ford             20459
# Chevrolet         9823
# Nissan            9759
# Hyundai           6869
# Toyota            6174
# Dodge             5432
# Infiniti          3982
# Kia               2747
# Chrysler          2726
# Mercedes-Benz     2491
# Honda             2356
# Volkswagen        2072
# Lexus             1855
# BMW               1451
# Mazda             1301
# Lincoln           1046
# Ram                925
# Jeep               807
# GMC                737
# Audi               577
# Mitsubishi         561
# Cadillac           520
# Subaru             514
# Buick              467
# MINI               279
# Scion              256
# FIAT               244
# Volvo              215
# Acura              210
# Porsche            200
# Land Rover         169
# smart               98
# Jaguar              61
# Suzuki              51
# Tesla               18
# Bentley              9
# Maserati             5
# Rolls-Royce          1
# Name: count, dtype: int64

# %%
car_sales_2014_df = df_by_year[2014][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2014_df
car_sales_2014_df["make"].value_counts()
# Out:
# make
# Ford             17179
# Chevrolet         8344
# Dodge             5542
# Kia               5468
# Toyota            5244
# Nissan            4504
# Chrysler          3664
# Jeep              2558
# Hyundai           2316
# BMW               1484
# Subaru            1426
# Ram               1408
# GMC               1258
# Volkswagen        1144
# Honda             1129
# Infiniti           946
# Lincoln            886
# Mercedes-Benz      843
# Mazda              736
# Mitsubishi         641
# Lexus              559
# Buick              417
# Audi               414
# MINI               296
# FIAT               274
# Cadillac           258
# Volvo              198
# Scion              143
# Acura              141
# Land Rover         105
# Porsche             89
# Jaguar              57
# Maserati            18
# smart               18
# Tesla                5
# Name: count, dtype: int64

# %%
car_sales_2015_df = df_by_year[2015][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2015_df
car_sales_2015_df["make"].value_counts()
# Out:
# make
# Chevrolet        1256
# Kia              1254
# Ford              906
# BMW               601
# Nissan            499
# Hyundai           443
# Chrysler          404
# Mazda             333
# Volvo             317
# Jeep              289
# Subaru            228
# GMC               220
# Toyota            217
# Dodge             209
# Buick             114
# Mercedes-Benz     103
# Audi               99
# Lexus              83
# Honda              69
# Cadillac           58
# Volkswagen         56
# Mitsubishi         56
# MINI               46
# Ram                43
# Lincoln            26
# Acura              16
# Jaguar             15
# Scion               9
# Infiniti            9
# Land Rover          6
# FIAT                5
# Porsche             4
# smart               1
# Name: count, dtype: int64

# %%
# # Sample JSON data with lists within cells
# json_data = [{"id": 1, "name": "Alice", "scores": [85, 90, 88]}, {"id": 2, "name": "Bob", "scores": [78, 82, 80]}]

# # Create a DataFrame from the JSON list
# df = pd.DataFrame(json_data)

# print("DataFrame with lists within cells:")
# print(df)

# # If you want to split the lists into separate columns
# df_expanded = pd.concat([df.drop(['scores'], axis=1), df['scores'].apply(pd.Series)], axis=1)

# print("\nDataFrame with lists split into separate columns:")
# print(df_expanded)
