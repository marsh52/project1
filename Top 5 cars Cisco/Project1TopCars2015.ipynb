# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.stats import linregress

# Import the API key
from config import car_key
from config import car_secret_key

# %%
colors = ['blue', 'green', 'red', 'purple', 'orange', 'yellow', 'cyan', 'magenta', 'brown', 'pink']

# %%
# search base URL
base_url = f"https://mc-api.marketcheck.com/v2/popular/cars?api_key={car_key}&car_type=new&country=us"


response = requests.get(base_url).json()
print(base_url)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# https://mc-api.marketcheck.com/v2/popular/cars?api_key=hkwHViWcszguqrfsvqvFnBmuRSQIVNZ8&car_type=new&country=us
# [
#     {
#         "count": 130243,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 22,
#             "iqr": 20,
#             "listings_count": 0,
#             "max": 1678,
#             "mean": 29,
#             "median": 25,
#             "min": 1,
#             "population_standard_deviation": 28,
#             "standard_deviation": 28,
#             "trimmed_mean": 26,
#             "variance": 793
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 33450,
#             "max": 140797,
#             "mean": 112,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2310,
#             "standard_deviation": 2310,
#             "trimmed_mean": 6,
#             "variance": 5333860
#         },
#         "model": "RAV4",
#         "price_stats": {
#             "geometric_mean": 37359,
#             "iqr": 6008,
#             "listings_count": 124603,
#             "max": 63313,
#             "mean": 37664,
#             "median": 36768,
#             "min": 9988,
#             "population_standard_deviation": 4952,
#             "standard_deviation": 4952,
#             "trimmed_mean": 37159,
#             "variance": 24524202
#         }
#     },
#     {
#         "count": 100180,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 29,
#             "iqr": 35,
#             "listings_count": 0,
#             "max": 2151,
#             "mean": 43,
#             "median": 31,
#             "min": 1,
#             "population_standard_deviation": 50,
#             "standard_deviation": 50,
#             "trimmed_mean": 35,
#             "variance": 2528
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 74781,
#             "max": 466625,
#             "mean": 91,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 3184,
#             "standard_deviation": 3184,
#             "trimmed_mean": 7,
#             "variance": 10139324
#         },
#         "model": "CR-V",
#         "price_stats": {
#             "geometric_mean": 37651,
#             "iqr": 4395,
#             "listings_count": 94027,
#             "max": 387000,
#             "mean": 37779,
#             "median": 37850,
#             "min": 5936,
#             "population_standard_deviation": 3274,
#             "standard_deviation": 3274,
#             "trimmed_mean": 37833,
#             "variance": 10721259
#         }
#     },
#     {
#         "count": 90182,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 58,
#             "iqr": 94,
#             "listings_count": 0,
#             "max": 1769,
#             "mean": 101,
#             "median": 69,
#             "min": 1,
#             "population_standard_deviation": 105,
#             "standard_deviation": 105,
#             "trimmed_mean": 82,
#             "variance": 11119
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 22,
#             "iqr": 45,
#             "listings_count": 53181,
#             "max": 544695,
#             "mean": 513,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 5110,
#             "standard_deviation": 5110,
#             "trimmed_mean": 46,
#             "variance": 26112289
#         },
#         "model": "F-150",
#         "price_stats": {
#             "geometric_mean": 58395,
#             "iqr": 16367,
#             "listings_count": 84939,
#             "max": 214335,
#             "mean": 59938,
#             "median": 57405,
#             "min": 5250,
#             "population_standard_deviation": 14650,
#             "standard_deviation": 14650,
#             "trimmed_mean": 58422,
#             "variance": 214608035
#         }
#     },
#     {
#         "count": 87978,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 74,
#             "iqr": 102,
#             "listings_count": 0,
#             "max": 1616,
#             "mean": 105,
#             "median": 83,
#             "min": 1,
#             "population_standard_deviation": 81,
#             "standard_deviation": 81,
#             "trimmed_mean": 95,
#             "variance": 6569
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 12,
#             "listings_count": 63799,
#             "max": 999999,
#             "mean": 331,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 5440,
#             "standard_deviation": 5440,
#             "trimmed_mean": 12,
#             "variance": 29598932
#         },
#         "model": "Silverado 1500",
#         "price_stats": {
#             "geometric_mean": 54091,
#             "iqr": 13609,
#             "listings_count": 85993,
#             "max": 681000,
#             "mean": 54933,
#             "median": 54435,
#             "min": 5995,
#             "population_standard_deviation": 10177,
#             "standard_deviation": 10177,
#             "trimmed_mean": 54673,
#             "variance": 103573151
#         }
#     },
#     {
#         "count": 84085,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 20,
#             "iqr": 19,
#             "listings_count": 0,
#             "max": 935,
#             "mean": 26,
#             "median": 22,
#             "min": 1,
#             "population_standard_deviation": 28,
#             "standard_deviation": 28,
#             "trimmed_mean": 23,
#             "variance": 772
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 18903,
#             "max": 210066,
#             "mean": 134,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2824,
#             "standard_deviation": 2824,
#             "trimmed_mean": 6,
#             "variance": 7973624
#         },
#         "model": "Camry",
#         "price_stats": {
#             "geometric_mean": 35141,
#             "iqr": 4953,
#             "listings_count": 80627,
#             "max": 80350,
#             "mean": 35323,
#             "median": 34638,
#             "min": 5999,
#             "population_standard_deviation": 3616,
#             "standard_deviation": 3616,
#             "trimmed_mean": 35135,
#             "variance": 13078946
#         }
#     },
#     {
#         "count": 72847,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 33,
#             "iqr": 36,
#             "listings_count": 0,
#             "max": 2192,
#             "mean": 43,
#             "median": 39,
#             "min": 1,
#             "population_standard_deviation": 35,
#             "standard_deviation": 35,
#             "trimmed_mean": 40,
#             "variance": 1200
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 18806,
#             "max": 245021,
#             "mean": 118,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3121,
#             "standard_deviation": 3121,
#             "trimmed_mean": 6,
#             "variance": 9738329
#         },
#         "model": "Tacoma",
#         "price_stats": {
#             "geometric_mean": 46917,
#             "iqr": 7933,
#             "listings_count": 70017,
#             "max": 89995,
#             "mean": 47297,
#             "median": 46624,
#             "min": 11289,
#             "population_standard_deviation": 6092,
#             "standard_deviation": 6092,
#             "trimmed_mean": 47032,
#             "variance": 37117152
#         }
#     },
#     {
#         "count": 63018,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 22,
#             "iqr": 18,
#             "listings_count": 0,
#             "max": 960,
#             "mean": 28,
#             "median": 24,
#             "min": 1,
#             "population_standard_deviation": 30,
#             "standard_deviation": 30,
#             "trimmed_mean": 25,
#             "variance": 919
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 7,
#             "listings_count": 14370,
#             "max": 188546,
#             "mean": 148,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3054,
#             "standard_deviation": 3054,
#             "trimmed_mean": 6,
#             "variance": 9329805
#         },
#         "model": "Corolla",
#         "price_stats": {
#             "geometric_mean": 25300,
#             "iqr": 2719,
#             "listings_count": 60619,
#             "max": 55306,
#             "mean": 25379,
#             "median": 24810,
#             "min": 7985,
#             "population_standard_deviation": 2064,
#             "standard_deviation": 2064,
#             "trimmed_mean": 25157,
#             "variance": 4261941
#         }
#     },
#     {
#         "count": 59819,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 40,
#             "iqr": 36,
#             "listings_count": 0,
#             "max": 1698,
#             "mean": 55,
#             "median": 39,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 45,
#             "variance": 2697
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 17254,
#             "max": 104131,
#             "mean": 127,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1844,
#             "standard_deviation": 1844,
#             "trimmed_mean": 6,
#             "variance": 3398848
#         },
#         "model": "Tundra",
#         "price_stats": {
#             "geometric_mean": 61841,
#             "iqr": 10521,
#             "listings_count": 57842,
#             "max": 324849,
#             "mean": 62294,
#             "median": 61935,
#             "min": 6950,
#             "population_standard_deviation": 7618,
#             "standard_deviation": 7618,
#             "trimmed_mean": 61984,
#             "variance": 58040067
#         }
#     },
#     {
#         "count": 58530,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 31,
#             "iqr": 38,
#             "listings_count": 0,
#             "max": 835,
#             "mean": 44,
#             "median": 33,
#             "min": 1,
#             "population_standard_deviation": 39,
#             "standard_deviation": 39,
#             "trimmed_mean": 38,
#             "variance": 1490
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 40243,
#             "max": 112515,
#             "mean": 48,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1100,
#             "standard_deviation": 1100,
#             "trimmed_mean": 7,
#             "variance": 1211027
#         },
#         "model": "Trax",
#         "price_stats": {
#             "geometric_mean": 24920,
#             "iqr": 2453,
#             "listings_count": 54950,
#             "max": 256230,
#             "mean": 24984,
#             "median": 25035,
#             "min": 5250,
#             "population_standard_deviation": 1977,
#             "standard_deviation": 1977,
#             "trimmed_mean": 25060,
#             "variance": 3910304
#         }
#     },
#     {
#         "count": 45637,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 50,
#             "iqr": 46,
#             "listings_count": 0,
#             "max": 2024,
#             "mean": 63,
#             "median": 50,
#             "min": 1,
#             "population_standard_deviation": 44,
#             "standard_deviation": 44,
#             "trimmed_mean": 56,
#             "variance": 1978
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 6,
#             "listings_count": 18215,
#             "max": 81113,
#             "mean": 56,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1219,
#             "standard_deviation": 1219,
#             "trimmed_mean": 5,
#             "variance": 1486591
#         },
#         "model": "Crosstrek",
#         "price_stats": {
#             "geometric_mean": 31772,
#             "iqr": 5233,
#             "listings_count": 44665,
#             "max": 362227,
#             "mean": 31940,
#             "median": 31667,
#             "min": 12500,
#             "population_standard_deviation": 3805,
#             "standard_deviation": 3805,
#             "trimmed_mean": 31966,
#             "variance": 14477512
#         }
#     },
#     {
#         "count": 44794,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 53,
#             "iqr": 70,
#             "listings_count": 0,
#             "max": 1417,
#             "mean": 76,
#             "median": 58,
#             "min": 1,
#             "population_standard_deviation": 69,
#             "standard_deviation": 69,
#             "trimmed_mean": 66,
#             "variance": 4718
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 9,
#             "listings_count": 33165,
#             "max": 200020,
#             "mean": 181,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2326,
#             "standard_deviation": 2326,
#             "trimmed_mean": 12,
#             "variance": 5410792
#         },
#         "model": "Tucson",
#         "price_stats": {
#             "geometric_mean": 35104,
#             "iqr": 6064,
#             "listings_count": 43554,
#             "max": 345550,
#             "mean": 35348,
#             "median": 34739,
#             "min": 6999,
#             "population_standard_deviation": 4384,
#             "standard_deviation": 4384,
#             "trimmed_mean": 35230,
#             "variance": 19221705
#         }
#     },
#     {
#         "count": 43208,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 64,
#             "iqr": 58,
#             "listings_count": 0,
#             "max": 1437,
#             "mean": 79,
#             "median": 66,
#             "min": 1,
#             "population_standard_deviation": 53,
#             "standard_deviation": 53,
#             "trimmed_mean": 71,
#             "variance": 2842
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 17007,
#             "max": 98000,
#             "mean": 123,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2043,
#             "standard_deviation": 2043,
#             "trimmed_mean": 6,
#             "variance": 4173920
#         },
#         "model": "Outback",
#         "price_stats": {
#             "geometric_mean": 38130,
#             "iqr": 6924,
#             "listings_count": 42274,
#             "max": 378044,
#             "mean": 38371,
#             "median": 38627,
#             "min": 5018,
#             "population_standard_deviation": 4481,
#             "standard_deviation": 4481,
#             "trimmed_mean": 38433,
#             "variance": 20076817
#         }
#     },
#     {
#         "count": 42352,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 26,
#             "iqr": 25,
#             "listings_count": 0,
#             "max": 2435,
#             "mean": 38,
#             "median": 27,
#             "min": 1,
#             "population_standard_deviation": 58,
#             "standard_deviation": 58,
#             "trimmed_mean": 30,
#             "variance": 3347
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 6,
#             "listings_count": 30916,
#             "max": 127000,
#             "mean": 94,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2112,
#             "standard_deviation": 2112,
#             "trimmed_mean": 7,
#             "variance": 4462208
#         },
#         "model": "Civic",
#         "price_stats": {
#             "geometric_mean": 27725,
#             "iqr": 1400,
#             "listings_count": 39485,
#             "max": 46645,
#             "mean": 27813,
#             "median": 27345,
#             "min": 5081,
#             "population_standard_deviation": 2179,
#             "standard_deviation": 2179,
#             "trimmed_mean": 27592,
#             "variance": 4747567
#         }
#     },
#     {
#         "count": 42102,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 65,
#             "iqr": 72,
#             "listings_count": 0,
#             "max": 1154,
#             "mean": 88,
#             "median": 68,
#             "min": 1,
#             "population_standard_deviation": 74,
#             "standard_deviation": 74,
#             "trimmed_mean": 76,
#             "variance": 5474
#         },
#         "make": "GMC",
#         "miles_stats": {
#             "geometric_mean": 9,
#             "iqr": 8,
#             "listings_count": 30342,
#             "max": 590072,
#             "mean": 238,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 4180,
#             "standard_deviation": 4180,
#             "trimmed_mean": 11,
#             "variance": 17472984
#         },
#         "model": "Sierra 1500",
#         "price_stats": {
#             "geometric_mean": 58844,
#             "iqr": 14502,
#             "listings_count": 41147,
#             "max": 900060,
#             "mean": 59914,
#             "median": 60126,
#             "min": 6750,
#             "population_standard_deviation": 11891,
#             "standard_deviation": 11891,
#             "trimmed_mean": 59828,
#             "variance": 141390713
#         }
#     },
#     {
#         "count": 40428,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 40,
#             "iqr": 55,
#             "listings_count": 0,
#             "max": 2057,
#             "mean": 61,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 72,
#             "standard_deviation": 72,
#             "trimmed_mean": 50,
#             "variance": 5133
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 30009,
#             "max": 364020,
#             "mean": 159,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 4038,
#             "standard_deviation": 4038,
#             "trimmed_mean": 7,
#             "variance": 16303753
#         },
#         "model": "Accord",
#         "price_stats": {
#             "geometric_mean": 33016,
#             "iqr": 4630,
#             "listings_count": 38338,
#             "max": 56349,
#             "mean": 33211,
#             "median": 32300,
#             "min": 5697,
#             "population_standard_deviation": 3597,
#             "standard_deviation": 3597,
#             "trimmed_mean": 32925,
#             "variance": 12939739
#         }
#     },
#     {
#         "count": 39967,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 62,
#             "iqr": 73,
#             "listings_count": 0,
#             "max": 1571,
#             "mean": 83,
#             "median": 73,
#             "min": 1,
#             "population_standard_deviation": 60,
#             "standard_deviation": 60,
#             "trimmed_mean": 77,
#             "variance": 3644
#         },
#         "make": "Nissan",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 5,
#             "listings_count": 28383,
#             "max": 532920,
#             "mean": 123,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 3729,
#             "standard_deviation": 3729,
#             "trimmed_mean": 7,
#             "variance": 13904516
#         },
#         "model": "Rogue",
#         "price_stats": {
#             "geometric_mean": 34380,
#             "iqr": 4835,
#             "listings_count": 38780,
#             "max": 66750,
#             "mean": 34615,
#             "median": 34305,
#             "min": 6980,
#             "population_standard_deviation": 4041,
#             "standard_deviation": 4041,
#             "trimmed_mean": 34445,
#             "variance": 16330294
#         }
#     },
#     {
#         "count": 38165,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 36,
#             "iqr": 60,
#             "listings_count": 0,
#             "max": 1482,
#             "mean": 57,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 57,
#             "standard_deviation": 57,
#             "trimmed_mean": 48,
#             "variance": 3292
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 30270,
#             "max": 215915,
#             "mean": 111,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2086,
#             "standard_deviation": 2086,
#             "trimmed_mean": 10,
#             "variance": 4352509
#         },
#         "model": "Sportage",
#         "price_stats": {
#             "geometric_mean": 34869,
#             "iqr": 5272,
#             "listings_count": 37145,
#             "max": 750202,
#             "mean": 35170,
#             "median": 34840,
#             "min": 12565,
#             "population_standard_deviation": 7919,
#             "standard_deviation": 7919,
#             "trimmed_mean": 34771,
#             "variance": 62716044
#         }
#     },
#     {
#         "count": 37292,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 46,
#             "iqr": 36,
#             "listings_count": 0,
#             "max": 1641,
#             "mean": 57,
#             "median": 50,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 52,
#             "variance": 2677
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 27982,
#             "max": 309017,
#             "mean": 81,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 2881,
#             "standard_deviation": 2881,
#             "trimmed_mean": 7,
#             "variance": 8298000
#         },
#         "model": "HR-V",
#         "price_stats": {
#             "geometric_mean": 29295,
#             "iqr": 2455,
#             "listings_count": 35321,
#             "max": 162185,
#             "mean": 29364,
#             "median": 29480,
#             "min": 5041,
#             "population_standard_deviation": 2052,
#             "standard_deviation": 2052,
#             "trimmed_mean": 29346,
#             "variance": 4208764
#         }
#     },
#     {
#         "count": 36961,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 25,
#             "iqr": 19,
#             "listings_count": 0,
#             "max": 798,
#             "mean": 31,
#             "median": 28,
#             "min": 1,
#             "population_standard_deviation": 22,
#             "standard_deviation": 22,
#             "trimmed_mean": 28,
#             "variance": 506
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 7,
#             "listings_count": 8923,
#             "max": 111264,
#             "mean": 48,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1362,
#             "standard_deviation": 1362,
#             "trimmed_mean": 6,
#             "variance": 1856158
#         },
#         "model": "Corolla Cross",
#         "price_stats": {
#             "geometric_mean": 31456,
#             "iqr": 4531,
#             "listings_count": 35317,
#             "max": 49710,
#             "mean": 31612,
#             "median": 31938,
#             "min": 21806,
#             "population_standard_deviation": 3117,
#             "standard_deviation": 3117,
#             "trimmed_mean": 31655,
#             "variance": 9714299
#         }
#     },
#     {
#         "count": 36404,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 38,
#             "iqr": 48,
#             "listings_count": 0,
#             "max": 1657,
#             "mean": 54,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 61,
#             "standard_deviation": 61,
#             "trimmed_mean": 47,
#             "variance": 3669
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 6,
#             "listings_count": 27368,
#             "max": 158517,
#             "mean": 114,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 2454,
#             "standard_deviation": 2454,
#             "trimmed_mean": 7,
#             "variance": 6023239
#         },
#         "model": "Pilot",
#         "price_stats": {
#             "geometric_mean": 49553,
#             "iqr": 6085,
#             "listings_count": 34652,
#             "max": 571365,
#             "mean": 49757,
#             "median": 50495,
#             "min": 5835,
#             "population_standard_deviation": 5090,
#             "standard_deviation": 5090,
#             "trimmed_mean": 49802,
#             "variance": 25910287
#         }
#     },
#     {
#         "count": 35046,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 60,
#             "iqr": 67,
#             "listings_count": 0,
#             "max": 2557,
#             "mean": 80,
#             "median": 62,
#             "min": 1,
#             "population_standard_deviation": 71,
#             "standard_deviation": 71,
#             "trimmed_mean": 71,
#             "variance": 5109
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 11,
#             "iqr": 8,
#             "listings_count": 26319,
#             "max": 130280,
#             "mean": 134,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1885,
#             "standard_deviation": 1885,
#             "trimmed_mean": 11,
#             "variance": 3551447
#         },
#         "model": "Elantra",
#         "price_stats": {
#             "geometric_mean": 25788,
#             "iqr": 3225,
#             "listings_count": 34195,
#             "max": 54490,
#             "mean": 25936,
#             "median": 25295,
#             "min": 9598,
#             "population_standard_deviation": 2883,
#             "standard_deviation": 2883,
#             "trimmed_mean": 25611,
#             "variance": 8313379
#         }
#     },
#     {
#         "count": 34562,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 94,
#             "iqr": 84,
#             "listings_count": 0,
#             "max": 2185,
#             "mean": 130,
#             "median": 121,
#             "min": 1,
#             "population_standard_deviation": 92,
#             "standard_deviation": 92,
#             "trimmed_mean": 121,
#             "variance": 8531
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 38,
#             "iqr": 524,
#             "listings_count": 21295,
#             "max": 183947,
#             "mean": 693,
#             "median": 13,
#             "min": 1,
#             "population_standard_deviation": 3447,
#             "standard_deviation": 3447,
#             "trimmed_mean": 251,
#             "variance": 11883433
#         },
#         "model": "Explorer",
#         "price_stats": {
#             "geometric_mean": 48786,
#             "iqr": 8987,
#             "listings_count": 32889,
#             "max": 81806,
#             "mean": 49276,
#             "median": 48560,
#             "min": 5762,
#             "population_standard_deviation": 6911,
#             "standard_deviation": 6911,
#             "trimmed_mean": 49100,
#             "variance": 47759308
#         }
#     },
#     {
#         "count": 34265,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 79,
#             "iqr": 93,
#             "listings_count": 0,
#             "max": 1116,
#             "mean": 106,
#             "median": 85,
#             "min": 1,
#             "population_standard_deviation": 80,
#             "standard_deviation": 80,
#             "trimmed_mean": 96,
#             "variance": 6406
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 26,
#             "iqr": 35,
#             "listings_count": 20749,
#             "max": 53000,
#             "mean": 411,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 1548,
#             "standard_deviation": 1548,
#             "trimmed_mean": 101,
#             "variance": 2396162
#         },
#         "model": "Bronco Sport",
#         "price_stats": {
#             "geometric_mean": 33426,
#             "iqr": 5168,
#             "listings_count": 33108,
#             "max": 65565,
#             "mean": 33651,
#             "median": 33160,
#             "min": 21676,
#             "population_standard_deviation": 3942,
#             "standard_deviation": 3942,
#             "trimmed_mean": 33447,
#             "variance": 15541110
#         }
#     },
#     {
#         "count": 33385,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 77,
#             "iqr": 99,
#             "listings_count": 0,
#             "max": 1418,
#             "mean": 105,
#             "median": 95,
#             "min": 1,
#             "population_standard_deviation": 73,
#             "standard_deviation": 73,
#             "trimmed_mean": 99,
#             "variance": 5271
#         },
#         "make": "Nissan",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 5,
#             "listings_count": 24587,
#             "max": 991390,
#             "mean": 127,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 6803,
#             "standard_deviation": 6803,
#             "trimmed_mean": 8,
#             "variance": 46283857
#         },
#         "model": "Sentra",
#         "price_stats": {
#             "geometric_mean": 23242,
#             "iqr": 2916,
#             "listings_count": 32356,
#             "max": 55344,
#             "mean": 23364,
#             "median": 23240,
#             "min": 6000,
#             "population_standard_deviation": 2400,
#             "standard_deviation": 2400,
#             "trimmed_mean": 23288,
#             "variance": 5761199
#         }
#     },
#     {
#         "count": 32116,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 97,
#             "iqr": 83,
#             "listings_count": 0,
#             "max": 1166,
#             "mean": 116,
#             "median": 101,
#             "min": 1,
#             "population_standard_deviation": 66,
#             "standard_deviation": 66,
#             "trimmed_mean": 110,
#             "variance": 4404
#         },
#         "make": "Mazda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 23752,
#             "max": 100000,
#             "mean": 104,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1713,
#             "standard_deviation": 1713,
#             "trimmed_mean": 7,
#             "variance": 2935087
#         },
#         "model": "CX-5",
#         "price_stats": {
#             "geometric_mean": 33337,
#             "iqr": 3694,
#             "listings_count": 31461,
#             "max": 51768,
#             "mean": 33495,
#             "median": 32740,
#             "min": 12977,
#             "population_standard_deviation": 3332,
#             "standard_deviation": 3332,
#             "trimmed_mean": 33157,
#             "variance": 11105379
#         }
#     },
#     {
#         "count": 32116,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 59,
#             "iqr": 58,
#             "listings_count": 0,
#             "max": 1118,
#             "mean": 79,
#             "median": 58,
#             "min": 1,
#             "population_standard_deviation": 67,
#             "standard_deviation": 67,
#             "trimmed_mean": 67,
#             "variance": 4540
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 21593,
#             "max": 180342,
#             "mean": 299,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 2843,
#             "standard_deviation": 2843,
#             "trimmed_mean": 13,
#             "variance": 8084954
#         },
#         "model": "Equinox",
#         "price_stats": {
#             "geometric_mean": 30792,
#             "iqr": 4506,
#             "listings_count": 31390,
#             "max": 59270,
#             "mean": 31024,
#             "median": 30991,
#             "min": 7500,
#             "population_standard_deviation": 3723,
#             "standard_deviation": 3723,
#             "trimmed_mean": 31032,
#             "variance": 13860827
#         }
#     },
#     {
#         "count": 30943,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 43,
#             "iqr": 37,
#             "listings_count": 0,
#             "max": 963,
#             "mean": 59,
#             "median": 45,
#             "min": 1,
#             "population_standard_deviation": 51,
#             "standard_deviation": 51,
#             "trimmed_mean": 50,
#             "variance": 2559
#         },
#         "make": "Subaru",
#         "miles_stats": {
#             "geometric_mean": 5,
#             "iqr": 8,
#             "listings_count": 12738,
#             "max": 110962,
#             "mean": 149,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 2438,
#             "standard_deviation": 2438,
#             "trimmed_mean": 5,
#             "variance": 5941572
#         },
#         "model": "Forester",
#         "price_stats": {
#             "geometric_mean": 36456,
#             "iqr": 4948,
#             "listings_count": 30156,
#             "max": 49995,
#             "mean": 36617,
#             "median": 36221,
#             "min": 9779,
#             "population_standard_deviation": 3392,
#             "standard_deviation": 3392,
#             "trimmed_mean": 36649,
#             "variance": 11502998
#         }
#     },
#     {
#         "count": 30890,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 32,
#             "iqr": 46,
#             "listings_count": 0,
#             "max": 1138,
#             "mean": 49,
#             "median": 34,
#             "min": 1,
#             "population_standard_deviation": 49,
#             "standard_deviation": 49,
#             "trimmed_mean": 40,
#             "variance": 2442
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 24537,
#             "max": 101499,
#             "mean": 103,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1409,
#             "standard_deviation": 1409,
#             "trimmed_mean": 10,
#             "variance": 1985413
#         },
#         "model": "Forte",
#         "price_stats": {
#             "geometric_mean": 22485,
#             "iqr": 2870,
#             "listings_count": 30078,
#             "max": 326750,
#             "mean": 22610,
#             "median": 22070,
#             "min": 6995,
#             "population_standard_deviation": 3532,
#             "standard_deviation": 3532,
#             "trimmed_mean": 22418,
#             "variance": 12475938
#         }
#     },
#     {
#         "count": 29885,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 116,
#             "iqr": 138,
#             "listings_count": 0,
#             "max": 2199,
#             "mean": 153,
#             "median": 124,
#             "min": 1,
#             "population_standard_deviation": 111,
#             "standard_deviation": 111,
#             "trimmed_mean": 140,
#             "variance": 12310
#         },
#         "make": "RAM",
#         "miles_stats": {
#             "geometric_mean": 20,
#             "iqr": 20,
#             "listings_count": 17932,
#             "max": 250212,
#             "mean": 380,
#             "median": 14,
#             "min": 1,
#             "population_standard_deviation": 3865,
#             "standard_deviation": 3865,
#             "trimmed_mean": 25,
#             "variance": 14938175
#         },
#         "model": "Ram 1500 Pickup",
#         "price_stats": {
#             "geometric_mean": 59097,
#             "iqr": 13811,
#             "listings_count": 29054,
#             "max": 200265,
#             "mean": 60479,
#             "median": 58813,
#             "min": 5900,
#             "population_standard_deviation": 14198,
#             "standard_deviation": 14198,
#             "trimmed_mean": 59029,
#             "variance": 201571875
#         }
#     },
#     {
#         "count": 29105,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 70,
#             "iqr": 103,
#             "listings_count": 0,
#             "max": 1273,
#             "mean": 105,
#             "median": 80,
#             "min": 1,
#             "population_standard_deviation": 90,
#             "standard_deviation": 90,
#             "trimmed_mean": 92,
#             "variance": 8186
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 27,
#             "iqr": 203,
#             "listings_count": 17166,
#             "max": 240854,
#             "mean": 783,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 5544,
#             "standard_deviation": 5544,
#             "trimmed_mean": 188,
#             "variance": 30737717
#         },
#         "model": "Escape",
#         "price_stats": {
#             "geometric_mean": 33478,
#             "iqr": 4532,
#             "listings_count": 27794,
#             "max": 366660,
#             "mean": 33758,
#             "median": 33160,
#             "min": 5250,
#             "population_standard_deviation": 4740,
#             "standard_deviation": 4740,
#             "trimmed_mean": 33410,
#             "variance": 22471163
#         }
#     },
#     {
#         "count": 28987,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 50,
#             "iqr": 69,
#             "listings_count": 0,
#             "max": 1109,
#             "mean": 72,
#             "median": 54,
#             "min": 1,
#             "population_standard_deviation": 61,
#             "standard_deviation": 61,
#             "trimmed_mean": 63,
#             "variance": 3670
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 8,
#             "iqr": 8,
#             "listings_count": 20923,
#             "max": 159496,
#             "mean": 122,
#             "median": 6,
#             "min": 1,
#             "population_standard_deviation": 1888,
#             "standard_deviation": 1888,
#             "trimmed_mean": 9,
#             "variance": 3562753
#         },
#         "model": "Trailblazer",
#         "price_stats": {
#             "geometric_mean": 28313,
#             "iqr": 4295,
#             "listings_count": 28106,
#             "max": 304400,
#             "mean": 28468,
#             "median": 28290,
#             "min": 5250,
#             "population_standard_deviation": 3332,
#             "standard_deviation": 3332,
#             "trimmed_mean": 28377,
#             "variance": 11104939
#         }
#     },
#     {
#         "count": 28786,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 39,
#             "iqr": 48,
#             "listings_count": 0,
#             "max": 1734,
#             "mean": 59,
#             "median": 41,
#             "min": 1,
#             "population_standard_deviation": 75,
#             "standard_deviation": 75,
#             "trimmed_mean": 47,
#             "variance": 5559
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 13,
#             "iqr": 11,
#             "listings_count": 21173,
#             "max": 156284,
#             "mean": 225,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2813,
#             "standard_deviation": 2813,
#             "trimmed_mean": 13,
#             "variance": 7911855
#         },
#         "model": "Santa Fe",
#         "price_stats": {
#             "geometric_mean": 43646,
#             "iqr": 9053,
#             "listings_count": 27990,
#             "max": 65800,
#             "mean": 43970,
#             "median": 45155,
#             "min": 8988,
#             "population_standard_deviation": 5205,
#             "standard_deviation": 5205,
#             "trimmed_mean": 44186,
#             "variance": 27089353
#         }
#     },
#     {
#         "count": 28579,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 22,
#             "iqr": 22,
#             "listings_count": 0,
#             "max": 823,
#             "mean": 32,
#             "median": 24,
#             "min": 1,
#             "population_standard_deviation": 37,
#             "standard_deviation": 37,
#             "trimmed_mean": 26,
#             "variance": 1391
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 7,
#             "listings_count": 18081,
#             "max": 901536,
#             "mean": 208,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 8931,
#             "standard_deviation": 8931,
#             "trimmed_mean": 8,
#             "variance": 79769577
#         },
#         "model": "Traverse",
#         "price_stats": {
#             "geometric_mean": 47555,
#             "iqr": 11660,
#             "listings_count": 27879,
#             "max": 93305,
#             "mean": 48002,
#             "median": 47160,
#             "min": 5995,
#             "population_standard_deviation": 6561,
#             "standard_deviation": 6561,
#             "trimmed_mean": 47859,
#             "variance": 43042767
#         }
#     },
#     {
#         "count": 28447,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 26,
#             "iqr": 43,
#             "listings_count": 0,
#             "max": 835,
#             "mean": 43,
#             "median": 35,
#             "min": 1,
#             "population_standard_deviation": 42,
#             "standard_deviation": 42,
#             "trimmed_mean": 37,
#             "variance": 1806
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 11,
#             "iqr": 15,
#             "listings_count": 15772,
#             "max": 39440,
#             "mean": 45,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 737,
#             "standard_deviation": 737,
#             "trimmed_mean": 13,
#             "variance": 542701
#         },
#         "model": "Maverick",
#         "price_stats": {
#             "geometric_mean": 32032,
#             "iqr": 7395,
#             "listings_count": 26223,
#             "max": 363300,
#             "mean": 32371,
#             "median": 31685,
#             "min": 23410,
#             "population_standard_deviation": 5961,
#             "standard_deviation": 5961,
#             "trimmed_mean": 32027,
#             "variance": 35532611
#         }
#     },
#     {
#         "count": 28056,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 83,
#             "iqr": 119,
#             "listings_count": 0,
#             "max": 2334,
#             "mean": 122,
#             "median": 85,
#             "min": 1,
#             "population_standard_deviation": 110,
#             "standard_deviation": 110,
#             "trimmed_mean": 103,
#             "variance": 12138
#         },
#         "make": "Jeep",
#         "miles_stats": {
#             "geometric_mean": 17,
#             "iqr": 16,
#             "listings_count": 17490,
#             "max": 144269,
#             "mean": 293,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 2649,
#             "standard_deviation": 2649,
#             "trimmed_mean": 20,
#             "variance": 7017217
#         },
#         "model": "Grand Cherokee",
#         "price_stats": {
#             "geometric_mean": 49594,
#             "iqr": 10565,
#             "listings_count": 27391,
#             "max": 95937,
#             "mean": 50315,
#             "median": 48700,
#             "min": 11249,
#             "population_standard_deviation": 8719,
#             "standard_deviation": 8719,
#             "trimmed_mean": 49606,
#             "variance": 76024943
#         }
#     },
#     {
#         "count": 28001,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 54,
#             "iqr": 91,
#             "listings_count": 0,
#             "max": 1629,
#             "mean": 92,
#             "median": 69,
#             "min": 1,
#             "population_standard_deviation": 89,
#             "standard_deviation": 89,
#             "trimmed_mean": 77,
#             "variance": 7984
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 18,
#             "listings_count": 16074,
#             "max": 215052,
#             "mean": 210,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 3838,
#             "standard_deviation": 3838,
#             "trimmed_mean": 16,
#             "variance": 14734029
#         },
#         "model": "F-250 Super Duty",
#         "price_stats": {
#             "geometric_mean": 69571,
#             "iqr": 28500,
#             "listings_count": 26211,
#             "max": 213161,
#             "mean": 71509,
#             "median": 68655,
#             "min": 19988,
#             "population_standard_deviation": 17056,
#             "standard_deviation": 17056,
#             "trimmed_mean": 70614,
#             "variance": 290913901
#         }
#     },
#     {
#         "count": 27645,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 49,
#             "iqr": 71,
#             "listings_count": 0,
#             "max": 1006,
#             "mean": 76,
#             "median": 55,
#             "min": 1,
#             "population_standard_deviation": 71,
#             "standard_deviation": 71,
#             "trimmed_mean": 64,
#             "variance": 5070
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 10,
#             "listings_count": 19359,
#             "max": 649112,
#             "mean": 146,
#             "median": 7,
#             "min": 1,
#             "population_standard_deviation": 5126,
#             "standard_deviation": 5126,
#             "trimmed_mean": 12,
#             "variance": 26272404
#         },
#         "model": "Silverado 2500HD",
#         "price_stats": {
#             "geometric_mean": 64978,
#             "iqr": 18625,
#             "listings_count": 26664,
#             "max": 128422,
#             "mean": 66019,
#             "median": 64212,
#             "min": 19995,
#             "population_standard_deviation": 11925,
#             "standard_deviation": 11925,
#             "trimmed_mean": 65259,
#             "variance": 142210117
#         }
#     },
#     {
#         "count": 27463,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 22,
#             "iqr": 21,
#             "listings_count": 0,
#             "max": 1432,
#             "mean": 31,
#             "median": 25,
#             "min": 1,
#             "population_standard_deviation": 40,
#             "standard_deviation": 40,
#             "trimmed_mean": 26,
#             "variance": 1617
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 7052,
#             "max": 123000,
#             "mean": 310,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3730,
#             "standard_deviation": 3730,
#             "trimmed_mean": 6,
#             "variance": 13916058
#         },
#         "model": "Highlander",
#         "price_stats": {
#             "geometric_mean": 48415,
#             "iqr": 5670,
#             "listings_count": 26263,
#             "max": 86572,
#             "mean": 48598,
#             "median": 47643,
#             "min": 7990,
#             "population_standard_deviation": 4141,
#             "standard_deviation": 4141,
#             "trimmed_mean": 48501,
#             "variance": 17149753
#         }
#     },
#     {
#         "count": 26852,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 32,
#             "iqr": 46,
#             "listings_count": 0,
#             "max": 685,
#             "mean": 49,
#             "median": 35,
#             "min": 1,
#             "population_standard_deviation": 48,
#             "standard_deviation": 48,
#             "trimmed_mean": 40,
#             "variance": 2304
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 21386,
#             "max": 668000,
#             "mean": 112,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 4741,
#             "standard_deviation": 4741,
#             "trimmed_mean": 10,
#             "variance": 22478527
#         },
#         "model": "Telluride",
#         "price_stats": {
#             "geometric_mean": 47356,
#             "iqr": 9240,
#             "listings_count": 26246,
#             "max": 68995,
#             "mean": 47656,
#             "median": 48060,
#             "min": 26997,
#             "population_standard_deviation": 5294,
#             "standard_deviation": 5294,
#             "trimmed_mean": 47766,
#             "variance": 28027575
#         }
#     },
#     {
#         "count": 25811,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 27,
#             "iqr": 27,
#             "listings_count": 0,
#             "max": 388,
#             "mean": 34,
#             "median": 30,
#             "min": 1,
#             "population_standard_deviation": 25,
#             "standard_deviation": 25,
#             "trimmed_mean": 32,
#             "variance": 645
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 5367,
#             "max": 22040,
#             "mean": 71,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 713,
#             "standard_deviation": 713,
#             "trimmed_mean": 6,
#             "variance": 508004
#         },
#         "model": "Grand Highlander",
#         "price_stats": {
#             "geometric_mean": 53250,
#             "iqr": 8116,
#             "listings_count": 24705,
#             "max": 83988,
#             "mean": 53463,
#             "median": 54470,
#             "min": 34787,
#             "population_standard_deviation": 4762,
#             "standard_deviation": 4762,
#             "trimmed_mean": 53405,
#             "variance": 22675480
#         }
#     },
#     {
#         "count": 25384,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 64,
#             "iqr": 80,
#             "listings_count": 0,
#             "max": 1080,
#             "mean": 87,
#             "median": 72,
#             "min": 1,
#             "population_standard_deviation": 63,
#             "standard_deviation": 63,
#             "trimmed_mean": 79,
#             "variance": 3991
#         },
#         "make": "Hyundai",
#         "miles_stats": {
#             "geometric_mean": 12,
#             "iqr": 9,
#             "listings_count": 19127,
#             "max": 100000,
#             "mean": 102,
#             "median": 11,
#             "min": 1,
#             "population_standard_deviation": 1360,
#             "standard_deviation": 1360,
#             "trimmed_mean": 12,
#             "variance": 1849445
#         },
#         "model": "Palisade",
#         "price_stats": {
#             "geometric_mean": 49343,
#             "iqr": 7139,
#             "listings_count": 24834,
#             "max": 595725,
#             "mean": 49579,
#             "median": 50130,
#             "min": 25238,
#             "population_standard_deviation": 5757,
#             "standard_deviation": 5757,
#             "trimmed_mean": 49763,
#             "variance": 33143318
#         }
#     },
#     {
#         "count": 25144,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 39,
#             "iqr": 53,
#             "listings_count": 0,
#             "max": 1506,
#             "mean": 55,
#             "median": 42,
#             "min": 1,
#             "population_standard_deviation": 47,
#             "standard_deviation": 47,
#             "trimmed_mean": 49,
#             "variance": 2196
#         },
#         "make": "Chevrolet",
#         "miles_stats": {
#             "geometric_mean": 7,
#             "iqr": 8,
#             "listings_count": 17687,
#             "max": 954659,
#             "mean": 152,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 7813,
#             "standard_deviation": 7813,
#             "trimmed_mean": 8,
#             "variance": 61040377
#         },
#         "model": "Colorado",
#         "price_stats": {
#             "geometric_mean": 41796,
#             "iqr": 8046,
#             "listings_count": 24413,
#             "max": 77010,
#             "mean": 42269,
#             "median": 42150,
#             "min": 5500,
#             "population_standard_deviation": 6336,
#             "standard_deviation": 6336,
#             "trimmed_mean": 42116,
#             "variance": 40145912
#         }
#     },
#     {
#         "count": 23239,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 64,
#             "iqr": 61,
#             "listings_count": 0,
#             "max": 795,
#             "mean": 79,
#             "median": 64,
#             "min": 1,
#             "population_standard_deviation": 53,
#             "standard_deviation": 53,
#             "trimmed_mean": 72,
#             "variance": 2844
#         },
#         "make": "Mazda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 17150,
#             "max": 42669,
#             "mean": 45,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 588,
#             "standard_deviation": 588,
#             "trimmed_mean": 7,
#             "variance": 345266
#         },
#         "model": "CX-50",
#         "price_stats": {
#             "geometric_mean": 35156,
#             "iqr": 7232,
#             "listings_count": 22760,
#             "max": 61390,
#             "mean": 35471,
#             "median": 33995,
#             "min": 22977,
#             "population_standard_deviation": 4849,
#             "standard_deviation": 4849,
#             "trimmed_mean": 35054,
#             "variance": 23512219
#         }
#     },
#     {
#         "count": 22451,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 39,
#             "iqr": 35,
#             "listings_count": 0,
#             "max": 1406,
#             "mean": 51,
#             "median": 42,
#             "min": 1,
#             "population_standard_deviation": 44,
#             "standard_deviation": 44,
#             "trimmed_mean": 44,
#             "variance": 1970
#         },
#         "make": "Toyota",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 7,
#             "listings_count": 8317,
#             "max": 115683,
#             "mean": 211,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 3216,
#             "standard_deviation": 3216,
#             "trimmed_mean": 6,
#             "variance": 10340152
#         },
#         "model": "4Runner",
#         "price_stats": {
#             "geometric_mean": 51042,
#             "iqr": 5505,
#             "listings_count": 21418,
#             "max": 82995,
#             "mean": 51236,
#             "median": 51049,
#             "min": 5084,
#             "population_standard_deviation": 4367,
#             "standard_deviation": 4367,
#             "trimmed_mean": 51204,
#             "variance": 19067098
#         }
#     },
#     {
#         "count": 22002,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 64,
#             "iqr": 99,
#             "listings_count": 0,
#             "max": 1159,
#             "mean": 98,
#             "median": 69,
#             "min": 1,
#             "population_standard_deviation": 87,
#             "standard_deviation": 87,
#             "trimmed_mean": 85,
#             "variance": 7600
#         },
#         "make": "Ford",
#         "miles_stats": {
#             "geometric_mean": 14,
#             "iqr": 21,
#             "listings_count": 12682,
#             "max": 83642,
#             "mean": 145,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 1562,
#             "standard_deviation": 1562,
#             "trimmed_mean": 18,
#             "variance": 2439879
#         },
#         "model": "Bronco 4-Door",
#         "price_stats": {
#             "geometric_mean": 59612,
#             "iqr": 14550,
#             "listings_count": 20914,
#             "max": 761071,
#             "mean": 61123,
#             "median": 57775,
#             "min": 15240,
#             "population_standard_deviation": 16023,
#             "standard_deviation": 16023,
#             "trimmed_mean": 58861,
#             "variance": 256726746
#         }
#     },
#     {
#         "count": 21587,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 32,
#             "iqr": 30,
#             "listings_count": 0,
#             "max": 1055,
#             "mean": 48,
#             "median": 32,
#             "min": 1,
#             "population_standard_deviation": 56,
#             "standard_deviation": 56,
#             "trimmed_mean": 36,
#             "variance": 3081
#         },
#         "make": "Lexus",
#         "miles_stats": {
#             "geometric_mean": 8,
#             "iqr": 5,
#             "listings_count": 10699,
#             "max": 154099,
#             "mean": 203,
#             "median": 7,
#             "min": 1,
#             "population_standard_deviation": 2974,
#             "standard_deviation": 2974,
#             "trimmed_mean": 8,
#             "variance": 8843427
#         },
#         "model": "RX",
#         "price_stats": {
#             "geometric_mean": 59011,
#             "iqr": 6510,
#             "listings_count": 20754,
#             "max": 125660,
#             "mean": 59238,
#             "median": 59065,
#             "min": 7877,
#             "population_standard_deviation": 4944,
#             "standard_deviation": 4944,
#             "trimmed_mean": 59180,
#             "variance": 24441857
#         }
#     },
#     {
#         "count": 21378,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 39,
#             "iqr": 59,
#             "listings_count": 0,
#             "max": 1448,
#             "mean": 61,
#             "median": 43,
#             "min": 1,
#             "population_standard_deviation": 63,
#             "standard_deviation": 63,
#             "trimmed_mean": 51,
#             "variance": 3952
#         },
#         "make": "Kia",
#         "miles_stats": {
#             "geometric_mean": 10,
#             "iqr": 9,
#             "listings_count": 17205,
#             "max": 140000,
#             "mean": 198,
#             "median": 10,
#             "min": 1,
#             "population_standard_deviation": 2418,
#             "standard_deviation": 2418,
#             "trimmed_mean": 10,
#             "variance": 5847613
#         },
#         "model": "Sorento",
#         "price_stats": {
#             "geometric_mean": 40982,
#             "iqr": 7615,
#             "listings_count": 20875,
#             "max": 69425,
#             "mean": 41320,
#             "median": 40890,
#             "min": 7999,
#             "population_standard_deviation": 5249,
#             "standard_deviation": 5249,
#             "trimmed_mean": 41254,
#             "variance": 27552844
#         }
#     },
#     {
#         "count": 21145,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 97,
#             "iqr": 88,
#             "listings_count": 0,
#             "max": 1172,
#             "mean": 123,
#             "median": 94,
#             "min": 1,
#             "population_standard_deviation": 94,
#             "standard_deviation": 94,
#             "trimmed_mean": 106,
#             "variance": 8925
#         },
#         "make": "Jeep",
#         "miles_stats": {
#             "geometric_mean": 16,
#             "iqr": 9,
#             "listings_count": 13391,
#             "max": 118856,
#             "mean": 269,
#             "median": 12,
#             "min": 1,
#             "population_standard_deviation": 2389,
#             "standard_deviation": 2389,
#             "trimmed_mean": 15,
#             "variance": 5705726
#         },
#         "model": "Compass",
#         "price_stats": {
#             "geometric_mean": 32718,
#             "iqr": 6062,
#             "listings_count": 20667,
#             "max": 66885,
#             "mean": 33032,
#             "median": 33511,
#             "min": 5898,
#             "population_standard_deviation": 4475,
#             "standard_deviation": 4475,
#             "trimmed_mean": 33083,
#             "variance": 20024367
#         }
#     },
#     {
#         "count": 20932,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 114,
#             "iqr": 145,
#             "listings_count": 0,
#             "max": 1053,
#             "mean": 150,
#             "median": 124,
#             "min": 1,
#             "population_standard_deviation": 104,
#             "standard_deviation": 104,
#             "trimmed_mean": 138,
#             "variance": 10898
#         },
#         "make": "RAM",
#         "miles_stats": {
#             "geometric_mean": 14,
#             "iqr": 12,
#             "listings_count": 12158,
#             "max": 116415,
#             "mean": 122,
#             "median": 13,
#             "min": 1,
#             "population_standard_deviation": 2111,
#             "standard_deviation": 2111,
#             "trimmed_mean": 15,
#             "variance": 4455580
#         },
#         "model": "Ram 2500 Pickup",
#         "price_stats": {
#             "geometric_mean": 65435,
#             "iqr": 17123,
#             "listings_count": 19292,
#             "max": 123080,
#             "mean": 66512,
#             "median": 65708,
#             "min": 5800,
#             "population_standard_deviation": 12053,
#             "standard_deviation": 12053,
#             "trimmed_mean": 65941,
#             "variance": 145284316
#         }
#     },
#     {
#         "count": 20520,
#         "country": "us",
#         "dom_stats": {
#             "geometric_mean": 30,
#             "iqr": 37,
#             "listings_count": 0,
#             "max": 1805,
#             "mean": 45,
#             "median": 31,
#             "min": 1,
#             "population_standard_deviation": 52,
#             "standard_deviation": 52,
#             "trimmed_mean": 36,
#             "variance": 2748
#         },
#         "make": "Honda",
#         "miles_stats": {
#             "geometric_mean": 6,
#             "iqr": 6,
#             "listings_count": 15258,
#             "max": 101012,
#             "mean": 62,
#             "median": 5,
#             "min": 1,
#             "population_standard_deviation": 1527,
#             "standard_deviation": 1527,
#             "trimmed_mean": 7,
#             "variance": 2331330
#         },
#         "model": "Civic Hatchback",
#         "price_stats": {
#             "geometric_mean": 29579,
#             "iqr": 3600,
#             "listings_count": 19095,
#             "max": 69995,
#             "mean": 29887,
#             "median": 27900,
#             "min": 5580,
#             "population_standard_deviation": 4784,
#             "standard_deviation": 4784,
#             "trimmed_mean": 29040,
#             "variance": 22882288
#         }
#     }
# ]

# %%
top50_df = pd.DataFrame(response)
top50_df
# df_expanded = pd.concat([top50_df.drop(['price_stats'], axis=1), top50_df['price_stats'].apply(pd.Series)], axis=1)
# df_expanded = pd.concat([top50_df.drop(['miles_stats'], axis=1), top50_df['miles_stats'].apply(pd.Series)], axis=1)
# df_expanded = pd.concat([top50_df.drop(['dom_stats'], axis=1), top50_df['dom_stats'].apply(pd.Series)], axis=1)

# top50_df = pd.DataFrame(data_dict)
# Out:
#    country   count       make             model  \
# 0       us  130243     Toyota              RAV4
# 1       us  100180      Honda              CR-V
# 2       us   90182       Ford             F-150
# 3       us   87978  Chevrolet    Silverado 1500
# 4       us   84085     Toyota             Camry
# 5       us   72847     Toyota            Tacoma
# 6       us   63018     Toyota           Corolla
# 7       us   59819     Toyota            Tundra
# 8       us   58530  Chevrolet              Trax
# 9       us   45637     Subaru         Crosstrek
# 10      us   44794    Hyundai            Tucson
# 11      us   43208     Subaru           Outback
# 12      us   42352      Honda             Civic
# 13      us   42102        GMC       Sierra 1500
# 14      us   40428      Honda            Accord
# 15      us   39967     Nissan             Rogue
# 16      us   38165        Kia          Sportage
# 17      us   37292      Honda              HR-V
# 18      us   36961     Toyota     Corolla Cross
# 19      us   36404      Honda             Pilot
# 20      us   35046    Hyundai           Elantra
# 21      us   34562       Ford          Explorer
# 22      us   34265       Ford      Bronco Sport
# 23      us   33385     Nissan            Sentra
# 24      us   32116      Mazda              CX-5
# 25      us   32116  Chevrolet           Equinox
# 26      us   30943     Subaru          Forester
# 27      us   30890        Kia             Forte
# 28      us   29885        RAM   Ram 1500 Pickup
# 29      us   29105       Ford            Escape
# 30      us   28987  Chevrolet       Trailblazer
# 31      us   28786    Hyundai          Santa Fe
# 32      us   28579  Chevrolet          Traverse
# 33      us   28447       Ford          Maverick
# 34      us   28056       Jeep    Grand Cherokee
# 35      us   28001       Ford  F-250 Super Duty
# 36      us   27645  Chevrolet  Silverado 2500HD
# 37      us   27463     Toyota        Highlander
# 38      us   26852        Kia         Telluride
# 39      us   25811     Toyota  Grand Highlander
# 40      us   25384    Hyundai          Palisade
# 41      us   25144  Chevrolet          Colorado
# 42      us   23239      Mazda             CX-50
# 43      us   22451     Toyota           4Runner
# 44      us   22002       Ford     Bronco 4-Door
# 45      us   21587      Lexus                RX
# 46      us   21378        Kia           Sorento
# 47      us   21145       Jeep           Compass
# 48      us   20932        RAM   Ram 2500 Pickup
# 49      us   20520      Honda   Civic Hatchback
#
#                                           price_stats  \
# 0   {'geometric_mean': 37359, 'listings_count': 12...
# 1   {'geometric_mean': 37651, 'listings_count': 94...
# 2   {'geometric_mean': 58395, 'listings_count': 84...
# 3   {'geometric_mean': 54091, 'listings_count': 85...
# 4   {'geometric_mean': 35141, 'listings_count': 80...
# 5   {'geometric_mean': 46917, 'listings_count': 70...
# 6   {'geometric_mean': 25300, 'listings_count': 60...
# 7   {'geometric_mean': 61841, 'listings_count': 57...
# 8   {'geometric_mean': 24920, 'listings_count': 54...
# 9   {'geometric_mean': 31772, 'listings_count': 44...
# 10  {'geometric_mean': 35104, 'listings_count': 43...
# 11  {'geometric_mean': 38130, 'listings_count': 42...
# 12  {'geometric_mean': 27725, 'listings_count': 39...
# 13  {'geometric_mean': 58844, 'listings_count': 41...
# 14  {'geometric_mean': 33016, 'listings_count': 38...
# 15  {'geometric_mean': 34380, 'listings_count': 38...
# 16  {'geometric_mean': 34869, 'listings_count': 37...
# 17  {'geometric_mean': 29295, 'listings_count': 35...
# 18  {'geometric_mean': 31456, 'listings_count': 35...
# 19  {'geometric_mean': 49553, 'listings_count': 34...
# 20  {'geometric_mean': 25788, 'listings_count': 34...
# 21  {'geometric_mean': 48786, 'listings_count': 32...
# 22  {'geometric_mean': 33426, 'listings_count': 33...
# 23  {'geometric_mean': 23242, 'listings_count': 32...
# 24  {'geometric_mean': 33337, 'listings_count': 31...
# 25  {'geometric_mean': 30792, 'listings_count': 31...
# 26  {'geometric_mean': 36456, 'listings_count': 30...
# 27  {'geometric_mean': 22485, 'listings_count': 30...
# 28  {'geometric_mean': 59097, 'listings_count': 29...
# 29  {'geometric_mean': 33478, 'listings_count': 27...
# 30  {'geometric_mean': 28313, 'listings_count': 28...
# 31  {'geometric_mean': 43646, 'listings_count': 27...
# 32  {'geometric_mean': 47555, 'listings_count': 27...
# 33  {'geometric_mean': 32032, 'listings_count': 26...
# 34  {'geometric_mean': 49594, 'listings_count': 27...
# 35  {'geometric_mean': 69571, 'listings_count': 26...
# 36  {'geometric_mean': 64978, 'listings_count': 26...
# 37  {'geometric_mean': 48415, 'listings_count': 26...
# 38  {'geometric_mean': 47356, 'listings_count': 26...
# 39  {'geometric_mean': 53250, 'listings_count': 24...
# 40  {'geometric_mean': 49343, 'listings_count': 24...
# 41  {'geometric_mean': 41796, 'listings_count': 24...
# 42  {'geometric_mean': 35156, 'listings_count': 22...
# 43  {'geometric_mean': 51042, 'listings_count': 21...
# 44  {'geometric_mean': 59612, 'listings_count': 20...
# 45  {'geometric_mean': 59011, 'listings_count': 20...
# 46  {'geometric_mean': 40982, 'listings_count': 20...
# 47  {'geometric_mean': 32718, 'listings_count': 20...
# 48  {'geometric_mean': 65435, 'listings_count': 19...
# 49  {'geometric_mean': 29579, 'listings_count': 19...
#
#                                           miles_stats  \
# 0   {'geometric_mean': 6, 'listings_count': 33450,...
# 1   {'geometric_mean': 7, 'listings_count': 74781,...
# 2   {'geometric_mean': 22, 'listings_count': 53181...
# 3   {'geometric_mean': 10, 'listings_count': 63799...
# 4   {'geometric_mean': 6, 'listings_count': 18903,...
# 5   {'geometric_mean': 6, 'listings_count': 18806,...
# 6   {'geometric_mean': 5, 'listings_count': 14370,...
# 7   {'geometric_mean': 6, 'listings_count': 17254,...
# 8   {'geometric_mean': 7, 'listings_count': 40243,...
# 9   {'geometric_mean': 5, 'listings_count': 18215,...
# 10  {'geometric_mean': 12, 'listings_count': 33165...
# 11  {'geometric_mean': 6, 'listings_count': 17007,...
# 12  {'geometric_mean': 6, 'listings_count': 30916,...
# 13  {'geometric_mean': 9, 'listings_count': 30342,...
# 14  {'geometric_mean': 7, 'listings_count': 30009,...
# 15  {'geometric_mean': 7, 'listings_count': 28383,...
# 16  {'geometric_mean': 10, 'listings_count': 30270...
# 17  {'geometric_mean': 7, 'listings_count': 27982,...
# 18  {'geometric_mean': 5, 'listings_count': 8923, ...
# 19  {'geometric_mean': 7, 'listings_count': 27368,...
# 20  {'geometric_mean': 11, 'listings_count': 26319...
# 21  {'geometric_mean': 38, 'listings_count': 21295...
# 22  {'geometric_mean': 26, 'listings_count': 20749...
# 23  {'geometric_mean': 7, 'listings_count': 24587,...
# 24  {'geometric_mean': 6, 'listings_count': 23752,...
# 25  {'geometric_mean': 10, 'listings_count': 21593...
# 26  {'geometric_mean': 5, 'listings_count': 12738,...
# 27  {'geometric_mean': 10, 'listings_count': 24537...
# 28  {'geometric_mean': 20, 'listings_count': 17932...
# 29  {'geometric_mean': 27, 'listings_count': 17166...
# 30  {'geometric_mean': 8, 'listings_count': 20923,...
# 31  {'geometric_mean': 13, 'listings_count': 21173...
# 32  {'geometric_mean': 7, 'listings_count': 18081,...
# 33  {'geometric_mean': 11, 'listings_count': 15772...
# 34  {'geometric_mean': 17, 'listings_count': 17490...
# 35  {'geometric_mean': 12, 'listings_count': 16074...
# 36  {'geometric_mean': 10, 'listings_count': 19359...
# 37  {'geometric_mean': 6, 'listings_count': 7052, ...
# 38  {'geometric_mean': 10, 'listings_count': 21386...
# 39  {'geometric_mean': 6, 'listings_count': 5367, ...
# 40  {'geometric_mean': 12, 'listings_count': 19127...
# 41  {'geometric_mean': 7, 'listings_count': 17687,...
# 42  {'geometric_mean': 6, 'listings_count': 17150,...
# 43  {'geometric_mean': 6, 'listings_count': 8317, ...
# 44  {'geometric_mean': 14, 'listings_count': 12682...
# 45  {'geometric_mean': 8, 'listings_count': 10699,...
# 46  {'geometric_mean': 10, 'listings_count': 17205...
# 47  {'geometric_mean': 16, 'listings_count': 13391...
# 48  {'geometric_mean': 14, 'listings_count': 12158...
# 49  {'geometric_mean': 6, 'listings_count': 15258,...
#
#                                             dom_stats
# 0   {'geometric_mean': 22, 'listings_count': 0, 'm...
# 1   {'geometric_mean': 29, 'listings_count': 0, 'm...
# 2   {'geometric_mean': 58, 'listings_count': 0, 'm...
# 3   {'geometric_mean': 74, 'listings_count': 0, 'm...
# 4   {'geometric_mean': 20, 'listings_count': 0, 'm...
# 5   {'geometric_mean': 33, 'listings_count': 0, 'm...
# 6   {'geometric_mean': 22, 'listings_count': 0, 'm...
# 7   {'geometric_mean': 40, 'listings_count': 0, 'm...
# 8   {'geometric_mean': 31, 'listings_count': 0, 'm...
# 9   {'geometric_mean': 50, 'listings_count': 0, 'm...
# 10  {'geometric_mean': 53, 'listings_count': 0, 'm...
# 11  {'geometric_mean': 64, 'listings_count': 0, 'm...
# 12  {'geometric_mean': 26, 'listings_count': 0, 'm...
# 13  {'geometric_mean': 65, 'listings_count': 0, 'm...
# 14  {'geometric_mean': 40, 'listings_count': 0, 'm...
# 15  {'geometric_mean': 62, 'listings_count': 0, 'm...
# 16  {'geometric_mean': 36, 'listings_count': 0, 'm...
# 17  {'geometric_mean': 46, 'listings_count': 0, 'm...
# 18  {'geometric_mean': 25, 'listings_count': 0, 'm...
# 19  {'geometric_mean': 38, 'listings_count': 0, 'm...
# 20  {'geometric_mean': 60, 'listings_count': 0, 'm...
# 21  {'geometric_mean': 94, 'listings_count': 0, 'm...
# 22  {'geometric_mean': 79, 'listings_count': 0, 'm...
# 23  {'geometric_mean': 77, 'listings_count': 0, 'm...
# 24  {'geometric_mean': 97, 'listings_count': 0, 'm...
# 25  {'geometric_mean': 59, 'listings_count': 0, 'm...
# 26  {'geometric_mean': 43, 'listings_count': 0, 'm...
# 27  {'geometric_mean': 32, 'listings_count': 0, 'm...
# 28  {'geometric_mean': 116, 'listings_count': 0, '...
# 29  {'geometric_mean': 70, 'listings_count': 0, 'm...
# 30  {'geometric_mean': 50, 'listings_count': 0, 'm...
# 31  {'geometric_mean': 39, 'listings_count': 0, 'm...
# 32  {'geometric_mean': 22, 'listings_count': 0, 'm...
# 33  {'geometric_mean': 26, 'listings_count': 0, 'm...
# 34  {'geometric_mean': 83, 'listings_count': 0, 'm...
# 35  {'geometric_mean': 54, 'listings_count': 0, 'm...
# 36  {'geometric_mean': 49, 'listings_count': 0, 'm...
# 37  {'geometric_mean': 22, 'listings_count': 0, 'm...
# 38  {'geometric_mean': 32, 'listings_count': 0, 'm...
# 39  {'geometric_mean': 27, 'listings_count': 0, 'm...
# 40  {'geometric_mean': 64, 'listings_count': 0, 'm...
# 41  {'geometric_mean': 39, 'listings_count': 0, 'm...
# 42  {'geometric_mean': 64, 'listings_count': 0, 'm...
# 43  {'geometric_mean': 39, 'listings_count': 0, 'm...
# 44  {'geometric_mean': 64, 'listings_count': 0, 'm...
# 45  {'geometric_mean': 32, 'listings_count': 0, 'm...
# 46  {'geometric_mean': 39, 'listings_count': 0, 'm...
# 47  {'geometric_mean': 97, 'listings_count': 0, 'm...
# 48  {'geometric_mean': 114, 'listings_count': 0, '...
# 49  {'geometric_mean': 30, 'listings_count': 0, 'm...

# %%
df_expanded = pd.concat([top50_df.drop(['price_stats'], axis=1), top50_df['price_stats'].apply(pd.Series)], axis=1)
df_expanded = df_expanded.drop("miles_stats", axis=1)
df_expanded = df_expanded.drop("dom_stats", axis=1)
df_expanded
# Out:
#    country   count       make             model  geometric_mean  \
# 0       us  130243     Toyota              RAV4           37359
# 1       us  100180      Honda              CR-V           37651
# 2       us   90182       Ford             F-150           58395
# 3       us   87978  Chevrolet    Silverado 1500           54091
# 4       us   84085     Toyota             Camry           35141
# 5       us   72847     Toyota            Tacoma           46917
# 6       us   63018     Toyota           Corolla           25300
# 7       us   59819     Toyota            Tundra           61841
# 8       us   58530  Chevrolet              Trax           24920
# 9       us   45637     Subaru         Crosstrek           31772
# 10      us   44794    Hyundai            Tucson           35104
# 11      us   43208     Subaru           Outback           38130
# 12      us   42352      Honda             Civic           27725
# 13      us   42102        GMC       Sierra 1500           58844
# 14      us   40428      Honda            Accord           33016
# 15      us   39967     Nissan             Rogue           34380
# 16      us   38165        Kia          Sportage           34869
# 17      us   37292      Honda              HR-V           29295
# 18      us   36961     Toyota     Corolla Cross           31456
# 19      us   36404      Honda             Pilot           49553
# 20      us   35046    Hyundai           Elantra           25788
# 21      us   34562       Ford          Explorer           48786
# 22      us   34265       Ford      Bronco Sport           33426
# 23      us   33385     Nissan            Sentra           23242
# 24      us   32116      Mazda              CX-5           33337
# 25      us   32116  Chevrolet           Equinox           30792
# 26      us   30943     Subaru          Forester           36456
# 27      us   30890        Kia             Forte           22485
# 28      us   29885        RAM   Ram 1500 Pickup           59097
# 29      us   29105       Ford            Escape           33478
# 30      us   28987  Chevrolet       Trailblazer           28313
# 31      us   28786    Hyundai          Santa Fe           43646
# 32      us   28579  Chevrolet          Traverse           47555
# 33      us   28447       Ford          Maverick           32032
# 34      us   28056       Jeep    Grand Cherokee           49594
# 35      us   28001       Ford  F-250 Super Duty           69571
# 36      us   27645  Chevrolet  Silverado 2500HD           64978
# 37      us   27463     Toyota        Highlander           48415
# 38      us   26852        Kia         Telluride           47356
# 39      us   25811     Toyota  Grand Highlander           53250
# 40      us   25384    Hyundai          Palisade           49343
# 41      us   25144  Chevrolet          Colorado           41796
# 42      us   23239      Mazda             CX-50           35156
# 43      us   22451     Toyota           4Runner           51042
# 44      us   22002       Ford     Bronco 4-Door           59612
# 45      us   21587      Lexus                RX           59011
# 46      us   21378        Kia           Sorento           40982
# 47      us   21145       Jeep           Compass           32718
# 48      us   20932        RAM   Ram 2500 Pickup           65435
# 49      us   20520      Honda   Civic Hatchback           29579
#
#     listings_count    min  median  population_standard_deviation   variance  \
# 0           124603   9988   36768                           4952   24524202
# 1            94027   5936   37850                           3274   10721259
# 2            84939   5250   57405                          14650  214608035
# 3            85993   5995   54435                          10177  103573151
# 4            80627   5999   34638                           3616   13078946
# 5            70017  11289   46624                           6092   37117152
# 6            60619   7985   24810                           2064    4261941
# 7            57842   6950   61935                           7618   58040067
# 8            54950   5250   25035                           1977    3910304
# 9            44665  12500   31667                           3805   14477512
# 10           43554   6999   34739                           4384   19221705
# 11           42274   5018   38627                           4481   20076817
# 12           39485   5081   27345                           2179    4747567
# 13           41147   6750   60126                          11891  141390713
# 14           38338   5697   32300                           3597   12939739
# 15           38780   6980   34305                           4041   16330294
# 16           37145  12565   34840                           7919   62716044
# 17           35321   5041   29480                           2052    4208764
# 18           35317  21806   31938                           3117    9714299
# 19           34652   5835   50495                           5090   25910287
# 20           34195   9598   25295                           2883    8313379
# 21           32889   5762   48560                           6911   47759308
# 22           33108  21676   33160                           3942   15541110
# 23           32356   6000   23240                           2400    5761199
# 24           31461  12977   32740                           3332   11105379
# 25           31390   7500   30991                           3723   13860827
# 26           30156   9779   36221                           3392   11502998
# 27           30078   6995   22070                           3532   12475938
# 28           29054   5900   58813                          14198  201571875
# 29           27794   5250   33160                           4740   22471163
# 30           28106   5250   28290                           3332   11104939
# 31           27990   8988   45155                           5205   27089353
# 32           27879   5995   47160                           6561   43042767
# 33           26223  23410   31685                           5961   35532611
# 34           27391  11249   48700                           8719   76024943
# 35           26211  19988   68655                          17056  290913901
# 36           26664  19995   64212                          11925  142210117
# 37           26263   7990   47643                           4141   17149753
# 38           26246  26997   48060                           5294   28027575
# 39           24705  34787   54470                           4762   22675480
# 40           24834  25238   50130                           5757   33143318
# 41           24413   5500   42150                           6336   40145912
# 42           22760  22977   33995                           4849   23512219
# 43           21418   5084   51049                           4367   19067098
# 44           20914  15240   57775                          16023  256726746
# 45           20754   7877   59065                           4944   24441857
# 46           20875   7999   40890                           5249   27552844
# 47           20667   5898   33511                           4475   20024367
# 48           19292   5800   65708                          12053  145284316
# 49           19095   5580   27900                           4784   22882288
#
#        max   mean  trimmed_mean  standard_deviation    iqr
# 0    63313  37664         37159                4952   6008
# 1   387000  37779         37833                3274   4395
# 2   214335  59938         58422               14650  16367
# 3   681000  54933         54673               10177  13609
# 4    80350  35323         35135                3616   4953
# 5    89995  47297         47032                6092   7933
# 6    55306  25379         25157                2064   2719
# 7   324849  62294         61984                7618  10521
# 8   256230  24984         25060                1977   2453
# 9   362227  31940         31966                3805   5233
# 10  345550  35348         35230                4384   6064
# 11  378044  38371         38433                4481   6924
# 12   46645  27813         27592                2179   1400
# 13  900060  59914         59828               11891  14502
# 14   56349  33211         32925                3597   4630
# 15   66750  34615         34445                4041   4835
# 16  750202  35170         34771                7919   5272
# 17  162185  29364         29346                2052   2455
# 18   49710  31612         31655                3117   4531
# 19  571365  49757         49802                5090   6085
# 20   54490  25936         25611                2883   3225
# 21   81806  49276         49100                6911   8987
# 22   65565  33651         33447                3942   5168
# 23   55344  23364         23288                2400   2916
# 24   51768  33495         33157                3332   3694
# 25   59270  31024         31032                3723   4506
# 26   49995  36617         36649                3392   4948
# 27  326750  22610         22418                3532   2870
# 28  200265  60479         59029               14198  13811
# 29  366660  33758         33410                4740   4532
# 30  304400  28468         28377                3332   4295
# 31   65800  43970         44186                5205   9053
# 32   93305  48002         47859                6561  11660
# 33  363300  32371         32027                5961   7395
# 34   95937  50315         49606                8719  10565
# 35  213161  71509         70614               17056  28500
# 36  128422  66019         65259               11925  18625
# 37   86572  48598         48501                4141   5670
# 38   68995  47656         47766                5294   9240
# 39   83988  53463         53405                4762   8116
# 40  595725  49579         49763                5757   7139
# 41   77010  42269         42116                6336   8046
# 42   61390  35471         35054                4849   7232
# 43   82995  51236         51204                4367   5505
# 44  761071  61123         58861               16023  14550
# 45  125660  59238         59180                4944   6510
# 46   69425  41320         41254                5249   7615
# 47   66885  33032         33083                4475   6062
# 48  123080  66512         65941               12053  17123
# 49   69995  29887         29040                4784   3600

# %%
top5_2024 = df_expanded.head(10)
top5_2024
# Out:
#   country   count       make           model  geometric_mean  listings_count  \
# 0      us  130243     Toyota            RAV4           37359          124603
# 1      us  100180      Honda            CR-V           37651           94027
# 2      us   90182       Ford           F-150           58395           84939
# 3      us   87978  Chevrolet  Silverado 1500           54091           85993
# 4      us   84085     Toyota           Camry           35141           80627
# 5      us   72847     Toyota          Tacoma           46917           70017
# 6      us   63018     Toyota         Corolla           25300           60619
# 7      us   59819     Toyota          Tundra           61841           57842
# 8      us   58530  Chevrolet            Trax           24920           54950
# 9      us   45637     Subaru       Crosstrek           31772           44665
#
#      min  median  population_standard_deviation   variance     max   mean  \
# 0   9988   36768                           4952   24524202   63313  37664
# 1   5936   37850                           3274   10721259  387000  37779
# 2   5250   57405                          14650  214608035  214335  59938
# 3   5995   54435                          10177  103573151  681000  54933
# 4   5999   34638                           3616   13078946   80350  35323
# 5  11289   46624                           6092   37117152   89995  47297
# 6   7985   24810                           2064    4261941   55306  25379
# 7   6950   61935                           7618   58040067  324849  62294
# 8   5250   25035                           1977    3910304  256230  24984
# 9  12500   31667                           3805   14477512  362227  31940
#
#    trimmed_mean  standard_deviation    iqr
# 0         37159                4952   6008
# 1         37833                3274   4395
# 2         58422               14650  16367
# 3         54673               10177  13609
# 4         35135                3616   4953
# 5         47032                6092   7933
# 6         25157                2064   2719
# 7         61984                7618  10521
# 8         25060                1977   2453
# 9         31966                3805   5233

# %%
plt.figure(figsize=(12, 6))
plt.bar(top5_2024['model'], top5_2024['count'], color=colors)
plt.title('Top 10 2024 Models sold in the current year')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
Make_top_50 = df_expanded['make'].value_counts()
Make_top_50
plt.title("Share of Makes in the Top 50 Cars of the US 2024")
plt.pie(Make_top_50, labels=Make_top_50.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
# Out:
# (-1.099998440490482,
#  1.0999999150793702,
#  -1.0999991497036314,
#  1.0999999595050427)

# %%
plt.figure(figsize=(10, 6))  # Set the figure size
top_5_cars = df_expanded.head(5)  # Select the top 5 cars

plt.figure(figsize=(10, 6))  # Set the figure size

plt.bar(top_5_cars['model'], top_5_cars['count'], color = colors)  # Create the bar chart for the top 5 cars

plt.xlabel('Car Model')  # Set the x-axis label
plt.ylabel('Number of Cars')  # Set the y-axis label
plt.title('Top 5 Car Models in 2024')  # Set the title

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.show()  # Display the plot

# %%
cars_clean_df = pd.read_csv('Resources/car_sales_clean.csv')
cars_clean_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0  white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0   gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0  white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0   gray
# ...             ...                ...   ...        ...       ...    ...
# 472320    automatic  wbafr1c53bc744672    fl       39.0   66403.0  white
# 472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0  white
# 472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0  black
# 472323    automatic  1n4al3ap0fc216050    ga       38.0   16658.0  white
# 472324    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 472320    brown           lauderdale imports ltd bmw pembrok pines  20300.0
# 472321    black                                    i -5 uhlmann rv  30200.0
# 472322    black             financial services remarketing (lease)  29800.0
# 472323    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 472324     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate   type
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)  Sedan
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)  Sedan
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Sedan
# ...              ...                                      ...    ...
# 472320       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)  Sedan
# 472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)  Truck
# 472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    SUV
# 472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)  Sedan
# 472324       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)  Truck
#
# [472325 rows x 17 columns]

# %%
df_by_year = {year: group for year, group in cars_clean_df.groupby('year')}
df_by_year
# Out:
# {1990:         year           make            model           trim         body  \
#  17756   1990         Toyota            Camry         Deluxe        Sedan
#  17759   1990          Honda           Accord             EX        Sedan
#  32378   1990         Toyota            Camry         Deluxe        Sedan
#  32379   1990      Chevrolet         Corvette           Base    Hatchback
#  41812   1990          Honda           Accord             LX        Sedan
#  41816   1990  Mercedes-Benz        300-Class           300E        Sedan
#  41817   1990          Lexus           LS 400           Base        Sedan
#  57280   1990          Honda           Accord             EX        Sedan
#  64529   1990         Toyota          Corolla           Base        Sedan
#  84461   1990       Cadillac          DeVille           Base        Sedan
#  108714  1990         Toyota          Corolla         Deluxe        Sedan
#  108722  1990          Lexus           LS 400           Base        Sedan
#  108723  1990         Toyota            Camry         Deluxe        Sedan
#  133328  1990          Honda           Accord             LX        Sedan
#  168919  1990          Mazda       MX-5 Miata           Base  Convertible
#  169368  1990          Honda           Accord             LX        Sedan
#  178372  1990          Lexus           LS 400           Base        Sedan
#  192577  1990          Lexus           LS 400           Base        Sedan
#  244565  1990      Chevrolet  C/K 1500 Series          454SS  Regular Cab
#  251356  1990         Nissan            300ZX             GS    Hatchback
#  269435  1990          Lexus           LS 400           Base        Sedan
#  269437  1990          Mazda       MX-5 Miata           Base  Convertible
#  306164  1990      Chevrolet  C/K 1500 Series          454SS  Regular Cab
#  324933  1990          Mazda       MX-5 Miata           Base  Convertible
#  333096  1990          Mazda       MX-5 Miata           Base  Convertible
#  337376  1990         Toyota          4Runner         SR5 V6          SUV
#  347077  1990  Mercedes-Benz        300-Class           300E        Sedan
#  368101  1990      Chevrolet         Corvette           Base    Hatchback
#  376241  1990          Mazda       MX-5 Miata           Base  Convertible
#  388421  1990          Honda           Accord             LX        Sedan
#  390869  1990         Jaguar        XJ-Series  XJ6 Sovereign        Sedan
#  462589  1990          Honda           Accord             EX        Sedan
#  467397  1990      Chevrolet         Corvette           Base    hatchback
#
#         transmission                vin state  condition  odometer  color  \
#  17756     automatic  jt2sv21exl0345999    wa        2.0  214723.0   blue
#  17759     automatic  jhmcb7661lc036504    tx        2.0   19279.0   gray
#  32378     automatic  4t1sv21e0lu227097    ca        2.0  122877.0   blue
#  32379     automatic  1g1yy2387l5108284    oh        1.0       1.0    red
#  41812     automatic  jhmcb765xlc131957    nv        1.0  183366.0   gold
#  41816     automatic  wdbea30d6lb200847    nv        2.0  141799.0  white
#  41817     automatic  jt8uf11e5l0041243    ca        3.0  106472.0  white
#  57280     automatic  jhmcb7665lc099475    az        1.0  247555.0   gray
#  64529     automatic  jt2ae91a0l3295341    or        2.0  195851.0    red
#  84461     automatic  1g6cd5333l4326699    pa        2.0  120590.0  white
#  108714    automatic  2t1ae94a8lc016373    fl        2.0  213005.0  white
#  108722    automatic  jt8uf11e4l0028791    fl        1.0  102437.0  black
#  108723    automatic  4t1sv21e3lu252866    ga        2.0  201659.0  black
#  133328       manual  1hgcb7554la154103    md        2.0   32286.0   blue
#  168919       manual  jm1na3515l0123822    ga        2.0  129102.0  white
#  169368    automatic  jhmcb7651lc020391    ca        2.0  237586.0   gold
#  178372    automatic  jt8uf11e1l0039294    ca        2.0  249117.0  black
#  192577    automatic  jt8uf11e6l0008543    md        1.0       1.0  white
#  244565    automatic  1gcdc14n4lz157583    fl        3.0  101927.0  black
#  251356       manual  jn1rz24a1lx006044    tx        1.0  181363.0    red
#  269435    automatic  jt8uf11e4l0010629    fl        2.0  221945.0  white
#  269437       manual  jm1na3513l0126525    md        2.0  119379.0   blue
#  306164    automatic  1gcdc14n5lz242061    tn        4.0   34266.0  black
#  324933       manual  jm1na3510l0124909    fl        2.0   63300.0    red
#  333096       manual  jm1na3512l0109926    ca        2.0   70370.0   blue
#  337376    automatic  jt3vn39w1l0036787    ca        1.0  206522.0    red
#  347077    automatic  wdbea30d3lb215497    tx        2.0  117082.0  white
#  368101    automatic  1g1yy2386l5118420    tx        2.0   58181.0    red
#  376241       manual  jm1na3518l0136144    fl        2.0  129347.0  white
#  388421    automatic  1hgcb7653la105991    pa        2.0  152307.0    red
#  390869    automatic  sajhy174xlc607411    ga        2.0  135657.0   blue
#  462589       manual  jhmcb7567lc044186    co        1.0  189267.0   gray
#  467397    automatic  1g1yy2385l5101074    mo        2.0  108639.0  green
#
#          interior                                 seller     mmr  sellingprice  \
#  17756       blue                     donate for charity   675.0         375.0
#  17759        tan             automotive remarketing inc   875.0         350.0
#  32378          —               charitable auto resource   700.0         400.0
#  32379        red              purple heart services inc  7850.0        2800.0
#  41812          —             automotive remarketing inc   775.0         400.0
#  41816          —             automotive remarketing inc   425.0         300.0
#  41817        tan                          illest motors   550.0         700.0
#  57280       gray                  cash time title loans   675.0         400.0
#  64529       gray              purple heart services inc   475.0         200.0
#  84461     purple                           purple heart   400.0         325.0
#  108714      gray         autonation toyota scion weston   500.0         500.0
#  108722      gray    autonation cadillac west palm beach   600.0         400.0
#  108723      gray                           purple heart   675.0         375.0
#  133328     black              purple heart services inc   725.0         300.0
#  168919     black                        five star dodge  1400.0         900.0
#  169368  burgundy                  honda of santa monica   600.0         350.0
#  178372     beige              purple heart services inc   700.0         300.0
#  192577      blue                       axcess financial   700.0         225.0
#  244565       red         american bank auto liquidators  7225.0        8000.0
#  251356       red  remarketing by ge/midsouth capital lp  1500.0         200.0
#  269435       tan           autonation ford jacksonville   575.0        1100.0
#  269437     black      manheim baltwash/junk a car scrap  1500.0         425.0
#  306164       red                           t & s motors  9550.0       11500.0
#  324933     black                     mini of fort myers  2150.0        1600.0
#  333096      gray                aaero sweet corporation  2075.0        2500.0
#  337376      gray                 premium auto wholesale   750.0         550.0
#  347077      gray                   titlemax/austin tx19   950.0         250.0
#  368101     black                      texas direct auto  6075.0        3700.0
#  376241     black              gettel toyota of lakewood  1675.0        2400.0
#  388421     beige                           purple heart   475.0         300.0
#  390869       tan                   capital auto auction   775.0         550.0
#  462589      gray             autonation subaru arapahoe   600.0         400.0
#  467397       tan                       tdaf remarketing  3875.0        4100.0
#
#                                         saledate         type
#  17756   Wed Jan 28 2015 04:30:00 GMT-0800 (PST)        Sedan
#  17759   Tue Dec 23 2014 10:00:00 GMT-0800 (PST)        Sedan
#  32378   Tue Dec 30 2014 13:00:00 GMT-0800 (PST)        Sedan
#  32379   Tue Dec 23 2014 13:00:00 GMT-0800 (PST)    Hatchback
#  41812   Thu Jan 22 2015 03:00:00 GMT-0800 (PST)        Sedan
#  41816   Thu Jan 22 2015 03:00:00 GMT-0800 (PST)        Sedan
#  41817   Wed Dec 31 2014 11:30:00 GMT-0800 (PST)        Sedan
#  57280   Wed Jan 07 2015 11:00:00 GMT-0800 (PST)        Sedan
#  64529   Tue Jan 06 2015 03:31:00 GMT-0800 (PST)        Sedan
#  84461   Tue Jan 13 2015 13:01:00 GMT-0800 (PST)        Sedan
#  108714  Tue Jan 13 2015 18:00:00 GMT-0800 (PST)        Sedan
#  108722  Tue Jan 13 2015 18:00:00 GMT-0800 (PST)        Sedan
#  108723  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)        Sedan
#  133328  Tue Jan 20 2015 04:00:00 GMT-0800 (PST)        Sedan
#  168919  Fri Jan 30 2015 03:00:00 GMT-0800 (PST)  Convertible
#  169368  Thu Jan 29 2015 04:00:00 GMT-0800 (PST)        Sedan
#  178372  Wed Feb 25 2015 07:10:00 GMT-0800 (PST)        Sedan
#  192577  Tue Feb 17 2015 05:00:00 GMT-0800 (PST)        Sedan
#  244565  Tue Feb 10 2015 01:30:00 GMT-0800 (PST)        Truck
#  251356  Thu Mar 05 2015 06:00:00 GMT-0800 (PST)    Hatchback
#  269435  Tue Feb 17 2015 10:00:00 GMT-0800 (PST)        Sedan
#  269437  Tue Feb 17 2015 05:00:00 GMT-0800 (PST)  Convertible
#  306164  Wed Mar 04 2015 02:30:00 GMT-0800 (PST)        Truck
#  324933  Tue Mar 03 2015 10:00:00 GMT-0800 (PST)  Convertible
#  333096  Wed Mar 04 2015 03:30:00 GMT-0800 (PST)  Convertible
#  337376  Thu Mar 05 2015 04:00:00 GMT-0800 (PST)          SUV
#  347077  Wed Apr 29 2015 03:00:00 GMT-0700 (PDT)        Sedan
#  368101  Thu May 28 2015 03:30:00 GMT-0700 (PDT)    Hatchback
#  376241  Thu May 21 2015 09:00:00 GMT-0700 (PDT)  Convertible
#  388421  Tue May 26 2015 06:01:00 GMT-0700 (PDT)        Sedan
#  390869  Thu May 28 2015 05:30:00 GMT-0700 (PDT)        Sedan
#  462589  Tue Jun 16 2015 05:00:00 GMT-0700 (PDT)        Sedan
#  467397  Tue Jun 16 2015 03:30:00 GMT-0700 (PDT)    Hatchback  ,
#  1991:         year           make            model       trim         body  \
#  4280    1991          Lexus           LS 400       Base        Sedan
#  17749   1991  Mercedes-Benz        500-Class      500SL  Convertible
#  17751   1991         Toyota          Corolla     Deluxe        Sedan
#  17754   1991         Nissan           Maxima        GXE        Sedan
#  17755   1991         Toyota            Camry     Deluxe        Sedan
#  32301   1991      Chevrolet         Corvette       Base  Convertible
#  32305   1991  Mercedes-Benz        500-Class      500SL  Convertible
#  32308   1991          Honda           Accord         LX        Sedan
#  41811   1991          Honda           Accord         SE        Sedan
#  41813   1991         Toyota          Corolla     Deluxe        Sedan
#  41814   1991         Toyota            Camry     Deluxe        Sedan
#  41815   1991          Mazda       MX-5 Miata       Base  Convertible
#  57265   1991         Toyota            Camry     Deluxe        Sedan
#  57268   1991          Mazda       MX-5 Miata       Base  Convertible
#  62927   1991      Chevrolet  C/K 1500 Series  Silverado  Regular Cab
#  72034   1991          Lexus           LS 400       Base        Sedan
#  108716  1991  Mercedes-Benz        300-Class      300SL  Convertible
#  108717  1991         Toyota            Camry     Deluxe        Sedan
#  108719  1991       Cadillac          DeVille       Base        Sedan
#  108720  1991      Chevrolet         Corvette       Base    Hatchback
#  114246  1991        Lincoln         Town Car  Signature        Sedan
#  124490  1991        Lincoln         Town Car  Signature        Sedan
#  124491  1991          Honda           Accord         LX        Sedan
#  124498  1991         Toyota          Corolla     Deluxe        Sedan
#  133325  1991          Honda            Civic       Base    Hatchback
#  133327  1991          Honda           Accord         LX        Sedan
#  168918  1991       Cadillac          DeVille       Base        Sedan
#  178370  1991  Mercedes-Benz        500-Class      500SL  Convertible
#  219589  1991         Toyota            Camry     Deluxe        Sedan
#  219590  1991          Honda           Accord         LX        Sedan
#  219591  1991       Cadillac          DeVille       Base        Sedan
#  257721  1991         Toyota            Camry     Deluxe        Sedan
#  269440  1991          Honda           Accord         EX        Sedan
#  281792  1991  Mercedes-Benz        500-Class      500SL  Convertible
#  283383  1991         Toyota            Camry     Deluxe        Sedan
#  319454  1991  Mercedes-Benz        300-Class       300E        Sedan
#  322074  1991         Toyota            Camry     Deluxe        Sedan
#  333094  1991            BMW         8 Series       850i        Coupe
#  333097  1991  Mercedes-Benz        420-Class     420SEL        Sedan
#  348360  1991  Mercedes-Benz        300-Class       300E        Sedan
#  376243  1991     Oldsmobile    Cutlass Ciera       Base        Sedan
#  381749  1991         Nissan            300ZX       Base    Hatchback
#  388420  1991  Mercedes-Benz        500-Class      500SL  Convertible
#  388423  1991      Chevrolet         Corvette       Base    Hatchback
#  388424  1991         Toyota            Camry     Deluxe        Sedan
#  426087  1991         Toyota          Corolla     Deluxe        wagon
#  434413  1991          Honda           Accord         EX        sedan
#  434415  1991      Chevrolet  C/K 1500 Series       Base  Regular Cab
#  462588  1991       Cadillac          DeVille       Base        sedan
#  462590  1991           Ford           Ranger          S  Regular Cab
#  462591  1991          Honda           Accord         EX        sedan
#
#         transmission                vin state  condition  odometer     color  \
#  4280      automatic  jt8uf11e5m0094008    ca        2.0  171533.0    silver
#  17749     automatic  wdbfa66e5mf030237    fl        2.0  117006.0      blue
#  17751     automatic  jt2ae94axm3443766    wa        2.0  154722.0    silver
#  17754     automatic  jn1hj01p5mt524361    fl        2.0  177167.0     black
#  17755     automatic  jt2sv21e3m3460184    ca        2.0  252591.0      gray
#  32301     automatic  1g1yy3383m5102652    ca        3.0   58049.0     black
#  32305     automatic  wdbfa66e7mf035858    ca        3.0  175568.0    silver
#  32308     automatic  1hgcb7655ma146317    md        2.0  171205.0      blue
#  41811     automatic  jhmcb7683mc096190    md        2.0  186903.0      gray
#  41813     automatic  1nxae94a7mz175093    tx        1.0  199887.0     white
#  41814     automatic  4t1sv21e8mu304686    fl        3.0  244226.0     white
#  41815     automatic  jm1na3513m1237748    nv        2.0  110154.0     white
#  57265     automatic  4t1sv21e5mu453282    md        2.0   91780.0     white
#  57268     automatic  jm1na3518m1211663    ga        2.0  246169.0       red
#  62927     automatic  1gcdc14z9mz173928    nv        2.0  117616.0     black
#  72034     automatic  jt8uf11e9m0096702    ga        2.0  189674.0     black
#  108716    automatic  wdbfa61e6mf014670    ca        3.0  112018.0       red
#  108717       manual  4t1sv21e7mu434409    sc        1.0  189563.0  burgundy
#  108719    automatic  1g6cd53b6m4241199    fl        1.0  125973.0      gray
#  108720    automatic  1g1yy238xm5116736    fl        2.0   91569.0      blue
#  114246    automatic  1lncm82w6my760695    ga        2.0  194552.0     white
#  124490    automatic  1lncm82w8my715001    nv        2.0  132993.0     black
#  124491    automatic  1hgcb7652ma183423    ca        1.0  185708.0    silver
#  124498    automatic  2t1ae94a9mc102275    md        1.0  110988.0     beige
#  133325       manual  2hged6349mh586681    fl        1.0  130708.0       red
#  133327    automatic  1hgcb765xma040008    va        1.0  238730.0     beige
#  168918    automatic  1g6cd53b3m4329899    fl        2.0   89483.0       red
#  178370    automatic  wdbfa66e5mf036023    md        3.0   74799.0    silver
#  219589    automatic  4t1sv21e6mu303147    va        2.0  232476.0     white
#  219590    automatic  1hgcb7652ma198083    fl        1.0  200843.0      gray
#  219591    automatic  1g6cd53b1m4317816    fl        2.0  145882.0      blue
#  257721    automatic  4t1sv21e2mu374524    nc        2.0  175381.0  burgundy
#  269440    automatic  1hgcb7667ma222046    md        2.0  235909.0     white
#  281792    automatic  wdbfa66e5mf032926    fl        2.0   48170.0      blue
#  283383    automatic  4t1sv21e5mu324474    nc        2.0  264816.0     white
#  319454    automatic  wdbea30d1mb333582    pa        3.0  157815.0     black
#  322074    automatic  4t1sv21e5mu352579    fl        2.0  210619.0      blue
#  333094    automatic  wbaeg231xmcb73952    ca        2.0  106148.0     white
#  333097    automatic  wdbca35e0ma592112    ca        2.0  166788.0     white
#  348360    automatic  wdbea30d5mb451344    wa        1.0  166096.0     black
#  376243    automatic  1g3al54n4m6345520    nc        1.0  170874.0     white
#  381749       manual  jn1rz24h7mx502139    tn        1.0  183646.0     white
#  388420    automatic  wdbfa66e0mf026712    fl        2.0   81307.0       red
#  388423    automatic  1g1yy2384m5104212    fl        2.0  138310.0       red
#  388424    automatic  4t1sv21e1mu378712    md        1.0  209809.0     beige
#  426087    automatic  jt2ae94k6m3447855    tx        2.0  199195.0     white
#  434413    automatic  1hgcb7662ma059905    fl        1.0  236380.0     white
#  434415       manual  1gcdc14z4me127124    tx        1.0  218570.0     black
#  462588    automatic  1g6cd53b9m4285326    ga        3.0   57795.0     beige
#  462590       manual  1ftcr10a8muc14007    ca        2.0   81649.0     white
#  462591    automatic  1hgcb7664ma110126    wa        2.0  143100.0     green
#
#          interior                                            seller     mmr  \
#  4280      silver                             san diego sports cars  1075.0
#  17749      beige                                  silva auto sales  2100.0
#  17751       gray                              capital auto auction   475.0
#  17754       gray                               coral springs honda   575.0
#  17755       gray                               honda of serramonte   300.0
#  32301      black                                       i 10 toyota  6175.0
#  32305       gray                                    bob baker jeep  1050.0
#  32308          —                         purple heart services inc   750.0
#  41811       blue                         purple heart services inc   575.0
#  41813       blue                        titlebucks/san antonio-tx1   475.0
#  41814       blue                     autonation toyota winter park   300.0
#  41815          —                        automotive remarketing inc  1350.0
#  57265      beige                         purple heart services inc   550.0
#  57268       gray                   titlemax/martin luther king ga1   175.0
#  62927          —                    tiger financial management llc   950.0
#  72034       gray                   titlemax/martin luther king ga1  1250.0
#  108716      gray                       magnussens lexus of fremont  2850.0
#  108717      gray                         purple heart services inc   425.0
#  108719       red                              capital auto auction   975.0
#  108720      gray  germain toyota of naples/germain scion of naples  4900.0
#  114246       tan                             instaloan/lovejoy ga1   375.0
#  124490         —                        automotive remarketing inc   400.0
#  124491       red                         purple heart car donation   650.0
#  124498       tan                       darcars toyota of baltimore   700.0
#  133325     black                   autonation toyota pinellas park   625.0
#  133327  burgundy                                      dt inventory   400.0
#  168918     beige                                 bmw of fort myers   675.0
#  178370     black                                darcars of fairfax  3325.0
#  219589      blue                                   check into cash   325.0
#  219590  burgundy                                 hertz remarketing   575.0
#  219591      blue                                 infiniti of tampa   450.0
#  257721      gray                                      dt inventory   425.0
#  269440      blue                         purple heart services inc   425.0
#  281792       tan                                north palm hyundai  2250.0
#  283383      blue                                      dt inventory   275.0
#  319454       tan                                      purple heart   875.0
#  322074      blue                      autonation chevrolet airport   375.0
#  333094      gray                                   rover of orange  7600.0
#  333097     beige                           aaero sweet corporation  1750.0
#  348360     black          volunteers of america western washington   825.0
#  376243         —                              hendrick kia of cary   150.0
#  381749     brown                                        easy money  2450.0
#  388420     beige             autonation chevrolet south clearwater  3000.0
#  388423       red                      autonation toyota fort myers  4625.0
#  388424     beige                                      liberty ford   475.0
#  426087      gray                                   manheim houston   450.0
#  434413      gray                          courtesy nissan of tampa   425.0
#  434415      blue                        automotive remarketing inc   950.0
#  462588       tan                          autonation ford marietta   775.0
#  462590      gray                         purple heart services inc   325.0
#  462591     beige                         purple heart services inc   625.0
#
#          sellingprice                                 saledate         type
#  4280          1400.0  Wed Dec 17 2014 12:15:00 GMT-0800 (PST)        Sedan
#  17749         1600.0  Fri Feb 06 2015 01:20:00 GMT-0800 (PST)  Convertible
#  17751          350.0  Tue Dec 30 2014 12:40:00 GMT-0800 (PST)        Sedan
#  17754          400.0  Thu Dec 18 2014 11:00:00 GMT-0800 (PST)        Sedan
#  17755          150.0  Wed Jan 21 2015 07:10:00 GMT-0800 (PST)        Sedan
#  32301         5200.0  Tue Dec 23 2014 12:30:00 GMT-0800 (PST)  Convertible
#  32305         1300.0  Tue Dec 23 2014 12:00:00 GMT-0800 (PST)  Convertible
#  32308          275.0  Tue Dec 23 2014 10:00:00 GMT-0800 (PST)        Sedan
#  41811          275.0  Tue Dec 30 2014 12:00:00 GMT-0800 (PST)        Sedan
#  41813          300.0  Wed Jan 21 2015 04:30:00 GMT-0800 (PST)        Sedan
#  41814          500.0  Tue Jan 13 2015 18:00:00 GMT-0800 (PST)        Sedan
#  41815          800.0  Thu Jan 22 2015 03:00:00 GMT-0800 (PST)  Convertible
#  57265          550.0  Tue Jan 06 2015 04:00:00 GMT-0800 (PST)        Sedan
#  57268          600.0  Thu Jan 08 2015 12:30:00 GMT-0800 (PST)  Convertible
#  62927          550.0  Thu Jan 08 2015 11:00:00 GMT-0800 (PST)        Truck
#  72034          450.0  Thu Jan 08 2015 12:30:00 GMT-0800 (PST)        Sedan
#  108716        4100.0  Wed Jan 14 2015 12:30:00 GMT-0800 (PST)  Convertible
#  108717         300.0  Thu Jan 15 2015 04:00:00 GMT-0800 (PST)        Sedan
#  108719         350.0  Wed Jan 14 2015 07:15:00 GMT-0800 (PST)        Sedan
#  108720        2400.0  Wed Jan 14 2015 08:00:00 GMT-0800 (PST)    Hatchback
#  114246         375.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)        Sedan
#  124490         400.0  Thu Jan 22 2015 03:00:00 GMT-0800 (PST)        Sedan
#  124491         450.0  Tue Jan 20 2015 04:00:00 GMT-0800 (PST)        Sedan
#  124498         500.0  Tue Jan 20 2015 01:30:00 GMT-0800 (PST)        Sedan
#  133325         400.0  Tue Jan 20 2015 10:00:00 GMT-0800 (PST)    Hatchback
#  133327         325.0  Thu Jan 22 2015 01:05:00 GMT-0800 (PST)        Sedan
#  168918         600.0  Tue Feb 03 2015 10:00:00 GMT-0800 (PST)        Sedan
#  178370        2000.0  Tue Feb 03 2015 01:30:00 GMT-0800 (PST)  Convertible
#  219589         300.0  Thu Feb 05 2015 03:50:00 GMT-0800 (PST)        Sedan
#  219590         300.0  Thu Feb 12 2015 01:30:00 GMT-0800 (PST)        Sedan
#  219591         400.0  Mon Feb 09 2015 01:30:00 GMT-0800 (PST)        Sedan
#  257721         300.0  Tue Feb 17 2015 01:30:00 GMT-0800 (PST)        Sedan
#  269440         250.0  Tue Mar 03 2015 05:00:00 GMT-0800 (PST)        Sedan
#  281792        3500.0  Thu Feb 19 2015 02:10:00 GMT-0800 (PST)  Convertible
#  283383         200.0  Tue Mar 03 2015 00:30:00 GMT-0800 (PST)        Sedan
#  319454         450.0  Tue Mar 03 2015 05:01:00 GMT-0800 (PST)        Sedan
#  322074         400.0  Tue Mar 03 2015 10:00:00 GMT-0800 (PST)        Sedan
#  333094        6750.0  Wed Mar 04 2015 04:30:00 GMT-0800 (PST)        Coupe
#  333097        1400.0  Wed Mar 04 2015 03:30:00 GMT-0800 (PST)        Sedan
#  348360         275.0  Wed Apr 29 2015 05:30:00 GMT-0700 (PDT)        Sedan
#  376243         200.0  Mon May 25 2015 02:30:00 GMT-0700 (PDT)        Sedan
#  381749         550.0  Tue May 26 2015 03:00:00 GMT-0700 (PDT)    Hatchback
#  388420        3300.0  Tue May 26 2015 10:30:00 GMT-0700 (PDT)  Convertible
#  388423        2700.0  Tue May 26 2015 10:30:00 GMT-0700 (PDT)    Hatchback
#  388424         250.0  Tue Jun 02 2015 06:00:00 GMT-0700 (PDT)        Sedan
#  426087         200.0  Tue Jun 02 2015 02:15:00 GMT-0700 (PDT)        Wagon
#  434413         300.0  Thu Jun 04 2015 09:20:00 GMT-0700 (PDT)        Sedan
#  434415         350.0  Tue Jun 09 2015 03:30:00 GMT-0700 (PDT)        Truck
#  462588         900.0  Tue Jun 16 2015 05:50:00 GMT-0700 (PDT)        Sedan
#  462590         200.0  Wed Jun 17 2015 04:00:00 GMT-0700 (PDT)        Truck
#  462591         350.0  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)        Sedan  ,
#  1992:         year      make        model       trim         body transmission  \
#  4272    1992  Cadillac      DeVille       Base        Sedan    automatic
#  4273    1992    Toyota      Corolla       Base        Sedan    automatic
#  4277    1992  Cadillac      DeVille       Base        Sedan    automatic
#  4279    1992    Toyota      Corolla         LE        Sedan    automatic
#  4282    1992     Honda       Accord         LX        Sedan    automatic
#  ...      ...       ...          ...        ...          ...          ...
#  448643  1992     Lexus       LS 400       Base        sedan    automatic
#  448648  1992     Buick  Park Avenue       Base        sedan    automatic
#  467398  1992     Mazda   MX-5 Miata       Base  convertible       manual
#  467399  1992     Honda       Accord         EX        Coupe    automatic
#  467400  1992   Lincoln     Town Car  Signature        sedan    automatic
#
#                        vin state  condition  odometer  color interior  \
#  4272    1g6cd53b6n4290503    ca        3.0  114502.0  white     blue
#  4273    1nxae91a2nz329392    ca        2.0  124294.0   blue     blue
#  4277    1g6cd53b5n4310353    ca        1.0  155093.0   blue     blue
#  4279    1nxae97axnz297234    ca        2.0  149118.0   gray     gray
#  4282    jhmcb7657nc049977    ca        2.0  216503.0  black     gray
#  ...                   ...   ...        ...       ...    ...      ...
#  448643  jt8uf11e8n0134874    ga        2.0  358235.0  black      tan
#  448648  1g4cw53l7n1603412    tx        3.0  146921.0   blue     blue
#  467398  jm1na3512n0321650    wa        2.0  116401.0  white    black
#  467399  1hgcb7271na065355    ga        1.0  224528.0  white     blue
#  467400  1lnlm82w5ny705589    wi        3.0   55099.0  white     gray
#
#                                      seller     mmr  sellingprice  \
#  4272                   aaero sweet company   925.0         400.0
#  4273             purple heart services inc   950.0         300.0
#  4277                      grand auto sales   575.0         600.0
#  4279             purple heart services inc   650.0         300.0
#  4282        western motors/aide rent a car   575.0         500.0
#  ...                                    ...     ...           ...
#  448643                titlemax/atlanta ga3   400.0         375.0
#  448648          automotive remarketing inc   525.0         300.0
#  467398                capital auto auction  1875.0        1000.0
#  467399  autonation hyundai mall of georgia   700.0        1250.0
#  467400         napletons hyundai of aurora   725.0        1000.0
#
#                                         saledate         type
#  4272    Wed Dec 17 2014 11:30:00 GMT-0800 (PST)        Sedan
#  4273    Wed Dec 17 2014 15:10:00 GMT-0800 (PST)        Sedan
#  4277    Wed Jan 14 2015 04:30:00 GMT-0800 (PST)        Sedan
#  4279    Wed Dec 17 2014 15:10:00 GMT-0800 (PST)        Sedan
#  4282    Tue Dec 16 2014 12:00:00 GMT-0800 (PST)        Sedan
#  ...                                         ...          ...
#  448643  Thu Jun 11 2015 05:30:00 GMT-0700 (PDT)        Sedan
#  448648  Tue Jun 16 2015 04:00:00 GMT-0700 (PDT)        Sedan
#  467398  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)  Convertible
#  467399  Tue Jun 16 2015 05:50:00 GMT-0700 (PDT)        Coupe
#  467400  Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)        Sedan
#
#  [97 rows x 17 columns],
#  1993:         year           make      model      trim   body transmission  \
#  4271    1993         Saturn   S-Series       SL2  Sedan       manual
#  4276    1993          Lexus     ES 300      Base  Sedan    automatic
#  6136    1993         Saturn   S-Series       SL2  Sedan    automatic
#  17727   1993          Buick    LeSabre   Limited  Sedan    automatic
#  17733   1993       Cadillac    Seville      Base  Sedan    automatic
#  ...      ...            ...        ...       ...    ...          ...
#  448638  1993  Mercedes-Benz  300-Class  300E 2.8  sedan    automatic
#  448645  1993          Honda     Accord        EX  Coupe       manual
#  466503  1993         Toyota    4Runner    SR5 V6    suv       manual
#  469794  1993          Honda      Civic        EX  coupe    automatic
#  470605  1993         Toyota      Camry        DX  Sedan    automatic
#
#                        vin state  condition  odometer  color  interior  \
#  4271    1g8zj5573pz263154    ca        1.0  287704.0   blue      gray
#  4276    jt8vk13t4p0224005    ca        2.0  169391.0  beige      gray
#  6136    1g8zk5578pz293411    ca        2.0  378670.0    red      gray
#  17727   1g4hr53l1ph508674    va        2.0   99938.0   blue      blue
#  17733   1g6ks52bxpu823040    fl        2.0  133872.0   gold     beige
#  ...                   ...   ...        ...       ...    ...       ...
#  448638  wdbea28expb859365    va        2.0  206770.0  beige       tan
#  448645  1hgcb7173pa016288    fl        3.0  233571.0  brown  burgundy
#  466503  jt3vn39wxp0103778    wa        2.0  192533.0   blue      blue
#  469794  1hgej125xpl043580    fl        1.0  169021.0    red     black
#  470605  jt2sk11e5p0165063    tx        3.0   70752.0  beige       tan
#
#                                            seller     mmr  sellingprice  \
#  4271              western motors/aide rent a car   350.0         400.0
#  4276                     nino quality motors inc  1075.0         500.0
#  6136                    charitable auto resource   325.0         400.0
#  17727                               purple heart   800.0         350.0
#  17733                           branford motor 1   225.0         650.0
#  ...                                          ...     ...           ...
#  448638                     brown's dulles nissan   575.0         550.0
#  448645                   coggin honda of orlando   650.0         400.0
#  466503  volunteers of america western washington  1100.0        1450.0
#  469794             autonation toyota winter park   875.0         300.0
#  470605               autonation honda lewisville   800.0        2000.0
#
#                                         saledate   type
#  4271    Tue Jan 20 2015 05:00:00 GMT-0800 (PST)  Sedan
#  4276    Wed Jan 14 2015 07:10:00 GMT-0800 (PST)  Sedan
#  6136    Tue Dec 23 2014 12:00:00 GMT-0800 (PST)  Sedan
#  17727   Thu Dec 18 2014 11:50:00 GMT-0800 (PST)  Sedan
#  17733   Fri Dec 19 2014 10:10:00 GMT-0800 (PST)  Sedan
#  ...                                         ...    ...
#  448638  Thu Jun 11 2015 02:05:00 GMT-0700 (PDT)  Sedan
#  448645  Thu Jun 11 2015 09:20:00 GMT-0700 (PDT)  Coupe
#  466503  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)    SUV
#  469794  Wed Jun 17 2015 01:30:00 GMT-0700 (PDT)  Coupe
#  470605  Thu Jun 18 2015 04:00:00 GMT-0700 (PDT)  Sedan
#
#  [127 rows x 17 columns],
#  1994:         year           make          model   trim         body transmission  \
#  4270    1994          Lexus         ES 300   Base        Sedan    automatic
#  4274    1994  Mercedes-Benz       SL-Class  SL500  Convertible    automatic
#  4275    1994        Mercury  Grand Marquis     LS        Sedan    automatic
#  4278    1994           Ford        Mustang   Base        Coupe       manual
#  6137    1994           Ford       Explorer    XLT          SUV    automatic
#  ...      ...            ...            ...    ...          ...          ...
#  462583  1994        Mercury  Grand Marquis     LS        sedan    automatic
#  462586  1994         Toyota         Celica     GT    hatchback    automatic
#  466501  1994          Acura        Integra     LS        sedan    automatic
#  471292  1994       Cadillac        Seville   Base        sedan    automatic
#  471293  1994          Honda          Civic     LX        sedan    automatic
#
#                        vin state  condition  odometer  color interior  \
#  4270    jt8gk13t0r0048033    ca        2.0  230417.0  white    beige
#  4274    wdbfa67e8rf095993    ca        2.0  119802.0   gray    beige
#  4275    2melm75w8rx671727    ca        2.0  156428.0  beige    beige
#  4278    1falp4047rf202353    ca        2.0  227968.0    red    beige
#  6137    1fmdu34x8rue13624    ca        2.0  201930.0  white     gray
#  ...                   ...   ...        ...       ...    ...      ...
#  462583  2melm75w1rx643039    fl        2.0   42964.0   blue    black
#  462586  jt2st07n2r0004882    fl        1.0   94085.0  white    black
#  466501  jh4db7655rs007808    md        1.0  122632.0   gray     gray
#  471292  1g6ks52y6ru826119    fl        2.0  147219.0   blue        —
#  471293  1hgeg8650rl003433    fl        2.0  208218.0   blue     gray
#
#                                  seller     mmr  sellingprice  \
#  4270               esquivel auto depot   975.0         400.0
#  4274             capistrano volkswagen  2175.0        2300.0
#  4275         purple heart services inc   400.0         250.0
#  4278         purple heart car donation   375.0         400.0
#  6137    western motors/aide rent a car   650.0         600.0
#  ...                                ...     ...           ...
#  462583     autonation honda clearwater   900.0         700.0
#  462586  autonation toyota scion weston  1050.0         300.0
#  466501           darcars chrysler jeep  1250.0         400.0
#  471292             ed morse auto plaza   750.0         900.0
#  471293       coggin honda of ft pierce   575.0         350.0
#
#                                         saledate         type
#  4270    Tue Dec 30 2014 13:00:00 GMT-0800 (PST)        Sedan
#  4274    Wed Dec 31 2014 12:30:00 GMT-0800 (PST)  Convertible
#  4275    Tue Dec 23 2014 15:10:00 GMT-0800 (PST)        Sedan
#  4278    Tue Dec 16 2014 13:00:00 GMT-0800 (PST)        Coupe
#  6137    Tue Jan 06 2015 04:00:00 GMT-0800 (PST)          SUV
#  ...                                         ...          ...
#  462583  Tue Jun 16 2015 10:30:00 GMT-0700 (PDT)        Sedan
#  462586  Wed Jun 17 2015 01:30:00 GMT-0700 (PDT)    Hatchback
#  466501  Tue Jun 16 2015 02:30:00 GMT-0700 (PDT)        Sedan
#  471292  Thu Jun 18 2015 08:30:00 GMT-0700 (PDT)        Sedan
#  471293  Thu Jun 18 2015 06:00:00 GMT-0700 (PDT)        Sedan
#
#  [286 rows x 17 columns],
#  1995:         year           make    model     trim       body transmission  \
#  4205    1995  Mercedes-Benz  E-Class     E320      Sedan    automatic
#  4209    1995          Buick    Regal   Custom      Sedan    automatic
#  4214    1995           Ford  Mustang       GT      Coupe       manual
#  4220    1995          Honda   Accord       LX      Coupe    automatic
#  4230    1995           Ford   Escort       LX      Wagon    automatic
#  ...      ...            ...      ...      ...        ...          ...
#  466502  1995         Nissan   Maxima       SE      sedan    automatic
#  466504  1995         Toyota  4Runner  Limited        suv    automatic
#  468098  1995  Mercedes-Benz  E-Class    E300D      sedan    automatic
#  470604  1995           Ford  Mustang     Base      coupe    automatic
#  471294  1995      Chevrolet   Camaro     Base  hatchback    automatic
#
#                        vin state  condition  odometer  color interior  \
#  4205    wdbea32e3sc272295    ca        2.0  241685.0  black    black
#  4209    2g4wb52l7s1421497    ca        2.0  111199.0  white      tan
#  4214    1falp42t0sf248732    ca        2.0  177751.0   blue    beige
#  4220    1hgcd7237sa035411    ca        1.0  168899.0   gold    beige
#  4230    3fasp15j4sr100431    ca        3.0  120649.0   gold    brown
#  ...                   ...   ...        ...       ...    ...      ...
#  466502  jn1ca21dxst615666    wa        2.0  160097.0  white    beige
#  466504  jt3vn39w2s0186485    pr        1.0  140115.0   gray     gray
#  468098  wdbeb31e0sc110591    ca        2.0  106462.0   gray     gray
#  470604  1falp4042sf193776    fl        2.0   52660.0  green     gray
#  471294  2g1fp22s3s2209758    tx        3.0  118442.0  black     gray
#
#                                                   seller     mmr  sellingprice  \
#  4205                                newport auto sports   900.0         400.0
#  4209                          purple heart services inc   650.0         325.0
#  4214                                        rancho ford   700.0         500.0
#  4220                          purple heart services inc   950.0         400.0
#  4230                                    wondries toyota   400.0         300.0
#  ...                                                 ...     ...           ...
#  466502                                  bellevue nissan   575.0         900.0
#  466504  select remarketing group llc/anderson financial  1200.0         500.0
#  468098                           a to z liquidators inc  3675.0        2300.0
#  470604                                   metro ford inc   900.0         400.0
#  471294                 autonation ford south fort worth  1225.0        1400.0
#
#                                         saledate       type
#  4205    Wed Dec 31 2014 11:30:00 GMT-0800 (PST)      Sedan
#  4209    Wed Dec 17 2014 13:30:00 GMT-0800 (PST)      Sedan
#  4214    Tue Jan 06 2015 13:00:00 GMT-0800 (PST)      Coupe
#  4220    Wed Dec 17 2014 15:10:00 GMT-0800 (PST)      Coupe
#  4230    Wed Dec 31 2014 12:30:00 GMT-0800 (PST)      Wagon
#  ...                                         ...        ...
#  466502  Wed Jun 17 2015 06:20:00 GMT-0700 (PDT)      Sedan
#  466504  Thu Jun 18 2015 04:00:00 GMT-0700 (PDT)        SUV
#  468098  Tue Jun 16 2015 05:30:00 GMT-0700 (PDT)      Sedan
#  470604  Fri Jun 19 2015 02:30:00 GMT-0700 (PDT)      Coupe
#  471294  Thu Jun 18 2015 04:00:00 GMT-0700 (PDT)  Hatchback
#
#  [483 rows x 17 columns],
#  1996:         year        make            model    trim          body transmission  \
#  4204    1996      Toyota          4Runner     SR5           SUV    automatic
#  4211    1996    Infiniti              I30    Base         Sedan    automatic
#  4221    1996      Saturn         S-Series     SL2         Sedan       manual
#  4229    1996    Cadillac          Seville     SLS         Sedan    automatic
#  4232    1996        Ford         Explorer     XLT           SUV    automatic
#  ...      ...         ...              ...     ...           ...          ...
#  466497  1996       Lexus           LS 400    Base         sedan    automatic
#  466499  1996  Oldsmobile  Cutlass Supreme      SL         sedan    automatic
#  467395  1996       Honda            Civic      EX         sedan       manual
#  467396  1996       Buick          LeSabre  Custom         sedan    automatic
#  469513  1996        Ford           Ranger     XLT  extended cab    automatic
#
#                        vin state  condition  odometer   color interior  \
#  4204    jt3gn86r1t0018360    ca        2.0  227353.0  silver      tan
#  4211    jnkca21dxtt019521    ca        3.0  201745.0   white    beige
#  4221    1g8zj5276tz324401    ca        2.0  185252.0    gold    beige
#  4229    1g6ks52y7tu818134    ca        2.0  145475.0     red    beige
#  4232    1fmdu32x4tzb45202    ca        1.0  175910.0   white     gray
#  ...                   ...   ...        ...       ...     ...      ...
#  466497  jt8bh22f1t0041772    ga        1.0  167855.0    gray     gray
#  466499  1g3wh52m7tf374977    fl        2.0  155389.0    gold    beige
#  467395  2hgej8540th517491    md        3.0  140240.0   black     gray
#  467396  1g4hp52k5th405752    nc        1.0  133992.0   white     blue
#  469513  1ftcr14u3tpb55031    fl        2.0  214623.0   green     gray
#
#                                     seller     mmr  sellingprice  \
#  4204                  aaero sweet company  1600.0        1300.0
#  4211             charitable auto resource   650.0         850.0
#  4221                          rpm lenders   625.0         200.0
#  4229                    hertz remarketing   575.0         400.0
#  4232            purple heart services inc   625.0         300.0
#  ...                                   ...     ...           ...
#  466497  autonation toyota mall of georgia  1250.0         700.0
#  466499                       dt inventory   725.0         300.0
#  467395                     darcars toyota  1225.0         900.0
#  467396            honda cars of rock hill   625.0         550.0
#  469513                     metro ford inc  1275.0         700.0
#
#                                         saledate   type
#  4204    Wed Dec 17 2014 11:30:00 GMT-0800 (PST)    SUV
#  4211    Tue Dec 16 2014 12:00:00 GMT-0800 (PST)  Sedan
#  4221    Wed Mar 04 2015 07:10:00 GMT-0800 (PST)  Sedan
#  4229    Thu Jan 15 2015 04:00:00 GMT-0800 (PST)  Sedan
#  4232    Wed Dec 17 2014 15:10:00 GMT-0800 (PST)    SUV
#  ...                                         ...    ...
#  466497  Tue Jun 16 2015 05:50:00 GMT-0700 (PDT)  Sedan
#  466499  Wed Jun 17 2015 09:00:00 GMT-0700 (PDT)  Sedan
#  467395  Tue Jun 16 2015 02:30:00 GMT-0700 (PDT)  Sedan
#  467396  Wed Jun 17 2015 07:00:00 GMT-0700 (PDT)  Sedan
#  469513  Fri Jun 19 2015 02:30:00 GMT-0700 (PDT)  Truck
#
#  [562 rows x 17 columns],
#  1997:         year           make            model             trim   body  \
#  4206    1997         Subaru           Legacy  Outback Limited  Wagon
#  4207    1997  Mercedes-Benz          E-Class             E320  Sedan
#  4210    1997       Infiniti              QX4             Base    SUV
#  4213    1997          Honda           Accord            EX V6  Sedan
#  4222    1997         Toyota          4Runner              SR5    SUV
#  ...      ...            ...              ...              ...    ...
#  470598  1997      Chevrolet         Cavalier               LS  Sedan
#  470601  1997          Honda             CR-V             Base    suv
#  470602  1997     Oldsmobile  Cutlass Supreme               SL  sedan
#  470603  1997         Nissan           Maxima               SE  sedan
#  472184  1997  Mercedes-Benz          S-Class         S320 LWB  sedan
#
#         transmission                vin state  condition  odometer   color  \
#  4206      automatic  4s3bg685xv7646670    ca        2.0  193138.0    blue
#  4207      automatic  wdbjf55f1va389812    ca       35.0  103257.0  silver
#  4210      automatic  jnrar05y5vw005370    ca       19.0  203286.0    gold
#  4213      automatic  1hgce667xva009264    ca       19.0  214580.0   green
#  4222      automatic  jt3hn86r1v0077982    ca       28.0  211287.0   white
#  ...             ...                ...   ...        ...       ...     ...
#  470598    automatic  3g1jf524xvs865857    fl        2.0  138360.0    blue
#  470601    automatic  jhlrd1857vc062344    ca       19.0  273013.0  silver
#  470602    automatic  1g3wh52m2vf337659    fl       19.0  137757.0  silver
#  470603       manual  jn1ca21d4vt218586    ca       27.0  192927.0   black
#  472184    automatic  wdbga33g9va372927    pa       28.0   94947.0       —
#
#         interior                           seller     mmr  sellingprice  \
#  4206       gray         charitable auto resource  1250.0         400.0
#  4207       gray              aaero sweet company  1750.0        2500.0
#  4210      beige        mercedes benz of temecula   625.0         850.0
#  4213      beige              aaero sweet company   450.0         400.0
#  4222      brown         first choice auto center  1850.0        1600.0
#  ...         ...                              ...     ...           ...
#  470598     gray  coggin chevrolet at the avenues   725.0         350.0
#  470601     gray               capitol mitsubishi   925.0        1250.0
#  470602     gray              ed morse auto plaza   725.0         700.0
#  470603     gray             ideal transportation   550.0         750.0
#  472184      tan     r hollenshead auto sales inc  2550.0        3200.0
#
#                                         saledate   type
#  4206    Tue Dec 23 2014 13:00:00 GMT-0800 (PST)  Wagon
#  4207    Wed Dec 17 2014 11:30:00 GMT-0800 (PST)  Sedan
#  4210    Wed Dec 17 2014 12:30:00 GMT-0800 (PST)    SUV
#  4213    Wed Dec 17 2014 11:30:00 GMT-0800 (PST)  Sedan
#  4222    Wed Dec 17 2014 11:30:00 GMT-0800 (PST)    SUV
#  ...                                         ...    ...
#  470598  Thu Jun 18 2015 06:00:00 GMT-0700 (PDT)  Sedan
#  470601  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)    SUV
#  470602  Thu Jun 18 2015 08:30:00 GMT-0700 (PDT)  Sedan
#  470603  Wed Jun 17 2015 05:30:00 GMT-0700 (PDT)  Sedan
#  472184  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)  Sedan
#
#  [1042 rows x 17 columns],
#  1998:         year        make         model  trim          body transmission  \
#  4203    1998       Volvo           S90  Base         Sedan    automatic
#  4208    1998       Lexus        GS 300  Base         Sedan    automatic
#  4212    1998       Lexus        ES 300  Base         Sedan    automatic
#  4218    1998    Chrysler       Sebring   JXi   Convertible    automatic
#  4219    1998       Lexus        GS 300  Base         Sedan    automatic
#  ...      ...         ...           ...   ...           ...          ...
#  470599  1998  Oldsmobile       Bravada  Base           suv    automatic
#  470600  1998      Toyota  Land Cruiser  Base           suv    automatic
#  471291  1998      Nissan        Altima   GLE         sedan    automatic
#  471686  1998        Ford         F-150   XLT  extended cab    automatic
#  471687  1998       Honda         Civic    LX         sedan       manual
#
#                        vin state  condition  odometer     color interior  \
# ...
#  1597    Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Convertible
#  1598    Thu Dec 18 2014 12:30:00 GMT-0800 (PST)        Sedan
#  1599    Thu Dec 18 2014 12:30:00 GMT-0800 (PST)        Sedan
#  1600    Thu Dec 18 2014 12:30:00 GMT-0800 (PST)        Sedan
#  ...                                         ...          ...
#  472281  Tue Jul 07 2015 08:45:00 GMT-0700 (PDT)          SUV
#  472287  Fri Jul 03 2015 06:30:00 GMT-0700 (PDT)        Wagon
#  472307  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    Hatchback
#  472316  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)          SUV
#  472320  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)        Sedan
#
#  [41384 rows x 17 columns],
#  2012:         year       make           model                    trim         body  \
#  677     2012        BMW        6 Series                    650i  Convertible
#  678     2012      Acura             TSX                    Base        Sedan
#  679     2012       Audi              A6    3.0T Premium quattro        Sedan
#  680     2012        BMW        6 Series                    650i        Coupe
#  681     2012        BMW        5 Series                    528i        Sedan
#  ...      ...        ...             ...                     ...          ...
#  472312  2012       Ford          Escape                     XLT          SUV
#  472314  2012  Chevrolet  Silverado 1500                      LT     Crew Cab
#  472319  2012      Dodge   Grand Caravan  American Value Package      Minivan
#  472321  2012        Ram            2500             Power Wagon     Crew Cab
#  472322  2012        BMW              X5               xDrive35d          SUV
#
#         transmission                vin state  condition  odometer   color  \
#  677       automatic  wbalz3c5xcdl71530    ca       38.0   28925.0   white
#  678       automatic  jh4cu2f43cc007761    ca       39.0   43127.0   black
#  679       automatic  wauggafc1cn055417    ca       35.0   36541.0       —
#  680       automatic  wbalx3c59cdv77170    ca       47.0   34941.0   black
#  681       automatic  wbaxg5c54cdx02704    ca       47.0   45443.0   black
#  ...             ...                ...   ...        ...       ...     ...
#  472312    automatic  1fmcu9d78ckc84074    fl       38.0   74673.0   white
#  472314    automatic  3gcpcse00cg289987    tx       37.0   37908.0   white
#  472319    automatic  2c4rdgbg1cr349287    ma       37.0   97036.0  silver
#  472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
#  472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
#
#         interior                                  seller      mmr  \
#  677       black  financial services remarketing (lease)  48500.0
#  678       black    ahfc/honda lease trust/hvt  inc. eot  16450.0
#  679       beige                 high bid trading co inc  29800.0
#  680       black  financial services remarketing (lease)  42600.0
#  681        gray  financial services remarketing (lease)  29500.0
#  ...         ...                                     ...      ...
#  472312     gray                    lehman buick gmc llc  11550.0
#  472314    black             wells fargo dealer services  25000.0
#  472319     gray   ge fleet services for itself/servicer   8300.0
#  472321    black                         i -5 uhlmann rv  30200.0
#  472322    black  financial services remarketing (lease)  29800.0
#
#          sellingprice                                 saledate         type
#  677          50500.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Convertible
#  678          17800.0  Thu Dec 18 2014 12:00:00 GMT-0800 (PST)        Sedan
#  679          29000.0  Thu Dec 18 2014 12:00:00 GMT-0800 (PST)        Sedan
#  680          42500.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)        Coupe
#  681          30500.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)        Sedan
#  ...              ...                                      ...          ...
#  472312       11400.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)          SUV
#  472314       23000.0  Tue Jul 07 2015 06:00:00 GMT-0700 (PDT)        Truck
#  472319        7800.0  Tue Jul 07 2015 06:30:00 GMT-0700 (PDT)      Minivan
#  472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)        Truck
#  472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)          SUV
#
#  [87380 rows x 17 columns],
#  2013:         year           make           model                  trim  \
#  107     2013       Infiniti         G Coupe             G37 Sport
#  108     2013       Infiniti         G Sedan           G37 Journey
#  109     2013       Infiniti         G Sedan           G37 Journey
#  110     2013       Infiniti         G Coupe             G37 Sport
#  111     2013       Infiniti         G Coupe             G37 Sport
#  ...      ...            ...             ...                   ...
#  472293  2013  Mercedes-Benz         C-Class                  C250
#  472305  2013          Honda           Civic               LX PZEV
#  472308  2013  Mercedes-Benz         G-Class               G63 AMG
#  472310  2013      Chevrolet  Silverado 1500                    LT
#  472315  2013           Audi              S5  Premium Plus quattro
#
#                 body transmission                vin state  condition  \
#  107         G Coupe    automatic  jn1cv6ek4dm921604    ca       45.0
#  108         G Sedan    automatic  jn1cv6ap3dm726059    ca       46.0
#  109         G Sedan    automatic  jn1cv6apxdm714541    ca       45.0
#  110         G Coupe    automatic  jn1cv6ek8dm920763    ca       47.0
#  111         G Coupe    automatic  jn1cv6ek8dm900321    ca       45.0
#  ...             ...          ...                ...   ...        ...
#  472293        Coupe    automatic  wddgj4hb5dg003648    ca       25.0
#  472305        Sedan    automatic  2hgfb2f54dh585400    ga       19.0
#  472308          suv    automatic  wdcyc7df4dx207385    fl        5.0
#  472310     crew cab    automatic  3gcpcse0xdg244430    tx       43.0
#  472315  convertible    automatic  waucgafh6dn005382    fl        5.0
#
#          odometer   color interior                                  seller  \
#  107      14716.0   white    black                      nissan infiniti lt
#  108         68.0   black    black                      nissan infiniti lt
#  109      24112.0   white    black                      nissan infiniti lt
#  110       4859.0   black    black                      nissan infiniti lt
#  111      21126.0   black    beige                      nissan infiniti lt
#  ...          ...     ...      ...                                     ...
#  472293   36823.0   white        —        mercedes-benz financial services
#  472305   32117.0    gray    black        ahfc/honda lease trust/hvt  inc.
#  472308   26799.0   black    black                              fields bmw
#  472310   74575.0   black    black  stanley chevrolet buick gmc gatesville
#  472315   20158.0  silver    black                           prestige audi
#
#               mmr  sellingprice                                 saledate  \
#  107      25900.0       25000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  108      25700.0       27250.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  109      22800.0       22500.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  110      27200.0       26750.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  111      25100.0       26500.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  ...          ...           ...                                      ...
#  472293   22200.0       24750.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
#  472305   12250.0       10000.0  Tue Jul 07 2015 09:50:00 GMT-0700 (PDT)
#  472308  104000.0      105000.0  Tue Jul 07 2015 06:00:00 GMT-0700 (PDT)
#  472310   22100.0       22000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)
#  472315   43900.0       42000.0  Thu Jul 09 2015 06:00:00 GMT-0700 (PDT)
#
#                 type
#  107           Coupe
#  108           Sedan
#  109           Sedan
#  110           Coupe
#  111           Coupe
#  ...             ...
#  472293        Coupe
#  472305        Sedan
#  472308          SUV
#  472310        Truck
#  472315  Convertible
#
#  [87467 rows x 17 columns],
#  2014:         year           make                model                       trim  \
#  2       2014            BMW             3 Series                 328i SULEV
#  4       2014            BMW  6 Series Gran Coupe                       650i
#  6       2014            BMW                   M5                       Base
#  7       2014      Chevrolet                Cruze                        1LT
#  8       2014           Audi                   A4  2.0T Premium Plus quattro
#  ...      ...            ...                  ...                        ...
#  472284  2014     Volkswagen                  GTI          Wolfsburg Edition
#  472302  2014  Mercedes-Benz              E-Class             E63 AMG 4MATIC
#  472317  2014           Jeep       Grand Cherokee                    Limited
#  472318  2014           Jeep       Grand Cherokee                     Laredo
#  472324  2014           Ford                F-150                        XLT
#
#               body transmission                vin state  condition  odometer  \
#  2           Sedan    automatic  wba3c1c51ek116351    ca       45.0    1331.0
#  4           Sedan    automatic  wba6b2c57ed129731    ca       43.0    2641.0
#  6           Sedan    automatic  wbsfv9c51ed593089    ca       34.0   14943.0
#  7           Sedan    automatic  1g1pc5sb2e7128460    ca        2.0   28617.0
#  8           Sedan    automatic  wauffafl3en030343    ca       42.0    9557.0
#  ...           ...          ...                ...   ...        ...       ...
#  472284  Hatchback       manual  wvwgd7ajxew008579    fl       37.0    8307.0
#  472302      Sedan    automatic  wddhf9cb9ea917688    ca       45.0   17518.0
#  472317        SUV    automatic  1c4rjebg4ec573100    ca       44.0    9024.0
#  472318        SUV    automatic  1c4rjfag0ec466276    pa       42.0   25180.0
#  472324  SuperCrew    automatic  1ftfw1et2eke87277    ca       34.0   15008.0
#
#          color interior                                             seller  \
#  2        gray    black             financial services remarketing (lease)
#  4        gray    black             financial services remarketing (lease)
#  6       black    black                              the hertz corporation
#  7       black    black  enterprise vehicle exchange / tra / rental / t...
#  8       white    black                                 audi mission viejo
#  ...       ...      ...                                                ...
#  472284  white    black                                          vw credit
#  472302  black    black                              the hertz corporation
#  472317   gray    black  enterprise vehicle exchange / tra / rental / t...
#  472318   gray    black                              hertz corporation/gdp
#  472324   gray     gray                   ford motor credit company llc pd
#
#              mmr  sellingprice                                 saledate  \
#  2       31900.0       30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)
#  4       66000.0       67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)
#  6       69000.0       65000.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)
#  7       11900.0        9800.0  Tue Dec 16 2014 13:00:00 GMT-0800 (PST)
#  8       32100.0       32250.0  Thu Dec 18 2014 12:00:00 GMT-0800 (PST)
#  ...         ...           ...                                      ...
#  472284  21300.0       22000.0  Thu Jul 02 2015 08:00:00 GMT-0700 (PDT)
#  472302  64000.0       69500.0  Tue Jul 07 2015 09:30:00 GMT-0700 (PDT)
#  472317  29800.0       17300.0  Thu Jul 09 2015 09:00:00 GMT-0700 (PDT)
#  472318  26000.0       24500.0  Tue Jul 07 2015 06:30:00 GMT-0700 (PDT)
#  472324  29600.0       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)
#
#               type
#  2           Sedan
#  4           Sedan
#  6           Sedan
#  7           Sedan
#  8           Sedan
#  ...           ...
#  472284  Hatchback
#  472302      Sedan
#  472317        SUV
#  472318        SUV
#  472324      Truck
#
#  [69712 rows x 17 columns],
#  2015:         year      make             model     trim       body transmission  \
#  0       2015       Kia           Sorento       LX        SUV    automatic
#  1       2015       Kia           Sorento       LX        SUV    automatic
#  3       2015     Volvo               S60       T5      Sedan    automatic
#  5       2015    Nissan            Altima    2.5 S      Sedan    automatic
#  11      2015       Kia            Optima       LX      Sedan    automatic
#  ...      ...       ...               ...      ...        ...          ...
#  472097  2015  Chrysler               200  Limited      sedan    automatic
#  472194  2015  Chrysler  Town and Country  Touring    minivan    automatic
#  472214  2015    Nissan              Leaf       SV  hatchback    automatic
#  472277  2015     Buick             Regal       GS      sedan    automatic
#  472323  2015    Nissan            Altima    2.5 S      sedan    automatic
#
#                        vin state  condition  odometer   color interior  \
#  0       5xyktca69fg566472    ca        5.0   16639.0   white    black
#  1       5xyktca69fg561319    ca        5.0    9393.0   white    beige
#  3       yv1612tb4f1310987    ca       41.0   14282.0   white    black
#  5       1n4al3ap1fn326013    ca        1.0    5554.0    gray    black
#  11      5xxgm4a73fg353538    ca       48.0    2034.0     red      tan
#  ...                   ...   ...        ...       ...     ...      ...
#  472097  1c3cccab3fn578972    nv        4.0   13634.0    gray    black
#  472194  2c4rc1bg5fr644641    nv       35.0    6788.0    gray    black
#  472214  1n4az0cp8fc308033    pa       43.0    2812.0  silver    black
#  472277  2g4gt5gx1f9142308    mi        5.0    5678.0   black    black
#  472323  1n4al3ap0fc216050    ga       38.0   16658.0   white    black
#
#                                                     seller      mmr  \
#  0                                 kia motors america  inc  20500.0
#  1                                 kia motors america  inc  20800.0
#  3                                 volvo na rep/world omni  27500.0
#  5       enterprise vehicle exchange / tra / rental / t...  15350.0
#  11                                     kia motors finance  15150.0
#  ...                                                   ...      ...
#  472097              remarketing by ge/certified fleet inc  15250.0
#  472194                                 kapitolia auto llc  23600.0
#  472214                                 nissan-infiniti lt  12900.0
#  472277                                     gm remarketing  33900.0
#  472323  enterprise vehicle exchange / tra / rental / t...  15100.0
#
#          sellingprice                                 saledate       type
#  0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)        SUV
#  1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)        SUV
#  3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)      Sedan
#  5            10900.0  Tue Dec 30 2014 12:00:00 GMT-0800 (PST)      Sedan
#  11           17700.0  Tue Dec 16 2014 12:00:00 GMT-0800 (PST)      Sedan
#  ...              ...                                      ...        ...
#  472097       14200.0  Fri Jun 19 2015 05:00:00 GMT-0700 (PDT)      Sedan
#  472194       19800.0  Fri Jun 19 2015 05:00:00 GMT-0700 (PDT)    Minivan
#  472214       12200.0  Fri Jun 19 2015 02:00:00 GMT-0700 (PDT)  Hatchback
#  472277       18900.0  Thu Jul 02 2015 07:00:00 GMT-0700 (PDT)      Sedan
#  472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)      Sedan
#
#  [7994 rows x 17 columns]}

# %%
#Data Analysis for Car Sales in 2010
# Dropping columns from the DataFrame
car_sales_2005_df = df_by_year[2005][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2005_df
make2005_counts = car_sales_2005_df["make"].value_counts().head(10)
price_mean_2005 = car_sales_2005_df['sellingprice'].mean()
print(price_mean_2005)
# Out:
# 4881.957889218941

# %%
colors = ['blue', 'green', 'red', 'purple', 'orange', 'yellow', 'cyan', 'magenta', 'brown', 'pink']

# %%
plt.figure(figsize=(12, 6))
make2005_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2005 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2006_df = df_by_year[2006][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2006_df
make2006_counts = car_sales_2006_df["make"].value_counts().head(10)
make2006_counts
# Out:
# make
# Chevrolet        2521
# Ford             2458
# Nissan           1504
# Dodge            1446
# Toyota           1272
# BMW              1260
# Chrysler         1140
# Honda             978
# Mercedes-Benz     950
# Jeep              788
# Name: count, dtype: int64

# %%
price_mean_2006 = car_sales_2006_df['sellingprice'].mean()
print(price_mean_2006)
# Out:
# 5993.042808931626

# %%
plt.figure(figsize=(12, 6))
make2006_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2006 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2007_df = df_by_year[2007][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2007_df
make2007_counts = car_sales_2007_df["make"].value_counts().head(10)
make2007_counts
# Out:
# make
# Chevrolet    3598
# Ford         2563
# Toyota       1882
# Dodge        1583
# Nissan       1486
# Honda        1478
# BMW          1296
# Chrysler     1237
# Jeep         1060
# GMC           918
# Name: count, dtype: int64

# %%
price_mean_2007 = car_sales_2007_df['sellingprice'].mean()
print(price_mean_2007)
# Out:
# 7861.239853416345

# %%
plt.figure(figsize=(12, 6))
make2007_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2007 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2008_df = df_by_year[2008][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2008_df
make2008_counts = car_sales_2008_df["make"].value_counts().head(10)
make2008_counts
# Out:
# make
# Chevrolet        3669
# Ford             3237
# Dodge            2053
# Honda            1537
# Toyota           1533
# BMW              1483
# Chrysler         1197
# Nissan           1191
# Mercedes-Benz    1088
# Jeep             1054
# Name: count, dtype: int64

# %%
price_mean_2008 = car_sales_2008_df['sellingprice'].mean()
print(price_mean_2008)
# Out:
# 9458.500055532932

# %%
plt.figure(figsize=(12, 6))
make2008_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2008 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2009_df = df_by_year[2009][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2009_df
make2009_counts = car_sales_2009_df["make"].value_counts().head(10)
make2009_counts
# Out:
# make
# Chevrolet        2746
# Ford             1933
# Toyota           1745
# Dodge            1299
# Honda            1170
# Nissan           1061
# BMW               736
# Mercedes-Benz     647
# Hyundai           641
# Volkswagen        600
# Name: count, dtype: int64

# %%
price_mean_2009 = car_sales_2009_df['sellingprice'].mean()
print(price_mean_2009)
# Out:
# 10227.297176902946

# %%
plt.figure(figsize=(12, 6))
make2009_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2009 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2010_df = df_by_year[2010][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2010_df
make2010_counts = car_sales_2010_df["make"].value_counts().head(10)
make2010_counts
# Out:
# make
# Ford             3534
# Chevrolet        3347
# Dodge            2421
# Toyota           1991
# Honda            1313
# Nissan           1271
# Hyundai           740
# Mercedes-Benz     738
# Jeep              730
# Chrysler          724
# Name: count, dtype: int64

# %%
price_mean_2010 = car_sales_2010_df['sellingprice'].mean()
print(price_mean_2010)
# Out:
# 12254.805270604882

# %%
plt.figure(figsize=(12, 6))
make2010_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2010 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2011_df = df_by_year[2011][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2011_df
make2011_counts = car_sales_2011_df["make"].value_counts().head(10)
make2011_counts
# Out:
# make
# Ford             6685
# Chevrolet        4892
# Nissan           4825
# Toyota           3829
# Infiniti         2633
# BMW              2215
# Honda            1563
# Dodge            1476
# Hyundai          1440
# Mercedes-Benz    1310
# Name: count, dtype: int64

# %%
price_mean_2011 = car_sales_2011_df['sellingprice'].mean()
print(price_mean_2011)
# Out:
# 15690.067973129711

# %%
plt.figure(figsize=(12, 6))
make2011_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2011 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2012_df = df_by_year[2012][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2012_df
make2012_counts = car_sales_2012_df["make"].value_counts().head(10)
make2012_counts
# Out:
# make
# Ford             14640
# Nissan           13785
# Honda             7994
# Toyota            6675
# Chevrolet         6359
# Infiniti          4106
# BMW               3720
# Hyundai           3459
# Dodge             2742
# Mercedes-Benz     2641
# Name: count, dtype: int64

# %%
price_mean_2012 = car_sales_2012_df['sellingprice'].mean()
print(price_mean_2012)
# Out:
# 16441.895021744105

# %%
plt.figure(figsize=(12, 6))
make2012_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2012 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2013_df = df_by_year[2013][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2013_df
make2013_counts = car_sales_2013_df["make"].value_counts().head(10)
make2013_counts
# Out:
# make
# Ford             20459
# Chevrolet         9823
# Nissan            9759
# Hyundai           6869
# Toyota            6174
# Dodge             5432
# Infiniti          3982
# Kia               2747
# Chrysler          2726
# Mercedes-Benz     2491
# Name: count, dtype: int64

# %%
price_mean_2013 = car_sales_2013_df['sellingprice'].mean()
print(price_mean_2013)
# Out:
# 17319.47609955755

# %%
plt.figure(figsize=(12, 6))
make2013_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2013 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2014_df = df_by_year[2014][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2014_df
make2014_counts = car_sales_2014_df["make"].value_counts().head(10)
make2014_counts
# Out:
# make
# Ford         17179
# Chevrolet     8344
# Dodge         5542
# Kia           5468
# Toyota        5244
# Nissan        4504
# Chrysler      3664
# Jeep          2558
# Hyundai       2316
# BMW           1484
# Name: count, dtype: int64

# %%
price_mean_2014 = car_sales_2014_df['sellingprice'].mean()
print(price_mean_2014)
# Out:
# 19902.62274787698

# %%
plt.figure(figsize=(12, 6))
make2014_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2014 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
car_sales_2015_df = df_by_year[2015][["year","make", "model", "state", "color", "mmr", "sellingprice", "saledate", "type"]].copy()
car_sales_2015_df
make2015_counts = car_sales_2015_df["make"].value_counts().head(10)
make2015_counts
# Out:
# make
# Chevrolet    1256
# Kia          1254
# Ford          906
# BMW           601
# Nissan        499
# Hyundai       443
# Chrysler      404
# Mazda         333
# Volvo         317
# Jeep          289
# Name: count, dtype: int64

# %%
price_mean_2015 = car_sales_2015_df['sellingprice'].mean()
print(price_mean_2015)
# Out:
# 26168.987990993246

# %%
plt.figure(figsize=(12, 6))
make2015_counts.plot(kind='bar', color=colors)
plt.title('Top 10 2015 Models sold from 2014 to 2015')
plt.xlabel('Car Make')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=45)
plt.show()

# %%
# total_cars_by_model_year=[]
# years = [2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# for year in df_by_year[years]:
#     total_cars_by_model_year[year] = df_by_year[years]['make'].count()

# total_cars_by_model_year
total_cars_by_model_year = {}
price_mean_by_year = {}

for year, group_data in cars_clean_df.groupby('year'):
    total_cars_by_model_year[year] = group_data['make'].count()
    price_mean_by_year[year] = group_data['sellingprice'].mean()
print(total_cars_by_model_year)
print(price_mean_by_year)
# Out:
# {1990: 33, 1991: 51, 1992: 97, 1993: 127, 1994: 286, 1995: 483, 1996: 562, 1997: 1042, 1998: 1464, 1999: 2227, 2000: 3427, 2001: 5140, 2002: 7693, 2003: 10368, 2004: 13624, 2005: 17169, 2006: 21631, 2007: 25378, 2008: 27011, 2009: 17959, 2010: 22616, 2011: 41384, 2012: 87380, 2013: 87467, 2014: 69712, 2015: 7994}
# {1990: 1429.5454545454545, 1991: 994.6078431372549, 1992: 874.7422680412371, 1993: 777.3622047244095, 1994: 856.4685314685315, 1995: 875.9316770186335, 1996: 922.8647686832741, 1997: 1081.333973128599, 1998: 1262.233606557377, 1999: 1520.4737314773238, 2000: 1783.1645754304056, 2001: 2161.770428015564, 2002: 2662.820746132848, 2003: 3395.4258294753085, 2004: 4317.718731650029, 2005: 4881.957889218941, 2006: 5993.042808931626, 2007: 7861.239853416345, 2008: 9458.500055532932, 2009: 10227.297176902946, 2010: 12254.805270604882, 2011: 15690.067973129711, 2012: 16441.895021744105, 2013: 17319.47609955755, 2014: 19902.62274787698, 2015: 26168.987990993246}

# %%
# Create a bar graph from 2005 to 2015 that shows cars sold and the mean of selling price
years = range(2005, 2016)
car_counts = [total_cars_by_model_year.get(year, 0) for year in years]

plt.figure(figsize=(10, 6))
plt.bar(years, car_counts, color=colors)
plt.xlabel('Model Year')
plt.ylabel('Total Number of Cars')
plt.title('Total Number of Cars sold by Model Year from 2014 to 2015')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
years = range(2005, 2016)
car_prices = [price_mean_by_year.get(year, 0) for year in years]

plt.figure(figsize=(10, 6))
plt.bar(years, car_prices, color=colors)
plt.xlabel('Model Year')
plt.ylabel('Avergae Selling Price ')
plt.title('Average Price by Model Year from 2014 to 2015')
plt.xticks(years)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
cars_clean_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0  white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0   gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0  white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0   gray
# ...             ...                ...   ...        ...       ...    ...
# 472320    automatic  wbafr1c53bc744672    fl       39.0   66403.0  white
# 472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0  white
# 472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0  black
# 472323    automatic  1n4al3ap0fc216050    ga       38.0   16658.0  white
# 472324    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 472320    brown           lauderdale imports ltd bmw pembrok pines  20300.0
# 472321    black                                    i -5 uhlmann rv  30200.0
# 472322    black             financial services remarketing (lease)  29800.0
# 472323    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 472324     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate   type
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)  Sedan
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)  Sedan
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Sedan
# ...              ...                                      ...    ...
# 472320       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)  Sedan
# 472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)  Truck
# 472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    SUV
# 472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)  Sedan
# 472324       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)  Truck
#
# [472325 rows x 17 columns]

# %%
cars_clean_df['saledate'] = cars_clean_df['saledate'].astype(str)
cars_clean_df['month'] = cars_clean_df['saledate'].str.split().str[1]
cars_clean_df['salesyear'] = cars_clean_df['saledate'].str.split().str[3]
cars_clean_df['day'] = cars_clean_df['saledate'].str.split().str[2]
cars_clean_df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer  color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0  white
# 1         automatic  5xyktca69fg561319    ca        5.0    9393.0  white
# 2         automatic  wba3c1c51ek116351    ca       45.0    1331.0   gray
# 3         automatic  yv1612tb4f1310987    ca       41.0   14282.0  white
# 4         automatic  wba6b2c57ed129731    ca       43.0    2641.0   gray
# ...             ...                ...   ...        ...       ...    ...
# 472320    automatic  wbafr1c53bc744672    fl       39.0   66403.0  white
# 472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0  white
# 472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0  black
# 472323    automatic  1n4al3ap0fc216050    ga       38.0   16658.0  white
# 472324    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#        interior                                             seller      mmr  \
# 0         black                            kia motors america  inc  20500.0
# 1         beige                            kia motors america  inc  20800.0
# 2         black             financial services remarketing (lease)  31900.0
# 3         black                            volvo na rep/world omni  27500.0
# 4         black             financial services remarketing (lease)  66000.0
# ...         ...                                                ...      ...
# 472320    brown           lauderdale imports ltd bmw pembrok pines  20300.0
# 472321    black                                    i -5 uhlmann rv  30200.0
# 472322    black             financial services remarketing (lease)  29800.0
# 472323    black  enterprise vehicle exchange / tra / rental / t...  15100.0
# 472324     gray                   ford motor credit company llc pd  29600.0
#
#         sellingprice                                 saledate   type month  \
# 0            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV   Dec
# 1            21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)    SUV   Dec
# 2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)  Sedan   Jan
# 3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)  Sedan   Jan
# 4            67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)  Sedan   Dec
# ...              ...                                      ...    ...   ...
# 472320       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)  Sedan   Jul
# 472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)  Truck   Jul
# 472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    SUV   Jul
# 472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)  Sedan   Jul
# 472324       26700.0  Thu May 28 2015 05:30:00 GMT-0700 (PDT)  Truck   May
#
#        salesyear day
# 0           2014  16
# 1           2014  16
# 2           2015  15
# 3           2015  29
# 4           2014  18
# ...          ...  ..
# 472320      2015  07
# 472321      2015  08
# 472322      2015  08
# 472323      2015  09
# 472324      2015  28
#
# [472325 rows x 20 columns]

# %%
cars_clean_df['saledate'] = cars_clean_df['saledate'].astype(str)
cars_clean_df['month'] = cars_clean_df['saledate'].str.split().str[1]
cars_clean_df['salesyear'] = cars_clean_df['saledate'].str.split().str[3]
cars_clean_df['day'] = cars_clean_df['saledate'].str.split().str[2]
cars_clean_df
# Define the custom order of months
custom_order = ['Dec','Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

# Group by 'sale_month' and count the number of cars sold in each month
cars_sold_by_month = cars_clean_df.groupby('month').size()

# Create a bar graph for cars sold by month
plt.figure(figsize=(12, 6))
cars_sold_by_month.reindex(custom_order).plot(kind='bar', color=colors)
plt.title('Number of Cars Sold by Month (Dec 2014 to Jul 2015)')
plt.xlabel('Month')
plt.ylabel('Number of Cars Sold')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
df_by_month = {month: group for month, group in cars_clean_df.groupby('month')}
df_by_month
# Out:
# {'Apr':         year       make             model     trim      body transmission  \
#  6309    2014   Chrysler  Town and Country  Touring   Minivan    automatic
#  15876   2004     Nissan             Quest    3.5 S   Minivan    automatic
#  27934   2014  Chevrolet          Traverse       LT       SUV    automatic
#  40707   2005       Ford   Econoline Cargo    E-250       Van    automatic
#  41185   2003       Ford             F-150       XL  SuperCab       manual
#  ...      ...        ...               ...      ...       ...          ...
#  348878  2015  Chevrolet  Silverado 2500HD       LT  Crew Cab    automatic
#  348976  2001     Nissan            Maxima       SE     Sedan    automatic
#  348979  1997      Lexus            ES 300     Base     Sedan    automatic
#  349003  2015       Ford            Escape       SE       SUV    automatic
#  349009  2014     Toyota           Corolla       LE     Sedan    automatic
#
#                        vin state  condition  odometer     color interior  \
#  6309    2c4rc1bgxer359349    il        4.0   17283.0     black    black
#  15876   5n1bv28u94n362426    nj       21.0       1.0      gray     gray
#  27934   1gnkvgkd1ej311772    il        3.0   22929.0     white     gray
#  40707   1ftns24w55hb20590    mi        2.0       1.0  burgundy     gray
#  41185   2ftrx17243cb00289    nc       28.0       1.0     white     gray
#  ...                   ...   ...        ...       ...       ...      ...
#  348878  1gc1kveg0ff560009    ga        2.0   12587.0       red    black
#  348976  jn1ca31d61t838887    ca       24.0  142681.0     green      tan
#  348979  jt8bf22g0v5001770    fl       19.0  179218.0     beige    beige
#  349003  1fmcu9g97fua11276    ga        2.0       1.0    silver     gray
#  349009  5yfburhe7ep099785    ga        2.0   35262.0       red     gray
#
#                                                     seller      mmr  \
#  6309                              enterprise holdings/gdp  13300.0
#  15876                           purple heart services inc   3975.0
#  27934                                      gm remarketing  15850.0
#  40707                                                 ari   3875.0
#  41185            repo remarketing/first flight federal cu   3900.0
#  ...                                                   ...      ...
#  348878  enterprise vehicle exchange / tra / rental / t...  34100.0
#  348976                           lithia hyundai of fresno   1475.0
#  348979                                   david j leahy jr   1525.0
#  349003  enterprise vehicle exchange / tra / rental / t...  23900.0
#  349009  enterprise vehicle exchange / tra / rental / t...  13100.0
#
#          sellingprice                                 saledate     type month  \
#  6309         13000.0  Thu Apr 30 2015 04:00:00 GMT-0700 (PDT)  Minivan   Apr
#  15876         1150.0  Thu Apr 23 2015 11:00:00 GMT-0700 (PDT)  Minivan   Apr
#  27934        15400.0  Tue Apr 07 2015 03:40:00 GMT-0700 (PDT)      SUV   Apr
#  40707          500.0  Thu Apr 23 2015 02:30:00 GMT-0700 (PDT)      Van   Apr
#  41185         4200.0  Mon Apr 13 2015 02:30:00 GMT-0700 (PDT)    Truck   Apr
#  ...              ...                                      ...      ...   ...
#  348878       40000.0  Thu Apr 30 2015 05:30:00 GMT-0700 (PDT)    Truck   Apr
#  348976        1150.0  Thu Apr 30 2015 06:00:00 GMT-0700 (PDT)    Sedan   Apr
#  348979         900.0  Thu Apr 30 2015 08:30:00 GMT-0700 (PDT)    Sedan   Apr
#  349003        2100.0  Thu Apr 30 2015 05:30:00 GMT-0700 (PDT)      SUV   Apr
#  349009       11000.0  Thu Apr 30 2015 05:30:00 GMT-0700 (PDT)    Sedan   Apr
#
#         salesyear day
#  6309        2015  30
#  15876       2015  23
#  27934       2015  07
#  40707       2015  23
#  41185       2015  13
#  ...          ...  ..
#  348878      2015  30
#  348976      2015  30
#  348979      2015  30
#  349003      2015  30
#  349009      2015  30
#
#  [1246 rows x 20 columns],
#  'Dec':        year           make                model          trim       body  \
#  0      2015            Kia              Sorento            LX        SUV
#  1      2015            Kia              Sorento            LX        SUV
#  4      2014            BMW  6 Series Gran Coupe          650i      Sedan
#  5      2015         Nissan               Altima         2.5 S      Sedan
#  6      2014            BMW                   M5          Base      Sedan
#  ...     ...            ...                  ...           ...        ...
#  54932  2011          Lexus               GX 460       Premium        SUV
#  54938  2011           MINI    Cooper Countryman             S      Wagon
#  54950  2011  Mercedes-Benz             GL-Class  GL450 4MATIC        SUV
#  54954  2011          Mazda               Mazda6       i Sport      Sedan
#  54964  2011          Mazda          Mazdaspeed3         Sport  Hatchback
#
#        transmission                vin state  condition  odometer   color  \
#  0        automatic  5xyktca69fg566472    ca        5.0   16639.0   white
#  1        automatic  5xyktca69fg561319    ca        5.0    9393.0   white
#  4        automatic  wba6b2c57ed129731    ca       43.0    2641.0    gray
#  5        automatic  1n4al3ap1fn326013    ca        1.0    5554.0    gray
#  6        automatic  wbsfv9c51ed593089    ca       34.0   14943.0   black
#  ...            ...                ...   ...        ...       ...     ...
#  54932    automatic  jtjjm7fx1b5030374    tx       43.0   48518.0   white
#  54938    automatic  wmwzc3c55bwl79176    tx       44.0   49067.0  orange
#  54950    automatic  4jgbf7be4ba736733    tn        5.0   46228.0    blue
#  54954    automatic  1yvhz8bh2b5m28095    nv       33.0   57816.0   black
#  54964       manual  jm1bl1k42b1900594    nv       35.0   43572.0   black
#
#        interior                                             seller      mmr  \
#  0        black                            kia motors america  inc  20500.0
#  1        beige                            kia motors america  inc  20800.0
#  4        black             financial services remarketing (lease)  66000.0
#  5        black  enterprise vehicle exchange / tra / rental / t...  15350.0
#  6        black                              the hertz corporation  69000.0
#  ...        ...                                                ...      ...
#  54932     gray                            frank kent cadillac ltd  36100.0
#  54938    black                                david mcdavid acura  15950.0
#  54950      tan                                 231 car sales inc.  30800.0
#  54954    black                                       planet mazda   8925.0
#  54964    black                                       planet mazda  14900.0
#
#         sellingprice                                 saledate       type month  \
#  0           21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)        SUV   Dec
#  1           21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)        SUV   Dec
#  4           67000.0  Thu Dec 18 2014 12:30:00 GMT-0800 (PST)      Sedan   Dec
#  5           10900.0  Tue Dec 30 2014 12:00:00 GMT-0800 (PST)      Sedan   Dec
#  6           65000.0  Wed Dec 17 2014 12:30:00 GMT-0800 (PST)      Sedan   Dec
#  ...             ...                                      ...        ...   ...
#  54932       37400.0  Wed Dec 31 2014 10:30:00 GMT-0800 (PST)        SUV   Dec
#  54938       15400.0  Wed Dec 31 2014 10:20:00 GMT-0800 (PST)      Wagon   Dec
#  54950       29850.0  Wed Dec 31 2014 10:30:00 GMT-0800 (PST)        SUV   Dec
#  54954        9500.0  Wed Dec 31 2014 12:00:00 GMT-0800 (PST)      Sedan   Dec
#  54964       14750.0  Wed Dec 31 2014 12:00:00 GMT-0800 (PST)  Hatchback   Dec
#
#        salesyear day
#  0          2014  16
#  1          2014  16
#  4          2014  18
#  5          2014  30
#  6          2014  17
#  ...         ...  ..
#  54932      2014  31
#  54938      2014  31
#  54950      2014  31
#  54954      2014  31
#  54964      2014  31
#
#  [36600 rows x 20 columns],
#  'Feb':         year      make     model          trim   body transmission  \
#  19      2014       BMW  5 Series          528i  Sedan    automatic
#  22      2015     Volvo      XC70            T6  Wagon    automatic
#  23      2015     Volvo      XC70            T6  Wagon    automatic
#  34      2014  Cadillac       ELR          Base  Coupe    automatic
#  45      2015       Kia      K900        Luxury  Sedan    automatic
#  ...      ...       ...       ...           ...    ...          ...
#  322059  1998     Honda    Accord            LX  Sedan    automatic
#  322149  2014       Kia   Cadenza       Premium  Sedan    automatic
#  322151  2014      Jeep  Wrangler         Sport    SUV       manual
#  322290  2015    Nissan     Versa        1.6 SL  Sedan       manual
#  322381  2012      Audi        A6  2.0T Premium  Sedan    automatic
#
#                        vin state  condition  odometer  color interior  \
#  19      wba5a5c51ed501631    ca       29.0   25969.0  black    black
#  22      yv4902nb3f1198103    ca       42.0   16506.0  brown    brown
#  23      yv4902nb3f1196951    ca       48.0   12725.0  beige    beige
#  34      1g6rr1e48eu601450    ca       47.0    4436.0   gray    black
#  45      knalw4d42f6019667    ca       42.0    5304.0   blue    black
#  ...                   ...   ...        ...       ...    ...      ...
#  322059  1hgcg564xwa058038    ca       19.0  208841.0   gray     gray
#  322149  knaln4d72e5128258    nv        5.0    7424.0  brown    black
#  322151  1c4ajwagxel296179    nv        5.0    6354.0  white    black
#  322290  3n1cn7ap3fl801412    nv       49.0    7928.0   blue    black
#  322381  waudfafc6cn150724    nv       49.0   30308.0  white    black
#
#                                          seller      mmr  sellingprice  \
#  19      financial services remarketing (lease)  34200.0       30000.0
#  22                     volvo na rep/world omni  32100.0       32500.0
#  23                     volvo na rep/world omni  32300.0       32500.0
#  34                                    rogue cu  49400.0       44000.0
#  45                     kia motors america  inc  39500.0       40000.0
#  ...                                        ...      ...           ...
#  322059                    pleasant auto center   1200.0         700.0
#  322149                           main auto llc  21900.0       23600.0
#  322151                chapmans las vegas dodge  25600.0       26250.0
#  322290                           planet nissan  11250.0       11600.0
#  322381      gaudin jaguar porsche of las vegas  26600.0       28250.0
#
#                                         saledate   type month salesyear day
#  19      Tue Feb 03 2015 04:30:00 GMT-0800 (PST)  Sedan   Feb      2015  03
#  22      Thu Feb 26 2015 04:30:00 GMT-0800 (PST)  Wagon   Feb      2015  26
#  23      Thu Feb 12 2015 04:30:00 GMT-0800 (PST)  Wagon   Feb      2015  12
#  34      Wed Feb 04 2015 04:30:00 GMT-0800 (PST)  Coupe   Feb      2015  04
#  45      Tue Feb 17 2015 04:30:00 GMT-0800 (PST)  Sedan   Feb      2015  17
#  ...                                         ...    ...   ...       ...  ..
#  322059  Fri Feb 27 2015 07:00:00 GMT-0800 (PST)  Sedan   Feb      2015  27
#  322149  Fri Feb 27 2015 03:45:00 GMT-0800 (PST)  Sedan   Feb      2015  27
#  322151  Fri Feb 27 2015 04:00:00 GMT-0800 (PST)    SUV   Feb      2015  27
#  322290  Fri Feb 27 2015 04:00:00 GMT-0800 (PST)  Sedan   Feb      2015  27
#  322381  Fri Feb 27 2015 04:00:00 GMT-0800 (PST)  Sedan   Feb      2015  27
#
#  [142338 rows x 20 columns],
#  'Jan':         year       make     model        trim         body transmission  \
#  2       2014        BMW  3 Series  328i SULEV        Sedan    automatic
#  3       2015      Volvo       S60          T5        Sedan    automatic
#  9       2014  Chevrolet    Camaro          LT  Convertible    automatic
#  12      2015       Ford    Fusion          SE        Sedan    automatic
#  21      2014        BMW  6 Series        650i  Convertible    automatic
#  ...      ...        ...       ...         ...          ...          ...
#  178518  2013       Ford     Focus          SE        Sedan    automatic
#  178520  2013       Ford    Fusion          SE        Sedan    automatic
#  178524  2013       Ford   Mustang          V6        Coupe    automatic
#  178526  2013       Ford    Taurus         SEL        Sedan    automatic
#  178527  2013       Ford   Mustang    Boss 302        Coupe       manual
#
#                        vin state  condition  odometer   color interior  \
#  2       wba3c1c51ek116351    ca       45.0    1331.0    gray    black
#  3       yv1612tb4f1310987    ca       41.0   14282.0   white    black
#  9       2g1fb3d37e9218789    ca        3.0    4809.0     red    black
#  12      3fa6p0hdxfr145753    ca        2.0    5559.0   white    beige
#  21      wbayp9c57ed169262    ca       38.0   10736.0   black    black
#  ...                   ...   ...        ...       ...     ...      ...
#  178518  1fadp3f27dl337704    ca        1.0   48367.0   white     gray
#  178520  3fa6p0h77dr101569    fl       47.0   11255.0   white    beige
#  178524  1zvbp8am0d5242118    wa       46.0   35424.0     red    black
#  178526  1fahp2e87dg166270    mo       41.0   55626.0   black    black
#  178527  1zvbp8cu6d5246364    tx        5.0    7083.0  yellow    black
#
#                                                     seller      mmr  \
#  2                  financial services remarketing (lease)  31900.0
#  3                                 volvo na rep/world omni  27500.0
#  9                                      d/m auto sales inc  26300.0
#  12      enterprise vehicle exchange / tra / rental / t...  15350.0
#  21                                  the hertz corporation  67000.0
#  ...                                                   ...      ...
#  178518                                 fox rent a car tra  10200.0
#  178520                      ford motor credit company llc  15350.0
#  178524                                   avis corporation  15850.0
#  178526                                exeter finance corp  13300.0
#  178527                                 j baer remarketing  36900.0
#
#          sellingprice                                 saledate         type  \
#  2            30000.0  Thu Jan 15 2015 04:30:00 GMT-0800 (PST)        Sedan
#  3            27750.0  Thu Jan 29 2015 04:30:00 GMT-0800 (PST)        Sedan
#  9            17500.0  Tue Jan 20 2015 04:00:00 GMT-0800 (PST)  Convertible
#  12           12000.0  Tue Jan 13 2015 12:00:00 GMT-0800 (PST)        Sedan
#  21           65000.0  Tue Jan 06 2015 12:30:00 GMT-0800 (PST)  Convertible
#  ...              ...                                      ...          ...
#  178518        2250.0  Tue Jan 27 2015 05:00:00 GMT-0800 (PST)        Sedan
#  178520       15200.0  Fri Jan 30 2015 01:00:00 GMT-0800 (PST)        Sedan
#  178524       16300.0  Wed Jan 28 2015 04:30:00 GMT-0800 (PST)        Coupe
#  178526       13400.0  Wed Jan 28 2015 02:30:00 GMT-0800 (PST)        Sedan
#  178527       37000.0  Wed Jan 28 2015 02:00:00 GMT-0800 (PST)        Coupe
#
#         month salesyear day
#  2        Jan      2015  15
#  3        Jan      2015  29
#  9        Jan      2015  20
#  12       Jan      2015  13
#  21       Jan      2015  06
#  ...      ...       ...  ..
#  178518   Jan      2015  27
#  178520   Jan      2015  30
#  178524   Jan      2015  28
#  178526   Jan      2015  28
#  178527   Jan      2015  28
#
#  [121399 rows x 20 columns],
#  'Jul':         year           make          model                    trim      body  \
#  18      2015      Chevrolet         Impala                     LTZ     Sedan
#  2053    2014          Dodge  Grand Caravan                     SXT   Minivan
#  2475    2010  Mercedes-Benz        E-Class                    E350     Sedan
#  5270    2013           Ford         Fusion                      SE     Sedan
#  6265    2015      Chevrolet       Suburban                      LT       SUV
#  ...      ...            ...            ...                     ...       ...
#  472319  2012          Dodge  Grand Caravan  American Value Package   Minivan
#  472320  2011            BMW       5 Series                    528i     Sedan
#  472321  2012            Ram           2500             Power Wagon  Crew Cab
#  472322  2012            BMW             X5               xDrive35d       SUV
#  472323  2015         Nissan         Altima                   2.5 S     sedan
#
#         transmission                vin state  condition  odometer   color  \
#  18        automatic  2g1165s30f9103921    ca       19.0   14538.0  silver
#  2053      automatic  2c4rdgcgxer263526    ca        3.0   26199.0       —
#  2475      automatic  wddhf5gb2aa236009    ca       43.0   43888.0   white
#  5270      automatic  3fa6p0h71dr349266    ca       26.0       1.0   white
#  6265      automatic  1gnskjkc4fr158207    pa        4.0   19410.0   black
#  ...             ...                ...   ...        ...       ...     ...
#  472319    automatic  2c4rdgbg1cr349287    ma       37.0   97036.0  silver
#  472320    automatic  wbafr1c53bc744672    fl       39.0   66403.0   white
#  472321    automatic  3c6td5et6cg112407    wa        5.0   54393.0   white
#  472322    automatic  5uxzw0c58cl668465    ca       48.0   50561.0   black
#  472323    automatic  1n4al3ap0fc216050    ga       38.0   16658.0   white
#
#           interior                                             seller      mmr  \
#  18          black  enterprise vehicle exchange / tra / rental / t...  24300.0
#  2053        black                            enterprise holdings/gdp  29400.0
#  2475    off-white                                  mercedes-benz usa  21500.0
#  5270        black                                 fox rent a car tra  10000.0
#  6265        black                     enterprise veh exchange/rental  11100.0
#  ...           ...                                                ...      ...
#  472319       gray              ge fleet services for itself/servicer   8300.0
#  472320      brown           lauderdale imports ltd bmw pembrok pines  20300.0
#  472321      black                                    i -5 uhlmann rv  30200.0
#  472322      black             financial services remarketing (lease)  29800.0
#  472323      black  enterprise vehicle exchange / tra / rental / t...  15100.0
#
#          sellingprice                                 saledate     type month  \
#  18            7200.0  Tue Jul 07 2015 09:30:00 GMT-0700 (PDT)    Sedan   Jul
#  2053         15800.0  Wed Jul 01 2015 09:30:00 GMT-0700 (PDT)  Minivan   Jul
#  2475         23500.0  Tue Jul 07 2015 09:30:00 GMT-0700 (PDT)    Sedan   Jul
#  5270          3500.0  Thu Jul 02 2015 09:30:00 GMT-0700 (PDT)    Sedan   Jul
#  6265         46400.0  Tue Jul 07 2015 07:00:00 GMT-0700 (PDT)      SUV   Jul
#  ...              ...                                      ...      ...   ...
#  472319        7800.0  Tue Jul 07 2015 06:30:00 GMT-0700 (PDT)  Minivan   Jul
#  472320       22800.0  Tue Jul 07 2015 06:15:00 GMT-0700 (PDT)    Sedan   Jul
#  472321       30800.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)    Truck   Jul
#  472322       34000.0  Wed Jul 08 2015 09:30:00 GMT-0700 (PDT)      SUV   Jul
#  472323       11100.0  Thu Jul 09 2015 06:45:00 GMT-0700 (PDT)    Sedan   Jul
#
#         salesyear day
#  18          2015  07
#  2053        2015  01
#  2475        2015  07
#  5270        2015  02
#  6265        2015  07
#  ...          ...  ..
#  472319      2015  07
#  472320      2015  07
#  472321      2015  08
#  472322      2015  08
#  472323      2015  09
#
#  [1111 rows x 20 columns],
#  'Jun':         year           make         model             trim   body  \
#  2688    2009          Honda         Civic               LX  Sedan
#  3700    2005  Mercedes-Benz       C-Class  C230 Kompressor  Sedan
#  4418    2014           Ford       Mustang               GT  Coupe
#  5901    2006        Hyundai        Sonata               LX  Sedan
#  6162    2014  Mercedes-Benz     CLA-Class           CLA250  Sedan
#  ...      ...            ...           ...              ...    ...
#  472271  2009        Pontiac            G8              GXP  sedan
#  472273  2007  Mercedes-Benz       S-Class             S550  sedan
#  472275  2014  Mercedes-Benz       E-Class      E350 Luxury  sedan
#  472276  2012       Maserati  Quattroporte                S  sedan
#  472282  2004           Ford    Expedition              XLT    suv
#
#         transmission                vin state  condition  odometer   color  \
#  2688      automatic  2hgfa16579h341583    ca        3.0       1.0  silver
#  3700      automatic  wdbrf40j25f712633    ca       19.0       1.0     red
#  4418      automatic  1zvbp8cf6e5242558    ca       28.0   26587.0   black
#  5901      automatic  5npeu46f86h069365    ca       19.0  176133.0  silver
#  6162      automatic  wddsj4eb5en062419    ca       36.0   13099.0       —
#  ...             ...                ...   ...        ...       ...     ...
#  472271    automatic  6g2ep57w49l306159    mo       35.0   50240.0     red
#  472273    automatic  wddng71x97a082259    ga       28.0  143856.0   black
#  472275    automatic  wddhf5kb9eb055822    ga       49.0   11448.0    blue
#  472276    automatic  zam39jka1c0060738    ga       39.0   21923.0    blue
#  472282    automatic  1fmru15w64la02138    fl       35.0  108286.0   white
#
#         interior                                  seller      mmr  \
#  2688       gray        ahfc/honda lease trust/hvt  inc.   9325.0
#  3700          —                   hadad auto whole sale   5375.0
#  4418      black                   the hertz corporation  24500.0
#  5901       gray                lithia hyundai of fresno   1625.0
#  6162       gray  mercedes-benz finc wholesale advantage  44900.0
#  ...         ...                                     ...      ...
#  472271    black              woodys dodge jeep chrysler  29600.0
#  472273    black                      rbm of atlanta inc  13500.0
#  472275    beige  mercedes-benz finc wholesale advantage  40600.0
#  472276        —              maserati north america inc  53300.0
#  472282     gray          prestige leasing and sales inc   4325.0
#
#          sellingprice                                 saledate   type month  \
#  2688          1000.0  Tue Jun 30 2015 10:00:00 GMT-0700 (PDT)  Sedan   Jun
#  3700          6800.0  Thu Jun 25 2015 05:00:00 GMT-0700 (PDT)  Sedan   Jun
#  4418         25500.0  Wed Jun 03 2015 05:30:00 GMT-0700 (PDT)  Coupe   Jun
#  5901          2400.0  Tue Jun 30 2015 09:30:00 GMT-0700 (PDT)  Sedan   Jun
#  6162         44500.0  Thu Jun 18 2015 05:30:00 GMT-0700 (PDT)  Sedan   Jun
#  ...              ...                                      ...    ...   ...
#  472271       26500.0  Wed Jun 24 2015 03:30:00 GMT-0700 (PDT)  Sedan   Jun
#  472273       15600.0  Wed Jun 24 2015 03:00:00 GMT-0700 (PDT)  Sedan   Jun
#  472275       40500.0  Wed Jun 24 2015 02:00:00 GMT-0700 (PDT)  Sedan   Jun
#  472276       40250.0  Wed Jun 24 2015 03:00:00 GMT-0700 (PDT)  Sedan   Jun
#  472282        5100.0  Wed Jun 24 2015 02:30:00 GMT-0700 (PDT)    SUV   Jun
#
#         salesyear day
#  2688        2015  30
#  3700        2015  25
#  4418        2015  03
#  5901        2015  30
#  6162        2015  18
#  ...          ...  ..
#  472271      2015  24
#  472273      2015  24
#  472275      2015  24
#  472276      2015  24
#  472282      2015  24
#
#  [85405 rows x 20 columns],
#  'Mar':         year       make           model     trim          body transmission  \
#  2810    2008   Chrysler             300       LX         Sedan    automatic
#  3384    2006    Pontiac              G6     Base         Sedan    automatic
#  3497    2014       Ford         Mustang       V6         Coupe    automatic
#  3593    2005        GMC          Canyon  Z85 SLE      Crew Cab    automatic
#  3719    2005      Mazda          Mazda3        s     Hatchback    automatic
#  ...      ...        ...             ...      ...           ...          ...
#  342815  2013     Nissan          Altima      2.5         Sedan    automatic
#  342820  2014       Ford          Fusion       SE         Sedan    automatic
#  342826  2008  Chevrolet          Impala       LT         Sedan    automatic
#  342829  2000  Chevrolet  Silverado 1500       LS  Extended Cab    automatic
#  342876  2001       Ford        Explorer      XLT           SUV    automatic
#
#                        vin state  condition  odometer   color interior  \
#  2810    2c3ka43r78h186722    ca       19.0       1.0   white    black
#  3384    1g2zf55b064165047    ca        1.0  101678.0     red    black
#  3497    1zvbp8am4e5201217    ca       31.0   32202.0  silver    beige
#  3593    1gtcs136058145917    ca       19.0  180009.0   green    black
#  3719    jm1bk343151309194    ca        2.0   35333.0  silver    black
#  ...                   ...   ...        ...       ...     ...      ...
#  342815  1n4al3ap1dn531750    ca       43.0   19861.0       —    black
#  342820  3fa6p0h7xer243903    fl       45.0   15138.0   green    black
#  342826  2g1wt58k189247641    mo       39.0   91683.0    gray     gray
#  342829  2gcek19t2y1135578    nj       19.0  110915.0   white     gray
#  342876  1fmzu73e41za42496    md       19.0  131890.0     red     gray
#
#                                       seller      mmr  sellingprice  \
#  2810            wells fargo dealer services  32500.0        1300.0
#  3384               finn's discount auto inc   3950.0         800.0
#  3497                       avis corporation  18100.0       17700.0
#  3593                    redline remarketing   4175.0        4400.0
#  3719                       nextgear capital   6200.0        6900.0
#  ...                                     ...      ...           ...
#  342815  nissan motor acceptance corporation  14900.0       11250.0
#  342820             palm beach auto mall inc  16100.0       29000.0
#  342826                 o'fallon motorsports   6750.0       22000.0
#  342829                    grand motor sales   4800.0        2000.0
#  342876                   shannon auto sales   1325.0         750.0
#
#                                         saledate       type month salesyear day
#  2810    Thu Mar 26 2015 04:30:00 GMT-0700 (PDT)      Sedan   Mar      2015  26
#  3384    Wed Mar 04 2015 05:30:00 GMT-0800 (PST)      Sedan   Mar      2015  04
#  3497    Thu Mar 05 2015 04:00:00 GMT-0800 (PST)      Coupe   Mar      2015  05
#  3593    Wed Mar 04 2015 04:30:00 GMT-0800 (PST)      Truck   Mar      2015  04
#  3719    Wed Mar 04 2015 04:30:00 GMT-0800 (PST)  Hatchback   Mar      2015  04
#  ...                                         ...        ...   ...       ...  ..
#  342815  Tue Mar 31 2015 05:30:00 GMT-0700 (PDT)      Sedan   Mar      2015  31
#  342820  Tue Mar 31 2015 02:30:00 GMT-0700 (PDT)      Sedan   Mar      2015  31
#  342826  Tue Mar 31 2015 04:00:00 GMT-0700 (PDT)      Sedan   Mar      2015  31
#  342829  Tue Mar 31 2015 02:30:00 GMT-0700 (PDT)      Truck   Mar      2015  31
#  342876  Tue Mar 31 2015 02:30:00 GMT-0700 (PDT)        SUV   Mar      2015  31
#
#  [40590 rows x 20 columns],
#  'May':         year           make             model        trim       body  \
#  1387    2012            Kia            Optima          SX      Sedan
#  4789    2014  Mercedes-Benz         GLK-Class      GLK350        SUV
#  7107    2014       Chrysler  Town and Country     Touring    Minivan
#  12979   2014           Ford            Fusion          SE      Sedan
#  13518   2014           Ford           Mustang  GT Premium      Coupe
#  ...      ...            ...               ...         ...        ...
#  414353  2002           Ford          Explorer         XLT        suv
#  414518  2014           Ford  F-250 Super Duty          XL   supercab
#  414538  2014           Ford           Mustang  GT Premium      coupe
#  414669  2014         Nissan             Versa      1.6 SV      sedan
#  472324  2014           Ford             F-150         XLT  SuperCrew
#
#         transmission                vin state  condition  odometer  color  \
#  1387      automatic  5xxgr4a68cg001060    ca       45.0   32284.0  black
#  4789      automatic  wdcgg5hb7eg160737    ca        4.0   27842.0  black
#  7107      automatic  2c4rc1bg8er324759    il        4.0   31411.0   blue
#  12979     automatic  3fa6p0h79er262734    tx       37.0   31245.0      —
#  13518     automatic  1zvbp8cf2e5242539    az       38.0   21733.0  black
#  ...             ...                ...   ...        ...       ...    ...
#  414353    automatic  1fmdu73w12zb48764    ca       19.0  171026.0  white
#  414518    automatic  1ft7x2a60eea25421    nv       49.0    7063.0  white
#  414538    automatic  1zvbp8cf7e5219676    nv       46.0    5493.0    red
#  414669       manual  3n1cn7ap4el855946    nv       25.0   13542.0  black
#  472324    automatic  1ftfw1et2eke87277    ca       34.0   15008.0   gray
#
#         interior                            seller      mmr  sellingprice  \
#  1387      black           kia motors america  inc  17650.0       15000.0
#  4789      black                       elad motors  36600.0       37250.0
#  7107      black             hertz corporation/gdp  19900.0       21250.0
#  12979     black         budget rent a car/atlanta  13500.0       14800.0
#  13518     black             the hertz corporation  27100.0       26800.0
#  ...         ...                               ...      ...           ...
#  414353     gray                        motorworld   1175.0        1500.0
#  414518     gray        mercedes benz of south bay  24700.0       25500.0
#  414538    beige                   gaudin motor co  29100.0       26700.0
#  414669    black                 fiat of las vegas   9400.0        8200.0
#  472324     gray  ford motor credit company llc pd  29600.0       26700.0
#
#                                         saledate     type month salesyear day
#  1387    Tue May 19 2015 05:00:00 GMT-0700 (PDT)    Sedan   May      2015  19
#  4789    Thu May 21 2015 05:30:00 GMT-0700 (PDT)      SUV   May      2015  21
#  7107    Thu May 28 2015 04:00:00 GMT-0700 (PDT)  Minivan   May      2015  28
#  12979   Thu May 21 2015 03:30:00 GMT-0700 (PDT)    Sedan   May      2015  21
#  13518   Thu May 28 2015 05:00:00 GMT-0700 (PDT)    Coupe   May      2015  28
#  ...                                         ...      ...   ...       ...  ..
#  414353  Fri May 29 2015 08:00:00 GMT-0700 (PDT)      SUV   May      2015  29
#  414518  Fri May 29 2015 04:55:00 GMT-0700 (PDT)    Truck   May      2015  29
#  414538  Fri May 29 2015 04:55:00 GMT-0700 (PDT)    Coupe   May      2015  29
#  414669  Fri May 29 2015 04:55:00 GMT-0700 (PDT)    Sedan   May      2015  29
#  472324  Thu May 28 2015 05:30:00 GMT-0700 (PDT)    Truck   May      2015  28
#
#  [43636 rows x 20 columns]}

# %%
top_selling_car = cars_clean_df[cars_clean_df['month'] == 'Apr'].groupby(['make', 'model'])['sellingprice'].sum().reset_index()
top_selling_car = top_selling_car.sort_values(by='sellingprice', ascending=False).head(5)
print("Top Selling Make and Model for April:")
print(top_selling_car[['make', 'model']])
# Out:
# Top Selling Make and Model for April:
#        make   model
# 203  Nissan  Altima
# 98     Ford  Fusion
# 96     Ford   Focus
# 84     Ford  Escape
# 254  Toyota   Camry

# %%
# Group the data by 'make' and 'model', calculate the count of sales, and find the top selling make and model by count
top_selling_car_count = cars_clean_df[cars_clean_df['month'] == 'Apr'].groupby(['make', 'model','year']).size().reset_index(name='number_sold')
top_selling_car_count = top_selling_car_count.sort_values(by='number_sold', ascending=False).head(5)

# Display the top selling make and model by count
print("Top Selling Make and Model for April by Number Sold:")
print(top_selling_car_count[['make', 'model','year' ,'number_sold']].to_string(index=False))
# Out:
# Top Selling Make and Model for April by Number Sold:
#   make   model  year  number_sold
# Nissan  Altima  2012           33
# Nissan   Rogue  2012           21
#   Ford  Fusion  2014           18
# Toyota   Camry  2012           15
#   Ford Mustang  2014           13

# %%
#get the average selling price for a specific car(make, model, year) in the months in custom order
custom_order = ['Dec','Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

 
# Ford F-Series
 
# Toyota Camry
 
# Toyota Corolla
 
# Honda CR-V 
 
# Honda Accord

# %%
# Define the custom order for months
custom_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

for month in custom_order:
    top_selling_car_count = cars_clean_df[cars_clean_df['month'] == month].groupby(['make', 'model', 'year']).size().reset_index(name='number_sold')
    top_selling_car_count = top_selling_car_count.sort_values(by='number_sold', ascending=False).head(5)

    # Merge with the original DataFrame to get selling prices
    top_selling_cars_prices = pd.merge(top_selling_car_count, cars_clean_df[cars_clean_df['month'] == month], on=['make', 'model', 'year'], how='inner')

    # Calculate average selling price per car
    avg_prices = top_selling_cars_prices.groupby(['make', 'model', 'year']).agg(avg_price=('sellingprice', 'mean')).reset_index()

    # Display the top 5 selling cars for each month
    print(f"Top 5 Selling Cars for {month}:")
    for index, row in top_selling_car_count.iterrows():
        make = row['make']
        model = row['model']
        year = row['year']
        number_sold = row['number_sold']
        avg_price = avg_prices[(avg_prices['make'] == make) & (avg_prices['model'] == model) & (avg_prices['year'] == year)]['avg_price'].values[0]
        print(f"{make} {model} ({year}): Number Sold - {number_sold}, Average Price - {avg_price}")

    # Create separate bar graphs for count and average price for the top 5 cars in each month
    fig, axs = plt.subplots(2, 1, figsize=(8, 12))

    # Bar graph for number of cars sold
    axs[0].barh([f"{make} {model} ({year})" for make, model, year in zip(top_selling_car_count['make'], top_selling_car_count['model'], top_selling_car_count['year'])], top_selling_car_count['number_sold'], color='skyblue')
    axs[0].set_xlabel('Number Sold')
    axs[0].set_title(f'Top 5 Selling Cars - Number Sold in {month}')

    # Bar graph for average price per car
    axs[1].barh([f"{make} {model} ({year})" for make, model, year in zip(top_selling_car_count['make'], top_selling_car_count['model'], top_selling_car_count['year'])], avg_prices['avg_price'], color='salmon')
    axs[1].set_xlabel('Average Price')
    axs[1].set_title(f'Top 5 Selling Cars - Average Price in {month}')

    plt.tight_layout()
    
    # Save the figure as a PNG file
    plt.savefig(f'{month}_top_5_selling_cars.png')
    
    plt.show()
# Out:
# Top 5 Selling Cars for Dec:
# Nissan Altima (2012): Number Sold - 519, Average Price - 11851.447013487475
# Toyota Camry (2014): Number Sold - 410, Average Price - 16015.853658536585
# Honda Accord (2012): Number Sold - 323, Average Price - 13432.50773993808
# Nissan Altima (2013): Number Sold - 281, Average Price - 13918.338078291816
# Honda Civic (2012): Number Sold - 261, Average Price - 11619.157088122605
# Top 5 Selling Cars for Jan:
# Nissan Altima (2012): Number Sold - 1958, Average Price - 11904.216547497446
# Honda Accord (2012): Number Sold - 996, Average Price - 13457.58032128514
# Ford Escape (2013): Number Sold - 979, Average Price - 16413.94484167518
# Ford Fusion (2012): Number Sold - 974, Average Price - 10909.396303901438
# Ford Fusion (2013): Number Sold - 899, Average Price - 15020.469410456062
# Top 5 Selling Cars for Feb:
# Nissan Altima (2012): Number Sold - 2336, Average Price - 12180.031678082192
# Nissan Altima (2013): Number Sold - 1484, Average Price - 13452.014824797843
# Ford Fusion (2012): Number Sold - 1246, Average Price - 11003.900481540932
# Ford Fusion (2013): Number Sold - 1008, Average Price - 15237.004960317461
# Ford Escape (2013): Number Sold - 995, Average Price - 16572.243216080402
# Top 5 Selling Cars for Mar:
# Nissan Altima (2012): Number Sold - 756, Average Price - 12798.809523809523
# Nissan Altima (2013): Number Sold - 411, Average Price - 13485.905109489051
# Ford Escape (2013): Number Sold - 387, Average Price - 17291.090439276486
# Ford Fusion (2014): Number Sold - 343, Average Price - 15990.08746355685
# Chevrolet Cruze (2014): Number Sold - 313, Average Price - 13473.482428115016
# Top 5 Selling Cars for Apr:
# Nissan Altima (2012): Number Sold - 33, Average Price - 14613.636363636364
# Nissan Rogue (2012): Number Sold - 21, Average Price - 12130.952380952382
# Ford Fusion (2014): Number Sold - 18, Average Price - 16111.111111111111
# Toyota Camry (2012): Number Sold - 15, Average Price - 14126.666666666666
# Ford Mustang (2014): Number Sold - 13, Average Price - 22221.153846153848
# Top 5 Selling Cars for May:
# Nissan Altima (2012): Number Sold - 476, Average Price - 11637.605042016807
# Ford Escape (2013): Number Sold - 419, Average Price - 15595.10739856802
# Nissan Rogue (2012): Number Sold - 380, Average Price - 14293.815789473685
# Ford Fusion (2012): Number Sold - 377, Average Price - 11203.18302387268
# Hyundai Elantra (2013): Number Sold - 360, Average Price - 11243.472222222223
# Top 5 Selling Cars for Jun:
# Nissan Altima (2012): Number Sold - 1000, Average Price - 11625.0
# Nissan Altima (2013): Number Sold - 847, Average Price - 12542.159386068477
# Toyota Camry (2012): Number Sold - 832, Average Price - 13381.432692307691
# Hyundai Elantra (2013): Number Sold - 804, Average Price - 11275.594527363184
# Infiniti G Sedan (2012): Number Sold - 760, Average Price - 18277.10657894737
# Top 5 Selling Cars for Jul:
# Ford Fusion (2014): Number Sold - 13, Average Price - 18576.923076923078
# Ford Mustang (2014): Number Sold - 13, Average Price - 18588.46153846154
# Ford Explorer (2013): Number Sold - 13, Average Price - 26153.846153846152
# Dodge Grand Caravan (2013): Number Sold - 12, Average Price - 12175.0
# Ford Fusion (2012): Number Sold - 12, Average Price - 10858.333333333334

# %%
# custom_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']
# first_month = custom_order[0]  # Get the first month from the custom order
# top_selling_cars_first_month = cars_clean_df[cars_clean_df['month'] == first_month].groupby(['make', 'model', 'year']).size().reset_index(name='number_sold')
# top_selling_cars_first_month = top_selling_cars_first_month.sort_values(by='number_sold', ascending=False).head(5)
# tracked_cars = top_selling_cars_first_month[['make', 'model']]  # Store the make and model of the top cars
# #Iterate over the months and filter the data for the tracked cars:
# for month in custom_order:
#     top_selling_car_count = cars_clean_df[(cars_clean_df['month'] == month) & 
#                                           (cars_clean_df['make'].isin(tracked_cars['make'])) & 
#                                           (cars_clean_df['model'].isin(tracked_cars['model']))].groupby(['make', 'model', 'year']).size().reset_index(name='number_sold')
#     top_selling_car_count = top_selling_car_count.sort_values(by='number_sold', ascending=False).head(5)

#         # Merge with the original DataFrame to get selling prices
#     top_selling_cars_prices = pd.merge(top_selling_car_count, cars_clean_df[cars_clean_df['month'] == month], on=['make', 'model', 'year'], how='inner')

#     # Calculate average selling price per car
#     avg_prices = top_selling_cars_prices.groupby(['make', 'model', 'year']).agg(avg_price=('sellingprice', 'mean')).reset_index()

#     # Display the top 5 selling cars for each month
#     print(f"Top 5 Selling Cars for {month}:")
#     for index, row in top_selling_car_count.iterrows():
#         make = row['make']
#         model = row['model']
#         year = row['year']
#         number_sold = row['number_sold']
#         avg_price = avg_prices[(avg_prices['make'] == make) & (avg_prices['model'] == model) & (avg_prices['year'] == year)]['avg_price'].values[0]
#         print(f"{make} {model} ({year}): Number Sold - {number_sold}, Average Price - {avg_price}")

#     # Create separate bar graphs for count and average price for the top 5 cars in each month
#     fig, axs = plt.subplots(2, 1, figsize=(8, 12))

#     # Bar graph for number of cars sold
#     axs[0].barh([f"{make} {model} ({year})" for make, model, year in zip(top_selling_car_count['make'], top_selling_car_count['model'], top_selling_car_count['year'])], top_selling_car_count['number_sold'], color='skyblue')
#     axs[0].set_xlabel('Number Sold')
#     axs[0].set_title(f'Top 5 Selling Cars - Number Sold in {month}')

#     # Bar graph for average price per car
#     axs[1].barh([f"{make} {model} ({year})" for make, model, year in zip(top_selling_car_count['make'], top_selling_car_count['model'], top_selling_car_count['year'])], avg_prices['avg_price'], color='salmon')
#     axs[1].set_xlabel('Average Price')
#     axs[1].set_title(f'Top 5 Selling Cars - Average Price in {month}')

#     plt.tight_layout()
    
#     # Save the figure as a PNG file
#     plt.savefig(f'{month}_top_5_selling_cars from Dec.png')
    
#     plt.show()

# %%
# # Define the custom order for months
# custom_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

# # Get the first month's top selling cars
# first_month = custom_order[0]
# top_selling_cars_first_month = cars_clean_df[cars_clean_df['month'] == first_month].groupby(['make', 'model', 'year']).size().reset_index(name='number_sold')
# top_selling_cars_first_month = top_selling_cars_first_month.sort_values(by='number_sold', ascending=False).head(5)
# tracked_cars = top_selling_cars_first_month[['make', 'model']].values

# # Iterate over the tracked cars
# for make, model in tracked_cars:
#     car_data = []  # Store average price data for the car
#     for month in custom_order:
#         car_month_data = cars_clean_df[(cars_clean_df['month'] == month) & 
#                                        (cars_clean_df['make'] == make) & 
#                                        (cars_clean_df['model'] == model)]
#         avg_price = car_month_data['sellingprice'].mean()
#         car_data.append(avg_price)

#     # Create a line plot for the car tracking average price every month
#     plt.figure(figsize=(10, 6))
#     plt.plot(custom_order, car_data, marker='o', label=f'{make} {model}')
#     plt.xlabel('Month')
#     plt.ylabel('Average Price')
#     plt.title(f'Average Price Tracking for {make} {model}')
#     plt.legend()
#     plt.tight_layout()

#     # Save the figure as a PNG file
#     plt.savefig(f'{make}_{model}_avg_price_tracking.png')

#     plt.show()

# %%
import matplotlib.pyplot as plt

# Define the custom order for months
custom_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

# Get the first month's top selling cars
first_month = custom_order[0]
top_selling_cars_first_month = cars_clean_df[cars_clean_df['month'] == first_month].groupby(['make', 'model']).size().reset_index(name='number_sold')
top_selling_cars_first_month = top_selling_cars_first_month.sort_values(by='number_sold', ascending=False).head(5)
tracked_cars = top_selling_cars_first_month[['make', 'model']].values

# Create a line plot for all tracked cars in one graph
plt.figure(figsize=(12, 8))

for make, model in tracked_cars:
    car_data = []  # Store average price data for the car
    for month in custom_order:
        car_month_data = cars_clean_df[(cars_clean_df['month'] == month) & 
                                       (cars_clean_df['make'] == make) & 
                                       (cars_clean_df['model'] == model)]
        avg_price = car_month_data['sellingprice'].mean()
        car_data.append(avg_price)

    plt.plot(custom_order, car_data, marker='o', label=f'{make} {model}')

plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Average Price Tracking for Top Selling Cars')
plt.legend()
plt.tight_layout()

# Save the figure as a PNG file
plt.savefig('all_tracked_cars_avg_price_tracking.png')

plt.show()

# %%
# Define the custom order for months
custom_order = ['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul']

# Get the first month's top selling cars
first_month = custom_order[0]
top_selling_cars_first_month = cars_clean_df[cars_clean_df['month'] == first_month].groupby(['make', 'model']).size().reset_index(name='number_sold')
top_selling_cars_first_month = top_selling_cars_first_month.sort_values(by='number_sold', ascending=False).head(5)
tracked_cars = top_selling_cars_first_month[['make', 'model']].values

# Define colors for each tracked car
colors = ['blue', 'green', 'red', 'purple', 'orange']

# Iterate over the tracked cars
for i, (make, model) in enumerate(tracked_cars):
    car_data = []  # Store average price data for the car
    number_sold_data = []  # Store number of cars sold data for the car
    for month in custom_order:
        car_month_data = cars_clean_df[(cars_clean_df['month'] == month) & 
                                       (cars_clean_df['make'] == make) & 
                                       (cars_clean_df['model'] == model)]
        avg_price = car_month_data['sellingprice'].mean()
        car_data.append(avg_price)
        number_sold = len(car_month_data)
        number_sold_data.append(number_sold)

    # Create subplots for the line graph and bar graph
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 12))

    # Line graph for average price tracking
    ax1.plot(custom_order, car_data, marker='o', label=f'{make} {model}', color=colors[i])
    ax1.set_xlabel('Month')
    ax1.set_ylabel('Average Price')
    ax1.set_title(f'Average Price Tracking for {make} {model}')
    ax1.legend()

    # Bar graph for number of cars sold
    ax2.bar(custom_order, number_sold_data, color=colors[i])
    ax2.set_xlabel('Month')
    ax2.set_ylabel('Number Sold')
    ax2.set_title(f'Number of Cars Sold for {make} {model}')

    plt.tight_layout()

    # Save the figure as a PNG file
    plt.savefig(f'{make}_{model}_avg_price_number_sold_tracking.png')

    plt.show()
